# %% [markdown]
# # Loading and concatenating allen gene data

# %%
import numpy as np
import pandas as pd
import glob
import json
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Using Pandas to have anice look at some of the raw data
x = glob.glob('/media/mathew/Data_2/Allen_genes/api-examples/structures/raw_expression*')
rows = pd.read_json(x[2])
rows.head()
# Out:
#    expression_density  expression_energy         id  \
# 0            0.053474            8.90860  450107570
# 1            0.053474            8.90860  450107573
# 2            0.048175            7.88153  450107576
# 3            0.044946            7.53617  450107583
# 4            0.048972            8.28153  450107588
#
#                                     section_data_set  section_data_set_id  \
# 0  {'delegate': False, 'qc_date': '2009-05-02T23:...             74581394
# 1  {'delegate': False, 'qc_date': '2009-05-02T23:...             74581394
# 2  {'delegate': False, 'qc_date': '2009-05-02T23:...             74581394
# 3  {'delegate': False, 'qc_date': '2009-05-02T23:...             74581394
# 4  {'delegate': False, 'qc_date': '2009-05-02T23:...             74581394
#
#    structure_id  sum_expressing_pixel_intensity  sum_expressing_pixels  \
# 0         15564                     17567800000            105451000.0
# 1         15565                     17567800000            105451000.0
# 2         15566                     10524900000             64332900.0
# 3         15568                       300947000              1794850.0
# 4         15569                       120519000               712680.0
#
#    sum_pixel_intensity    sum_pixels  voxel_energy_cv  voxel_energy_mean
# 0          97598900000  1.972000e+09         0.527604            8.89557
# 1          97598900000  1.972000e+09         0.527604            8.89557
# 2          64605900000  1.335390e+09         0.483118            7.87337
# 3           1723840000  3.993370e+07         0.623599            7.54407
# 4            671011000  1.455270e+07         0.535451            8.27926

# %%
# Python list version of above (instead of pd.dataframe), but loading all of the data (the last file will error as of 20.03.17)
x = glob.glob('/media/mathew/Data_2/Allen_genes/api-examples/structures/raw_expression*')
# x = glob.glob('/Users/mathew/Dropbox/Data/allen_genes/raw_expression*')
my_union = []
# NOTE: first two files are not gene expression, so need to be avoided. Last item is also bad.
# TO DO: change for loop to reflect this - for now just deleting the bad entries posthoc
for i in range(len(x)):
    with open(x[i]) as json_data:
        my_union.append(json.load(json_data))
# Out:
# ---------------------------------------------------------------------------
# IsADirectoryError                         Traceback (most recent call last)
# <ipython-input-9-a39eee2768b2> in <module>()
#       4 my_union = []
#       5 for i in range(len(x)):
# ----> 6     with open(x[i]) as json_data:
#       7         my_union.append(json.load(json_data))
#       8
#
# IsADirectoryError: [Errno 21] Is a directory: '/media/mathew/Data_2/Allen_genes/api-examples/structures/raw_expression_json'

# %%
# The first two files aren't gene data so delete them
del my_union[0]
del my_union[0]
# my_union[0]

# save 'unionized' data as single json file
f = open('my_unionizes.json', "w")
f.write(json.dumps(my_union))
f.close()

# %%
# Load in structure data and dataset list (generated at the bottom of this notebook)
with open('structureIds.json') as json_data:
    structureIds = json.load(json_data)

with open('structHash.json') as json_data:
    structHash = json.load(json_data) 
    
# Change structHash keys back into ints (fixing json pipe 'issue')
structHash = {int(k): v for k,v in structHash.items()}
    
with open('dataSets.json') as json_data:
    dataSets = json.load(json_data) 
# structureIds
# dataSets?

# %%
# original version of region x gene indexing, not used.
# sidHash = dict([(id, i) for (i, id) in enumerate(structureIds)])
# didHash = dict([(d['id'], i) for (i, d) in enumerate(mini_data)])

# %%
# Generate region x gene index for all available regions and genes in dataset
allIds = [sid for sid, s in structHash.items()]
sidHash_all = dict([(id, i) for (i, id) in enumerate(allIds)])
didHash = {}
for i, us in enumerate(my_union):
    # for each unionize
    for j, u in enumerate(us):
        didHash[u['section_data_set_id']] = i

# %%
# Generate expression array and compute pairwise correlations
nstructs = len(allIds)
ndata = len(my_union) #my_union

expression = np.empty([nstructs, ndata])
expression.fill(np.nan)

# For each data set's set of unionizes, then for each individual structure,
# fill in the structure's expression vector.
for i, us in enumerate(my_union):
    # for each unionize
    for j, u in enumerate(us):
        sid = u['structure_id']
        did = u['section_data_set_id']


#         if sidHash.has_key(sid) and didHash.has_key(did):
        if sid in sidHash_all and did in didHash: 
            expression[sidHash_all[sid]][didHash[did]] = u['expression_energy']

# numpy has a masked_array data structure that performs computations while
# filtering out values you don't care about.  In this case, we don't want
# the correlation computation to use NaN's, which indicate that no
# expression was measured for a structure.
mdat = np.ma.masked_array(expression, np.isnan(expression))
corr = np.ma.corrcoef(mdat)

# %%
# Save expression data and correlation matrix
f = open('expression.json', "w")
f.write(json.dumps(expression.tolist()))
f.close()

f = open('gene_correlations.json', "w")
f.write(json.dumps(corr.tolist()))
f.close()

# %%
# image plot of expression vectors
np.shape(expression)
plt.imshow(expression)

# %%
# image of correlation matrix
plt.imshow(corr)

# %%
# Generate list of region names/ depths
region_names = [structHash[d]['name'] for d in allIds]  #structureIds
region_depth = [structHash[d]['depth'] for d in allIds] #structureIds

# %%
# Compute whether a node is a leaf (no children) or not
leaf_nodes = []
for d in allIds:
    if structHash[d]['num_children'] == 0:
        leaf_nodes.append(1)
    else:
        leaf_nodes.append(0)

# %%
# Check the above is consistent
n = 500
print(region_names[n],',',region_depth[n],',',leaf_nodes[n])
structHash[allIds[n]]
# Out:
# Subiculum, dorsal part , 8 , 0
# {'acronym': 'SUBd',
#  'atlas_id': 346,
#  'color_hex_triplet': '4FC244',
#  'depth': 8,
#  'failed': False,
#  'failed_facet': 734881840,
#  'graph_id': 1,
#  'graph_order': 536,
#  'hemisphere_id': 3,
#  'id': 509,
#  'name': 'Subiculum, dorsal part',
#  'neuro_name_structure_id': None,
#  'neuro_name_structure_id_path': None,
#  'num_children': 3,
#  'ontology_id': 1,
#  'parent_structure_id': 502,
#  'safe_name': 'Subiculum dorsal part',
#  'sphinx_id': 537,
#  'st_level': None,
#  'structure_id_path': [997, 8, 567, 688, 695, 1089, 822, 502, 509],
#  'structure_name_facet': 454566553,
#  'weight': 8690}

# %%
# Generate list of RGB colours per brain region
def hex2rgb(hexcode):
        hexcode = hexcode.lstrip('#')
        return list(int(hexcode[i:i+2],16) for i in (0, 2, 4))
    
region_colours = [hex2rgb(structHash[x]['color_hex_triplet']) for x in allIds]
# region_colours

# %%
# Make a list of parent nodes. Save level 3 structure (if available) and level 4 OR cortical region
parent_id = []
subregion_id = []
for x in allIds:
    num_parents = len(structHash[x]['structure_id_path'])-1
    
    subregion= structHash[structHash[x]['structure_id_path'][min(num_parents,4)]]['name']
    semi_parent = structHash[structHash[x]['structure_id_path'][min(num_parents,3)]]['name']
    if num_parents >=6 and structHash[x]['structure_id_path'][3]==688:
        subregion = structHash[structHash[x]['structure_id_path'][6]]['name']                             
    print(subregion,',',semi_parent,',',structHash[x]['name'],',',structHash[x]['depth'])                           
    
    parent_id.append(semi_parent)
    subregion_id.append(subregion)
                    
#     print(structHash[structHash[x]['structure_id_path'][semi_parent]]['name'],',',structHash[x]['name'],',',structHash[x]['depth'])
#     print(structHash[structHash[x]['structure_id_path'][semi_parent]]['name'],structHash[structHash[x]['structure_id_path'][semi_parent2]]['name'])
# Out:
# Hypothalamus , Interbrain , Tuberomammillary nucleus, ventral part , 8
# Somatosensory areas , Cerebral cortex , Primary somatosensory area, mouth, layer 6b , 9
# secondary fissure , secondary fissure , secondary fissure , 3
# Midbrain, sensory related , Midbrain , Inferior colliculus , 5
# Hypothalamus , Interbrain , Median eminence , 5
# internal capsule , corticospinal tract , internal capsule , 4
# Pons , Hindbrain , Principal sensory nucleus of the trigeminal , 6
# Basic cell groups and regions , Basic cell groups and regions , Basic cell groups and regions , 1
# Somatosensory areas , Cerebral cortex , Primary somatosensory area, trunk, layer 6a , 9
# Midbrain, motor related , Midbrain , Superior colliculus, motor related, intermediate gray layer , 6
# posterolateral fissure , posterolateral fissure , posterolateral fissure , 3
# Midbrain, behavioral state related , Midbrain , Interfascicular nucleus raphe , 6
# internal medullary lamina of the thalamus , thalamus related , internal medullary lamina of the thalamus , 4
# Thalamus , Interbrain , Parataenial nucleus , 7
# Cortical subplate , Cerebral cortex , Layer 6b, isocortex , 5
# Midbrain, motor related , Midbrain , Superior colliculus, motor related, intermediate white layer , 6
# nodular fissure , nodular fissure , nodular fissure , 3
# Hippocampal region , Cerebral cortex , Induseum griseum , 7
# Retrohippocampal region , Cerebral cortex , Entorhinal area, lateral part, layer 2 , 9
# lateral olfactory tract, general , olfactory nerve , lateral olfactory tract, general , 4
# Posterior parietal association areas , Cerebral cortex , Posterior parietal association areas , 6
# Striatum , Cerebral nuclei , Anterior amygdalar area , 6
# simple fissure , simple fissure , simple fissure , 3
# Midbrain, motor related , Midbrain , Superior colliculus, motor related, deep gray layer , 6
# Thalamus , Interbrain , Intergeniculate leaflet of the lateral geniculate complex , 7
# Retrohippocampal region , Cerebral cortex , Entorhinal area, lateral part, layer 6a , 9
# lateral spinothalamic tract , spinothalamic tract , lateral spinothalamic tract , 4
# Hypothalamus , Interbrain , Periventricular hypothalamic nucleus, anterior part , 6
# Anterior cingulate area , Cerebral cortex , Anterior cingulate area , 6
# Visual areas , Cerebral cortex , Primary visual area, layer 6a , 8
# intercrural fissure , intercrural fissure , intercrural fissure , 3
# Midbrain, motor related , Midbrain , Oculomotor nucleus , 5
# Gustatory areas , Cerebral cortex , Gustatory areas, layer 1 , 7
# longitudinal association bundle , cerebrum related , longitudinal association bundle , 4
# Hypothalamus , Interbrain , Paraventricular hypothalamic nucleus , 6
# Anterior cingulate area , Cerebral cortex , Anterior cingulate area, dorsal part , 7
# Visual areas , Cerebral cortex , posteromedial visual area, layer 2/3 , 8
# Midbrain, motor related , Midbrain , Superior colliculus, motor related, deep white layer , 6
# ansoparamedian fissure , ansoparamedian fissure , ansoparamedian fissure , 3
# Infralimbic area , Cerebral cortex , Infralimbic area , 6
# Medulla , Hindbrain , Spinal nucleus of the trigeminal, interpolar part , 6
# Hemispheric regions , Cerebellar cortex , Crus 2, granular layer , 7
# Hemispheric regions , Cerebellar cortex , Crus 2, Purkinje layer , 7
# Orbital area , Cerebral cortex , Orbital area, lateral part, layer 6a , 8
# Visual areas , Cerebral cortex , Anteromedial visual area, layer 6b , 8
# Hemispheric regions , Cerebellar cortex , Paramedian lobule, Purkinje layer , 6
# fornix system , cerebrum related , dorsal hippocampal commissure , 6
# Thalamus , Interbrain , Medial group of the dorsal thalamus , 6
# Hemispheric regions , Cerebellar cortex , Copula pyramidis, Purkinje layer , 6
# Hippocampal region , Cerebral cortex , Field CA2, pyramidal layer , 9
# Hemispheric regions , Cerebellar cortex , Paraflocculus, granular layer , 6
# Orbital area , Cerebral cortex , Orbital area, lateral part, layer 1 , 8
# Hemispheric regions , Cerebellar cortex , Paraflocculus, molecular layer , 6
# Hemispheric regions , Cerebellar cortex , Flocculus, granular layer , 6
# Hemispheric regions , Cerebellar cortex , Flocculus, Purkinje layer , 6
# Hypothalamus , Interbrain , Median preoptic nucleus , 6
# Somatosensory areas , Cerebral cortex , Somatosensory areas , 6
# Retrohippocampal region , Cerebral cortex , Parasubiculum, layer 2 , 8
# Hypothalamus , Interbrain , Paraventricular hypothalamic nucleus, descending division, lateral parvicellular part , 7
# Retrohippocampal region , Cerebral cortex , Postsubiculum, layer 1 , 8
# Visual areas , Cerebral cortex , Visual areas, layer 6a , 7
# Striatum , Cerebral nuclei , Olfactory tubercle, molecular layer , 7
# lateral olfactory tract, general , olfactory nerve , accessory olfactory tract , 5
# Midbrain, sensory related , Midbrain , Midbrain trigeminal nucleus , 5
# Retrohippocampal region , Cerebral cortex , Presubiculum, layer 3 , 8
# Pons , Hindbrain , Superior salivatory nucleus , 6
# Hippocampal region , Cerebral cortex , Field CA3 , 8
# Hypothalamus , Interbrain , Paraventricular hypothalamic nucleus, descending division, medial parvicellular part, ventral zone , 7
# Striatum , Cerebral nuclei , Olfactory tubercle, pyramidal layer , 7
# Vermal regions , Cerebellar cortex , Lingula (I), Purkinje layer , 6
# Vermal regions , Cerebellar cortex , Lingula (I), molecular layer , 6
# Vermal regions , Cerebellar cortex , Lobule II, granular layer , 7
# Visual areas , Cerebral cortex , posteromedial visual area, layer 6b , 8
# Hypothalamus , Interbrain , Subthalamic nucleus , 6
# Vermal regions , Cerebellar cortex , Lobule III, granular layer , 7
# Striatum , Cerebral nuclei , Medial amygdalar nucleus, posterodorsal part, sublayer a , 8
# Striatum , Cerebral nuclei , Olfactory tubercle, polymorph layer , 7
# fornix system , cerebrum related , angular path , 5
# Thalamus , Interbrain , Medial geniculate complex , 7
# Orbital area , Cerebral cortex , Orbital area, layer 6a , 7
# Vermal regions , Cerebellar cortex , Lobule V, granular layer , 7
# Somatosensory areas , Cerebral cortex , Primary somatosensory area, lower limb, layer 6a , 9
# Vermal regions , Cerebellar cortex , Lobule V, molecular layer , 7
# Striatum , Cerebral nuclei , Medial amygdalar nucleus, posterodorsal part, sublayer b , 8
# Frontal pole, cerebral cortex , Cerebral cortex , Frontal pole, layer 6a , 7
# solitary tract , vagus nerve , solitary tract , 4
# Somatosensory areas , Cerebral cortex , Primary somatosensory area, layer 5 , 8
# Vermal regions , Cerebellar cortex , Lobule IV, molecular layer , 7
# Midbrain, sensory related , Midbrain , Nucleus of the brachium of the inferior colliculus , 5
# Pallidum , Cerebral nuclei , Triangular nucleus of septum , 6
# Pons , Hindbrain , Parabrachial nucleus, medial division, ventral medial part , 8
# Somatosensory areas , Cerebral cortex , Primary somatosensory area, unassigned, layer 1 , 9
# Thalamus , Interbrain , Dorsal part of the lateral geniculate complex, ipsilateral zone , 8
# Pallidum , Cerebral nuclei , Bed nuclei of the stria terminalis, posterior division, interfascicular nucleus , 8
# posterior superior fissure , posterior superior fissure , posterior superior fissure , 3
# Striatum , Cerebral nuclei , Medial amygdalar nucleus, posterodorsal part, sublayer c , 8
# Somatosensory areas , Cerebral cortex , Primary somatosensory area, unassigned, layer 2/3 , 9
# Hypothalamus , Interbrain , Medial mammillary nucleus , 7
# Vermal regions , Cerebellar cortex , Pyramus (VIII), Purkinje layer , 6
# Hemispheric regions , Cerebellar cortex , Paraflocculus, Purkinje layer , 6
# Retrohippocampal region , Cerebral cortex , Prosubiculum, dorsal part, pyramidal layer , 9
# Somatosensory areas , Cerebral cortex , Primary somatosensory area, unassigned, layer 4 , 9
# Visual areas , Cerebral cortex , Primary visual area, layer 2/3 , 8
# Anterior cingulate area , Cerebral cortex , Anterior cingulate area, dorsal part, layer 1 , 8
# Visual areas , Cerebral cortex , Visual areas, layer 5 , 7
# Pallidum , Cerebral nuclei , Bed nuclei of the stria terminalis , 6
# Vermal regions , Cerebellar cortex , Declive (VI), granular layer , 6
# Perirhinal area , Cerebral cortex , Perirhinal area, layer 5 , 7
# Somatosensory areas , Cerebral cortex , Primary somatosensory area, unassigned, layer 6a , 9
# Auditory areas , Cerebral cortex , Laterolateral anterior visual area, layer 1 , 9
# Auditory areas , Cerebral cortex , Dorsal auditory area, layer 2/3 , 8
# Somatosensory areas , Cerebral cortex , Primary somatosensory area, trunk, layer 6b , 9
# Somatosensory areas , Cerebral cortex , Primary somatosensory area, upper limb, layer 6a , 9
# Taenia tecta , Cerebral cortex , Taenia tecta, ventral part , 7
# Hypothalamus , Interbrain , Paraventricular hypothalamic nucleus, descending division, forniceal part , 7
# Hemispheric regions , Cerebellar cortex , Flocculus, molecular layer , 6
# Piriform-amygdalar area , Cerebral cortex , Piriform-amygdalar area , 6
# Midbrain, behavioral state related , Midbrain , Dorsal nucleus raphe , 6
# epithalamus related , hypothalamus related , habenular commissure , 5
# Orbital area , Cerebral cortex , Orbital area, lateral part, layer 6b , 8
# Hypothalamus , Interbrain , Anteroventral periventricular nucleus , 6
# Retrohippocampal region , Cerebral cortex , Parasubiculum, layer 1 , 8
# Vermal regions , Cerebellar cortex , Declive (VI), molecular layer , 6
# Visual areas , Cerebral cortex , Laterointermediate area, layer 2/3 , 8
# Thalamus , Interbrain , Mediodorsal nucleus of the thalamus, central part , 8
# fornix system , cerebrum related , postcommissural fornix , 5
# Retrohippocampal region , Cerebral cortex , Entorhinal area, medial part, dorsal zone, layer 6 , 9
# corticospinal tract , corticospinal tract , corticospinal tract , 3
# Retrosplenial area , Cerebral cortex , Retrosplenial area, dorsal part, layer 2/3 , 8
# spinotelenchephalic pathway , spinothalamic tract , spinotelenchephalic pathway , 4
# fornix system , cerebrum related , alveus , 5
# Auditory areas , Cerebral cortex , Laterolateral anterior visual area, layer 6b , 9
# Midbrain, motor related , Midbrain , Superior colliculus, motor related, intermediate gray layer, sublayer a , 7
# Auditory areas , Cerebral cortex , Ventral auditory area, layer 2/3 , 8
# Infralimbic area , Cerebral cortex , Infralimbic area, layer 1 , 7
# Somatosensory areas , Cerebral cortex , Rostrolateral lateral visual area , 9
# Posterior parietal association areas , Cerebral cortex , Anterior area, layer 1 , 8
# Posterior parietal association areas , Cerebral cortex , Anterior area, layer 2/3 , 8
# Posterior parietal association areas , Cerebral cortex , Anterior area, layer 4 , 8
# Posterior parietal association areas , Cerebral cortex , Anterior area, layer 5 , 8
# Retrohippocampal region , Cerebral cortex , Prosubiculum, ventral part , 8
# Somatosensory areas , Cerebral cortex , Rostrolateral lateral visual area, layer 6a , 10
# Somatosensory areas , Cerebral cortex , Rostrolateral lateral visual area, layer 6b , 10
# cochlear nerve , vestibulocochlear nerve , brachium of the inferior colliculus , 5
# Visual areas , Cerebral cortex , Laterointermediate area , 7
# Visual areas , Cerebral cortex , Laterointermediate area, layer 1 , 8
# Auditory areas , Cerebral cortex , Laterolateral anterior visual area, layer 2/3 , 9
# Visual areas , Cerebral cortex , Laterointermediate area, layer 4 , 8
# Auditory areas , Cerebral cortex , Laterolateral anterior visual area,layer 5 , 9
# Retrohippocampal region , Cerebral cortex , Postsubiculum, layer 3 , 8
# Auditory areas , Cerebral cortex , Laterolateral anterior visual area, layer 6a , 9
# Visual areas , Cerebral cortex , Laterointermediate area, layer 6b , 8
# Retrosplenial area , Cerebral cortex , Mediomedial anterior visual area , 8
# Posterior parietal association areas , Cerebral cortex , Rostrolateral area, layer 1 , 8
# Retrosplenial area , Cerebral cortex , Mediomedial anterior visual area, layer 1 , 9
# Posterior parietal association areas , Cerebral cortex , Rostrolateral area, layer 2/3 , 8
# Hippocampal region , Cerebral cortex , Dentate gyrus crest, molecular layer , 9
# Retrosplenial area , Cerebral cortex , Mediomedial anterior visual area, layer 2/3 , 9
# Posterior parietal association areas , Cerebral cortex , Rostrolateral area, layer 4 , 8
# Retrosplenial area , Cerebral cortex , Mediomedial anterior visual area, layer 4 , 9
# Posterior parietal association areas , Cerebral cortex , Rostrolateral area, layer 5 , 8
# Retrosplenial area , Cerebral cortex , Mediomedial anterior visual area,layer 5 , 9
# Posterior parietal association areas , Cerebral cortex , Rostrolateral area, layer 6a , 8
# Retrosplenial area , Cerebral cortex , Mediomedial anterior visual area, layer 6a , 9
# Posterior parietal association areas , Cerebral cortex , Rostrolateral area, layer 6b , 8
# Retrosplenial area , Cerebral cortex , Mediomedial anterior visual area, layer 6b , 9
# Visual areas , Cerebral cortex , Postrhinal area , 7
# Retrosplenial area , Cerebral cortex , Mediomedial posterior visual area , 8
# retina , retina , retina , 1
# Visual areas , Cerebral cortex , Postrhinal area, layer 1 , 8
# Midbrain, sensory related , Midbrain , Inferior colliculus, central nucleus , 6
# Retrosplenial area , Cerebral cortex , Mediomedial posterior visual area, layer 1 , 9
# Visual areas , Cerebral cortex , Postrhinal area, layer 2/3 , 8
# Retrosplenial area , Cerebral cortex , Mediomedial posterior visual area, layer 2/3 , 9
# Striatum , Cerebral nuclei , Lateral strip of striatum , 6
# Visual areas , Cerebral cortex , Postrhinal area, layer 4 , 8
# Retrosplenial area , Cerebral cortex , Mediomedial posterior visual area, layer 4 , 9
# Midbrain, motor related , Midbrain , Retroparafascicular nucleus , 6
# Visual areas , Cerebral cortex , Postrhinal area, layer 5 , 8
# Retrosplenial area , Cerebral cortex , Mediomedial posterior visual area,layer 5 , 9
# Midbrain, motor related , Midbrain , Intercollicular nucleus , 5
# Visual areas , Cerebral cortex , Postrhinal area, layer 6a , 8
# Retrosplenial area , Cerebral cortex , Mediomedial posterior visual area, layer 6a , 9
# Midbrain, motor related , Midbrain , Medial accesory oculomotor nucleus , 5
# Visual areas , Cerebral cortex , Postrhinal area, layer 6b , 8
# Retrosplenial area , Cerebral cortex , Mediomedial posterior visual area, layer 6b , 9
# Pons , Hindbrain , Peritrigeminal zone , 6
# Visual areas , Cerebral cortex , Laterointermediate area, layer 5 , 8
# Retrosplenial area , Cerebral cortex , Medial visual area , 8
# Pons , Hindbrain , Accessory trigeminal nucleus , 6
# Retrosplenial area , Cerebral cortex , Medial visual area, layer 1 , 9
# Pons , Hindbrain , Parvicellular motor 5 nucleus , 6
# Retrosplenial area , Cerebral cortex , Medial visual area, layer 2/3 , 9
# Pons , Hindbrain , Intertrigeminal nucleus , 6
# Retrosplenial area , Cerebral cortex , Medial visual area, layer 4 , 9
# Medulla , Hindbrain , Abducens nucleus , 6
# Retrosplenial area , Cerebral cortex , Medial visual area,layer 5 , 9
# Retrosplenial area , Cerebral cortex , Medial visual area, layer 6a , 9
# Retrosplenial area , Cerebral cortex , Medial visual area, layer 6b , 9
# Retrosplenial area , Cerebral cortex , Retrosplenial area, ventral part, layer 5 , 8
# Somatosensory areas , Cerebral cortex , Primary somatosensory area, mouth, layer 2/3 , 9
# Vermal regions , Cerebellar cortex , Lobule II, Purkinje layer , 7
# Hippocampal region , Cerebral cortex , Dentate gyrus, subgranular zone , 8
# corpus callosum, body , corpus callosum , corpus callosum, body , 4
# Vermal regions , Cerebellar cortex , Uvula (IX), Purkinje layer , 6
# Hippocampal region , Cerebral cortex , Dentate gyrus, molecular layer , 8
# Thalamus , Interbrain , Subparafascicular nucleus, parvicellular part , 7
# Visual areas , Cerebral cortex , Laterointermediate area, layer 6a , 8
# Cortical plate , Cerebral cortex , Cortical plate , 4
# Anterior cingulate area , Cerebral cortex , Anterior cingulate area, dorsal part, layer 5 , 8
# stria terminalis , cerebrum related , commissural branch of stria terminalis , 5
# Striatum , Cerebral nuclei , Septohippocampal nucleus , 6
# Retrohippocampal region , Cerebral cortex , Prosubiculum, ventral part, pyramidal layer , 9
# Thalamus , Interbrain , Ventral part of the lateral geniculate complex , 7
# Vermal regions , Cerebellar cortex , Lobules IV-V, granular layer , 7

# %%
subregion_id
# parent_id
# Out:
# ['Hypothalamus',
#  'Somatosensory areas',
#  'secondary fissure',
#  'Midbrain, sensory related',
#  'Hypothalamus',
#  'internal capsule',
#  'Pons',
#  'Basic cell groups and regions',
#  'Somatosensory areas',
#  'Midbrain, motor related',
#  'posterolateral fissure',
#  'Midbrain, behavioral state related',
#  'internal medullary lamina of the thalamus',
#  'Thalamus',
#  'Cortical subplate',
#  'Midbrain, motor related',
#  'nodular fissure',
#  'Hippocampal region',
#  'Retrohippocampal region',
#  'lateral olfactory tract, general',
#  'Posterior parietal association areas',
#  'Striatum',
#  'simple fissure',
#  'Midbrain, motor related',
#  'Thalamus',
#  'Retrohippocampal region',
#  'lateral spinothalamic tract',
#  'Hypothalamus',
#  'Anterior cingulate area',
#  'Visual areas',
#  'intercrural fissure',
#  'Midbrain, motor related',
#  'Gustatory areas',
#  'longitudinal association bundle',
#  'Hypothalamus',
#  'Anterior cingulate area',
#  'Visual areas',
#  'Midbrain, motor related',
#  'ansoparamedian fissure',
#  'Infralimbic area',
#  'Medulla',
#  'mammillary related',
#  'Hypothalamus',
#  'Anterior cingulate area',
#  'intraparafloccular fissure',
#  'Midbrain, motor related',
#  'Thalamus',
#  'Retrohippocampal region',
#  'Medulla',
#  'medial forebrain bundle',
#  'Hypothalamus',
#  'Striatum',
#  'paramedian sulcus',
#  'Midbrain, motor related',
#  'Thalamus',
#  'Retrohippocampal region',
#  'Medulla',
#  'medial longitudinal fascicle',
#  'Hypothalamus',
#  'Thalamus',
#  'parafloccular sulcus',
#  'Midbrain, motor related',
#  'Midbrain, motor related',
#  'Frontal pole, cerebral cortex',
#  'Medulla',
#  'midbrain related',
#  'Hypothalamus',
#  'Hypothalamus',
#  'ventricular systems',
#  'Visual areas',
#  'Midbrain, motor related',
#  'Medulla',
#  'Medulla',
#  'middle cerebellar peduncle',
#  'Hypothalamus',
#  'Hypothalamus',
#  'lateral ventricle',
#  'Pons',
#  'Medulla',
#  'Prelimbic area',
#  'superior cerebelar peduncles',
#  'middle thalamic commissure',
#  'Hypothalamus',
#  'Hypothalamus',
#  'rhinocele',
#  'Pons',
#  'Interposed nucleus',
#  'Retrohippocampal region',
#  'motor root of the trigeminal nerve',
#  'Hypothalamus',
#  'Agranular insular area',
#  'Medulla',
#  'Temporal association areas',
#  'subependymal zone',
#  'Pons',
#  'Midbrain, behavioral state related',
#  'Medulla',
#  'nigrostriatal tract',
#  'Hypothalamus',
#  'Agranular insular area',
#  'Pons',
#  'Medulla',
#  'Somatomotor areas',
#  'choroid plexus',
#  'nigrothalamic fibers',
#  'Hypothalamus',
#  'Agranular insular area',
#  'Medulla',
#  'Somatosensory areas',
#  'Pons',
#  'Midbrain, motor related',
#  'choroid fissure',
#  'optic chiasm',
#  'Hypothalamus',
#  'Agranular insular area',
#  'Agranular insular area',
#  'Visual areas',
#  'Pons',
#  'Pons',
#  'interventricular foramen',
#  'optic tract',
#  'Hypothalamus',
#  'Thalamus',
#  'Midbrain, motor related',
#  'third ventricle',
#  'Pons',
#  'Cortical subplate',
#  'Prelimbic area',
#  'Hypothalamus',
#  'pallidotegmental fascicle',
#  'Somatosensory areas',
#  'Medulla',
#  'Pons',
#  'Thalamus',
#  'Retrohippocampal region',
#  'cerebral aqueduct',
#  'Hypothalamus',
#  'pallidothalmic pathway',
#  'Medulla',
#  'Striatum',
#  'fourth ventricle',
#  'Pons',
#  'Somatosensory areas',
#  'Gustatory areas',
#  'Thalamus',
#  'periventricular bundle of the hypothalamus',
#  'Accessory olfactory bulb',
#  'Piriform area',
#  'lateral recess',
#  'Medulla',
#  'Thalamus',
#  'Auditory areas',
#  'Hypothalamus',
#  'posterior commissure',
#  'Thalamus',
#  'Anterior olfactory nucleus',
#  'Medulla',
#  'Pons',
#  'Agranular insular area',
#  'central canal, spinal cord/medulla',
#  'Midbrain, behavioral state related',
#  'premammillary commissure',
#  'Anterior olfactory nucleus',
#  'Anterior olfactory nucleus',
#  'Medulla',
#  'Thalamus',
#  'Prelimbic area',
#  'Hypothalamus',
#  'preoptic commissure',
#  'Anterior olfactory nucleus',
#  'Medulla',
#  'Orbital area',
#  'Anterior cingulate area',
#  'Gustatory areas',
#  'Thalamus',
#  'propriohypothalamic pathways',
#  'Anterior olfactory nucleus',
#  'Frontal pole, cerebral cortex',
#  'Medulla',
#  'Posterior parietal association areas',
#  'Gustatory areas',
#  'Accessory olfactory bulb',
#  'Thalamus',
#  'pyramid',
#  'Anterior olfactory nucleus',
#  'Cortical amygdalar area',
#  'Medulla',
#  'Vermal regions',
#  'Prelimbic area',
#  'Accessory olfactory bulb',
#  'Midbrain, behavioral state related',
#  'pyramidal decussation',
#  'Anterior olfactory nucleus',
#  'Cortical amygdalar area',
#  'Somatosensory areas',
#  'Medulla',
#  'Medulla',
#  'Accessory olfactory bulb',
#  'retriculospinal tract, lateral part',
#  'Medulla',
#  'Medulla',
#  'Cortical amygdalar area',
#  'Medulla',
#  'Hypothalamus',
#  'Anterior cingulate area',
#  'Main olfactory bulb',
#  'retriculospinal tract, medial part',
#  'Midbrain, motor related',
#  'Midbrain, motor related',
#  'Cortical amygdalar area',
#  'Medulla',
#  'Thalamus',
#  'Somatomotor areas',
#  'Main olfactory bulb',
#  'rubroreticular tract',
#  'Medulla',
#  'Hypothalamus',
#  'Cortical amygdalar area',
#  'Medulla',
#  'Hypothalamus',
#  'Anterior cingulate area',
#  'Main olfactory bulb',
#  'sensory root of the trigeminal nerve',
#  'Medulla',
#  'Midbrain, motor related',
#  'Cortical amygdalar area',
#  'Visual areas',
#  'Temporal association areas',
#  'Medulla',
#  'Main olfactory bulb',
#  'Posterior parietal association areas',
#  'Pons',
#  'Thalamus',
#  'Cortical amygdalar area',
#  'Posterior parietal association areas',
#  'Striatum',
#  'Auditory areas',
#  'Main olfactory bulb',
#  'spinocervical tract',
#  'Midbrain, motor related',
#  'Auditory areas',
#  'Cortical amygdalar area',
#  'Auditory areas',
#  'Striatum',
#  'Auditory areas',
#  'Auditory areas',
#  'spinohypothalamic pathway',
#  'Retrosplenial area',
#  'Thalamus',
#  'Cortical amygdalar area',
#  'Visual areas',
#  'Striatum',
#  'Retrohippocampal region',
#  'Nucleus of the lateral olfactory tract',
#  'spino-olivary pathway',
#  'Thalamus',
#  'Hypothalamus',
#  'Orbital area',
#  'Hippocampal region',
#  'Striatum',
#  'Dorsal peduncular area',
#  'Nucleus of the lateral olfactory tract',
#  'Visual areas',
#  'spinoreticular pathway',
#  'Midbrain, sensory related',
#  'Somatosensory areas',
#  'Retrosplenial area',
#  'Striatum',
#  'Piriform area',
#  'spinotectal pathway',
#  'Striatum',
#  'Retrosplenial area',
#  'Pons',
#  'Visual areas',
#  'Pons',
#  'Piriform area',
#  'Somatosensory areas',
#  'Hypothalamus',
#  'Pallidum',
#  'Orbital area',
#  'Temporal association areas',
#  'Hypothalamus',
#  'Piriform area',
#  'Striatum',
#  'spinovestibular pathway',
#  'Midbrain, motor related',
#  'Cortical subplate',
#  'Anterior cingulate area',
#  'Taenia tecta',
#  'Pallidum',
#  'Somatomotor areas',
#  'Thalamus',
#  'stria terminalis',
#  'Midbrain, sensory related',
#  'Basolateral amygdalar nucleus, anterior part',
#  'Prelimbic area',
#  'Visual areas',
#  'Taenia tecta',
#  'Medulla',
#  'Posterior parietal association areas',
#  'striatonigral pathway',
#  'Striatum',
#  'Basolateral amygdalar nucleus, posterior part',
#  'Retrohippocampal region',
#  'Midbrain',
#  'Agranular insular area',
#  'Cortical plate',
#  'Thalamus',
#  'subthalamic fascicle',
#  'Pons',
#  'Cortical subplate',
#  'Somatomotor areas',
#  'Thalamus',
#  'Somatosensory areas',
#  'Midbrain, motor related',
#  'Retrohippocampal region',
#  'Thalamus',
#  'superior cerebelar peduncles',
#  'Basomedial amygdalar nucleus, anterior part',
#  'Agranular insular area',
#  'Somatosensory areas',
#  'Retrosplenial area',
#  'Hypothalamus',
#  'Hypothalamus',
#  'Somatosensory areas',
#  'Basomedial amygdalar nucleus, posterior part',
#  'Perirhinal area',
#  'superior colliculus commissure',
#  'Somatosensory areas',
#  'Hypothalamus',
#  'Midbrain, sensory related',
#  'Posterior parietal association areas',
#  'supramammillary decussation',
#  'Pallidum',
#  'Brain stem',
#  'Agranular insular area',
#  'Somatosensory areas',
#  'Somatosensory areas',
#  'Hypothalamus',
#  'Midbrain, behavioral state related',
#  'supraoptic commissures',
#  'Pons',
#  'Striatum',
#  'Orbital area',
#  'Somatosensory areas',
#  'Medulla',
#  'Agranular insular area',
#  'Hypothalamus',
#  'tectothalamic pathway',
#  'Pons',
#  'Pallidum',
#  'Dorsal peduncular area',
#  'Somatosensory areas',
#  'Thalamus',
#  'Prelimbic area',
#  'Hypothalamus',
#  'thalamic peduncles',
#  'Thalamus',
#  'Pallidum',
#  'Perirhinal area',
#  'Somatosensory areas',
#  'Medulla',
#  'Retrohippocampal region',
#  'Medulla',
#  'trigeminocerebellar tract',
#  'Midbrain, behavioral state related',
#  'Hippocampal region',
#  'Cortical amygdalar area',
#  'Visual areas',
#  'Somatosensory areas',
#  'Medulla',
#  'cervicothalamic tract',
#  'Posterior parietal association areas',
#  'Hippocampal region',
#  'Cortical amygdalar area',
#  'trochlear nerve decussation',
#  'Visual areas',
#  'Medulla',
#  'Retrohippocampal region',
#  'cervicothalamic tract',
#  'ventral spinothalamic tract',
#  'Hypothalamus',
#  'Hippocampal region',
#  'Nucleus of the lateral olfactory tract',
#  'Visual areas',
#  'Visual areas',
#  'Medulla',
#  'cervicothalamic tract',
#  'ventral tegmental decussation',
#  'Pons',
#  'Hippocampal region',
#  'Piriform-amygdalar area',
#  'Visual areas',
#  'Visual areas',
#  'Striatum',
#  'inferior cerebellar peduncle',
#  'ventrolateral hypothalamic tract',
#  'Thalamus',
#  'Hippocampal region',
#  'Piriform-amygdalar area',
#  'Visual areas',
#  'Hypothalamus',
#  'Striatum',
#  'Orbital area',
#  'inferior cerebellar peduncle',
#  'Thalamus',
#  'Hippocampal region',
#  'Somatosensory areas',
#  'Posterior parietal association areas',
#  'Striatum',
#  'Retrohippocampal region',
#  'fornix system',
#  'Visual areas',
#  'Orbital area',
#  'Hippocampal region',
#  'Piriform-amygdalar area',
#  'Visual areas',
#  'Striatum',
#  'Ectorhinal area',
#  'fornix system',
#  'Medulla',
#  'Retrosplenial area',
#  'vestibular nerve',
#  'Hemispheric regions',
#  'Visual areas',
#  'Hemispheric regions',
#  'Striatum',
#  'Hemispheric regions',
#  'Medulla',
#  'Hemispheric regions',
#  'Hemispheric regions',
#  'Orbital area',
#  'Visual areas',
#  'Hemispheric regions',
#  'fornix system',
#  'Thalamus',
#  'Hemispheric regions',
#  'Hippocampal region',
#  'Hemispheric regions',
#  'Orbital area',
#  'Hemispheric regions',
#  'Hemispheric regions',
#  'Hemispheric regions',
#  'Hypothalamus',
#  'Somatosensory areas',
#  'Retrohippocampal region',
#  'Hypothalamus',
#  'Retrohippocampal region',
#  'Visual areas',
#  'Striatum',
#  'lateral olfactory tract, general',
#  'Midbrain, sensory related',
#  'Retrohippocampal region',
#  'Pons',
#  'Hippocampal region',
#  'Hypothalamus',
#  'Striatum',
#  'Vermal regions',
#  'Vermal regions',
#  'Vermal regions',
#  'Visual areas',
#  'Hypothalamus',
#  'Vermal regions',
#  'Striatum',
#  'Striatum',
#  'fornix system',
#  'Thalamus',
#  'Orbital area',
#  'Vermal regions',
#  'Somatosensory areas',
#  'Vermal regions',
#  'Striatum',
#  'Vermal regions',
#  'Vermal regions',
#  'Thalamus',
#  'Orbital area',
#  'Striatum',
#  'Vermal regions',
#  'Vermal regions',
#  'Vermal regions',
#  'Striatum',
#  'inferior cerebellar peduncle',
#  'Vermal regions',
#  'Vermal regions',
#  'Striatum',
#  'Vermal regions',
#  'Hippocampal region',
#  'Vermal regions',
#  'Vermal regions',
#  'Pallidum',
#  'inferior cerebellar peduncle',
#  'Somatomotor areas',
#  'Visual areas',
#  'Retrohippocampal region',
#  'Midbrain, motor related',
#  'Hippocampal region',
#  'Pallidum',
#  'cochlear nerve',
#  'Main olfactory bulb',
#  'Retrohippocampal region',
#  'Retrohippocampal region',
#  'Somatosensory areas',
#  'Midbrain, motor related',
#  'Cerebellum',
#  'Pallidum',
#  'cervicothalamic tract',
#  'Hypothalamus',
#  'Orbital area',
#  'Postpiriform transition area',
#  'Retrohippocampal region',
#  'Cerebellar nuclei',
#  'Auditory areas',
#  'Pallidum',
#  'cervicothalamic tract',
#  'Hypothalamus',
#  'Orbital area',
#  'Hypothalamus',
#  'Retrohippocampal region',
#  'Auditory areas',
#  'Cerebellar cortex',
#  'Pallidum',
#  'fornix system',
#  'Midbrain, motor related',
#  'Posterior parietal association areas',
#  'Visual areas',
#  'Pons',
#  'Dorsal peduncular area',
#  'Striatum',
#  'Pallidum',
#  'lateral olfactory tract, general',
#  'Midbrain, motor related',
#  'Perirhinal area',
#  'Temporal association areas',
#  'Retrosplenial area',
#  'Retrohippocampal region',
#  'Striatum',
#  'Retrosplenial area',
#  'Pallidum',
#  'midbrain related',
#  'Midbrain, motor related',
#  'Thalamus',
#  'Retrohippocampal region',
#  'Hemispheric regions',
#  'Pons',
#  'inferior cerebellar peduncle',
#  'Pallidum',
#  'Midbrain, motor related',
#  'Infralimbic area',
#  'Hypothalamus',
#  'Somatosensory areas',
#  'Striatum',
#  'Medulla',
#  'corpus callosum',
#  'Pallidum',
#  'midbrain related',
#  'Pallidum',
#  'Dorsal peduncular area',
#  'Postpiriform transition area',
#  'Cerebrum',
#  'Medulla',
#  'fornix system',
#  'cervicothalamic tract',
#  'Thalamus',
#  'Anterior cingulate area',
#  'Visual areas',
#  'Pons',
#  'Thalamus',
#  'Thalamus',
#  'Somatosensory areas',
#  'Pallidum',
#  'corpus callosum, anterior forceps',
#  'Thalamus',
#  'Hippocampal region',
#  'Orbital area',
#  'Cortical subplate',
#  'Cortical amygdalar area',
#  'Retrohippocampal region',
#  'cervicothalamic tract',
#  'Midbrain, motor related',
#  'Anterior cingulate area',
#  'Taenia tecta',
#  'Retrosplenial area',
#  'Midbrain, behavioral state related',
#  'Cortical amygdalar area',
#  'Visual areas',
#  'Pallidum',
#  'epithalamus related',
#  'Pallidum',
#  'Taenia tecta',
#  'Auditory areas',
#  'Thalamus',
#  'Frontal pole, cerebral cortex',
#  'Visual areas',
#  'Pallidum',
#  'fornix system',
#  'Pons',
#  'Retrosplenial area',
#  'Retrosplenial area',
#  'Medulla',
#  'Orbital area',
#  'Thalamus',
#  'Retrosplenial area',
#  'Hemispheric regions',
#  'Pons',
#  'Visual areas',
#  'Hypothalamus',
#  'Midbrain, motor related',
#  'Midbrain, motor related',
#  'Hemispheric regions',
#  'fornix system',
#  'Nucleus of the lateral olfactory tract',
#  'Orbital area',
#  'Pons',
#  'Retrosplenial area',
#  'Cerebral nuclei',
#  'Interpeduncular fossa',
#  'Somatosensory areas',
#  'Thalamus',
#  'spinotelenchephalic pathway',
#  'Midbrain, motor related',
#  'Thalamus',
#  'Orbital area',
#  'Cortical amygdalar area',
#  'Hippocampal region',
#  'cochlear nerve',
#  'Midbrain, motor related',
#  'Posterior parietal association areas',
#  'Thalamus',
#  'Thalamus',
#  'Gustatory areas',
#  'Cortical amygdalar area',
#  'Medulla',
#  'cochlear nerve',
#  'Medulla',
#  'Auditory areas',
#  'Somatomotor areas',
#  'Vermal regions',
#  'Dorsal peduncular area',
#  'Cortical amygdalar area',
#  'Somatomotor areas',
#  'Visual areas',
#  'inferior cerebellar peduncle',
#  'Medulla',
#  'Hypothalamus',
#  'Somatosensory areas',
#  'Somatosensory areas',
#  'Cortical amygdalar area',
#  'Somatomotor areas',
#  'dorsal roots',
#  'cochlear nerve',
#  'Medulla',
#  'Hypothalamus',
#  'Medulla',
#  'Gustatory areas',
#  'Cortical amygdalar area',
#  'Retrohippocampal region',
#  'lateral olfactory tract, general',
#  'Medulla',
#  'Frontal pole, cerebral cortex',
#  'Hypothalamus',
#  'Visual areas',
#  'Somatosensory areas',
#  'Retrosplenial area',
#  'Striatum',
#  'mammillary related',
#  'Medulla',
#  'Agranular insular area',
#  'Hypothalamus',
#  'Visceral area',
#  'Auditory areas',
#  'Pons',
#  'Orbital area',
#  'mammillary related',
#  'Medulla',
#  'Retrohippocampal region',
#  'Hypothalamus',
#  'Thalamus',
#  'Somatosensory areas',
#  'Hypothalamus',
#  'Cerebral cortex',
#  'Auditory areas',
#  'mammillary related',
#  'Medulla',
#  'Medulla',
#  'Hypothalamus',
#  'Agranular insular area',
#  'Retrohippocampal region',
#  'Auditory areas',
#  'cervicothalamic tract',
#  'Cortical plate',
#  'Agranular insular area',
#  'Hypothalamus',
#  'Medulla',
#  'Somatosensory areas',
#  'Cortical subplate',
#  'Agranular insular area',
#  'sensory root of the trigeminal nerve',
#  'Midbrain, motor related',
#  'Retrohippocampal region',
#  'Somatosensory areas',
#  'Somatosensory areas',
#  'abducens nerve',
#  'Medulla',
#  'Retrohippocampal region',
#  'fornix system',
#  'Orbital area',
#  'Retrohippocampal region',
#  'Hypothalamus',
#  'accessory spinal nerve',
#  'Thalamus',
#  'Somatosensory areas',
#  'Medulla',
#  'Visual areas',
#  'dorsal thalamus related',
#  'Orbital area',
#  'Hypothalamus',
#  'Thalamus',
#  'Hippocampal region',
#  'Retrohippocampal region',
#  'arbor vitae',
#  'Temporal association areas',
#  'epithalamus related',
#  'Orbital area',
#  'Hypothalamus',
#  'Thalamus',
#  'Hippocampal region',
#  'Auditory areas',
#  'central tegmental bundle',
#  'Hippocampal region',
#  'Orbital area',
#  'Anterior cingulate area',
#  'Hypothalamus',
#  'Thalamus',
#  'Retrohippocampal region',
#  'Vermal regions',
#  'cerebellar commissure',
#  'fornix system',
#  'Orbital area',
#  'Infralimbic area',
#  'Hypothalamus',
#  'Midbrain, motor related',
#  'Visual areas',
#  'Hippocampal region',
#  'cerebellar peduncles',
#  'mammillary related',
#  'Striatum',
#  'Hypothalamus',
#  'Hypothalamus',
#  'Midbrain, motor related',
#  'Hippocampal region',
#  'Retrohippocampal region',
#  'cerebral nuclei related',
#  'Hypothalamus',
#  'propriohypothalamic pathways',
#  'Hypothalamus',
#  'Retrohippocampal region',
#  'Medulla',
#  'Hippocampal region',
#  'Somatomotor areas',
#  'Retrohippocampal region',
#  'Hypothalamus',
#  'propriohypothalamic pathways',
#  'Pons',
#  'Anterior cingulate area',
#  'Auditory areas',
#  'Retrosplenial area',
#  'Hippocampal region',
#  'Retrohippocampal region',
#  'Hypothalamus',
#  'Visual areas',
#  'Hippocampal region',
#  'Cortical subplate',
#  'Medulla',
#  'Hippocampal region',
#  'Agranular insular area',
#  'supra-callosal cerebral white matter',
#  'Hypothalamus',
#  'Temporal association areas',
#  'propriohypothalamic pathways',
#  'Hypothalamus',
#  'Medulla',
#  'Hippocampal region',
#  'Auditory areas',
#  'optic radiation',
#  'Somatosensory areas',
#  'sensory root of the trigeminal nerve',
#  'Hippocampal region',
#  'auditory radiation',
#  'Vermal regions',
#  'facial nerve',
#  'Hippocampal region',
#  'Agranular insular area',
#  'Visual areas',
#  'epithalamus related',
#  'Pallidum',
#  'Hypothalamus',
#  'Visual areas',
#  'Somatosensory areas',
#  'Hippocampal region',
#  'glossopharyngeal nerve',
#  'Pallidum',
#  'Anterior cingulate area',
#  'Medulla',
#  'superior cerebelar peduncles',
#  'hypoglossal nerve',
#  'Dorsal peduncular area',
#  'Striatum',
#  'Auditory areas',
#  'supraoptic commissures',
#  'Pallidum',
#  'Anterior cingulate area',
#  'Midbrain, sensory related',
#  'Vermal regions',
#  'Retrohippocampal region',
#  'Hippocampal region',
#  'hypothalamus related',
#  'supraoptic commissures',
#  'Pallidum',
#  'Infralimbic area',
#  'Midbrain, sensory related',
#  'Retrohippocampal region',
#  'Hypothalamus',
#  'Agranular insular area',
#  'oculomotor nerve',
#  'supraoptic commissures',
#  'Midbrain, sensory related',
#  'Pallidum',
#  'Ectorhinal area',
#  'Retrohippocampal region',
#  'Somatosensory areas',
#  'Medulla',
#  'olfactory nerve',
#  'cochlear nerve',
#  'Midbrain, sensory related',
#  'Retrohippocampal region',
#  'Somatomotor areas',
#  'Retrohippocampal region',
#  'Dentate nucleus',
#  'Auditory areas',
#  'optic nerve',
#  'Visceral area',
#  'superior cerebelar peduncles',
#  'Midbrain, sensory related',
#  'Medulla',
#  'Retrohippocampal region',
#  'Somatosensory areas',
#  'retriculospinal tract',
#  'Thalamus',
#  'Visceral area',
#  'cervicothalamic tract',
#  'Medulla',
#  'Pons',
#  'Retrohippocampal region',
#  'Somatosensory areas',
#  'rubrospinal tract',
#  'Thalamus',
#  'Somatosensory areas',
#  'superior cerebelar peduncles',
#  'Pons',
#  'Pons',
#  'Visual areas',
#  'Retrohippocampal region',
#  'spinothalamic tract',
#  'propriohypothalamic pathways',
#  'Somatosensory areas',
#  'Midbrain, sensory related',
#  'Pons',
#  'accessory optic tract',
#  'tectospinal pathway',
#  'Somatosensory areas',
#  'Retrosplenial area',
#  'Pons',
#  'Pons',
#  'Somatomotor areas',
#  'Pons',
#  'amygdalar capsule',
#  'terminal nerve',
#  'Retrosplenial area',
#  'Medulla',
#  'Perirhinal area',
#  'Somatosensory areas',
#  'Pons',
#  'Pons',
#  'ansa peduncularis',
#  'Somatosensory areas',
#  'Retrosplenial area',
#  'Ectorhinal area',
#  'thalamus related',
#  'Visceral area',
#  'Pons',
#  'Pons',
#  'anterior commissure, olfactory limb',
#  'trigeminal nerve',
#  'Visual areas',
#  'Medulla',
#  'Pallidum',
#  'Visual areas',
#  'Retrosplenial area',
#  'Thalamus',
#  'anterior commissure, temporal limb',
#  'Retrohippocampal region',
#  'Orbital area',
#  'trochlear nerve',
#  'Vermal regions',
#  'Visual areas',
#  'Hypothalamus',
#  'Pons',
#  'brachium of the superior colliculus',
#  'vagus nerve',
#  'Retrohippocampal region',
#  'Anterior cingulate area',
#  'Vermal regions',
#  'Somatosensory areas',
#  'Perirhinal area',
#  'Vermal regions',
#  'cerebal peduncle',
#  'ventral roots',
#  'Retrohippocampal region',
#  'Anterior cingulate area',
#  'Vermal regions',
#  'Somatosensory areas',
#  'Thalamus',
#  'Pons',
#  'cervicothalamic tract',
#  'vestibulocochlear nerve',
#  'Retrohippocampal region',
#  'Visual areas',
#  'Vermal regions',
#  'Somatosensory areas',
#  'Medulla',
#  'Medulla',
#  'cingulum bundle',
#  'vestibulospinal pathway',
#  'Cortical subplate',
#  'Somatomotor areas',
#  'Vermal regions',
#  'Somatosensory areas',
#  'Hypothalamus',
#  'Somatomotor areas',
#  'cochlear nerve',
#  'vomeronasal nerve',
#  'Somatosensory areas',
#  'Vermal regions',
#  'Endopiriform nucleus, dorsal part',
#  'Thalamus',
#  'Auditory areas',
#  'Medulla',
#  'corpus callosum, anterior forceps',
#  'Vermal regions',
#  'Thalamus',
#  'Auditory areas',
#  'cerebellum related fiber tracts',
#  'Piriform area',
#  'Somatomotor areas',
#  'Medulla',
#  'corpus callosum, extreme capsule',
#  'Retrosplenial area',
#  'Endopiriform nucleus, ventral part',
#  'cranial nerves',
#  'Vermal regions',
#  'Orbital area',
#  'Medulla',
#  'corpus callosum, posterior forceps',
#  'Prelimbic area',
#  'Visual areas',
#  'Somatosensory areas',
#  'Midbrain, motor related',
#  'Vermal regions',
#  'Ectorhinal area',
#  'Medulla',
#  'corpus callosum, rostrum',
#  'Hypothalamus',
#  'Somatosensory areas',
#  'Hippocampal region',
#  'lateral forebrain bundle system',
#  'Vermal regions',
#  'Somatomotor areas',
#  'corpus callosum, splenium',
#  'Pons',
#  'Ectorhinal area',
#  'Fastigial nucleus',
#  'Auditory areas',
#  'medial forebrain bundle system',
#  'Vermal regions',
#  'Somatomotor areas',
#  'corticobulbar tract',
#  'Medulla',
#  'Agranular insular area',
#  'root',
#  'Striatum',
#  'Retrohippocampal region',
#  'extrapyramidal fiber systems',
#  'Vermal regions',
#  'Auditory areas',
#  'corticopontine tract',
#  'Hypothalamus',
#  'Auditory areas',
#  'Somatosensory areas',
#  'Hemispheric regions',
#  'Thalamus',
#  ...]

# %%
# Save data and labels into matlab formats
import scipy.io as sio
sio.savemat('allen_names.mat',{'allen_names':region_names})
sio.savemat('allen_depth.mat',{'allen_depths':region_depth})
sio.savemat('allen_CC.mat',{'allen_cc':corr.data})
sio.savemat('allen_expression.mat',{'allen_expression':expression})
sio.savemat('allIds.mat',{'allIds':allIds})

sio.savemat('allen_colours.mat',{'allen_colours':region_colours})
sio.savemat('allen_leafnodes.mat',{'allen_leafnodes':leaf_nodes})

sio.savemat('allen_parents.mat',{'allen_parents':parent_id})
sio.savemat('allen_subregion.mat',{'allen_subregion':subregion_id})

# %% [markdown]
# ### Some code for looking at slices of the data

# %%
# pandas version of the structure dataset for prettier printing of data rows
structDF = pd.DataFrame.from_dict(structHash,orient='index')

# %%
# Find the Zona Incerta
structDF[structDF.acronym == 'ZI']
# Out:
#     color_hex_triplet  parent_structure_id  ontology_id  weight acronym  \
# 797            F2483B                290.0            1    8690      ZI
#
#      sphinx_id failed  structure_name_facet  atlas_id  depth      ...       \
# 797        790  False            3420252476     382.0      6      ...
#
#         safe_name  graph_id num_children  neuro_name_structure_id  \
# 797  Zona incerta         1            2                     None
#
#      graph_order neuro_name_structure_id_path  \
# 797          789                         None
#
#                        structure_id_path st_level failed_facet          name
# 797  [997, 8, 343, 1129, 1097, 290, 797]      NaN    734881840  Zona incerta
#
# [1 rows x 22 columns]

# %%
# Find the direct children of ZI
structDF[structDF.parent_structure_id == 797]
# Out:
#     color_hex_triplet  parent_structure_id  ontology_id  weight acronym  \
# 796            F2483B                797.0            1    8690     A13
# 804            F2483B                797.0            1    8690      FF
#
#      sphinx_id failed  structure_name_facet  atlas_id  depth  \
# 796        791  False            4064653384     806.0      7
# 804        792  False              89343914     807.0      7
#
#               ...                         safe_name  graph_id num_children  \
# 796           ...            Dopaminergic A13 group         1            0
# 804           ...                   Fields of Forel         1            0
#
#      neuro_name_structure_id  graph_order neuro_name_structure_id_path  \
# 796                     None          790                         None
# 804                     None          791                         None
#
#                             structure_id_path st_level failed_facet  \
# 796  [997, 8, 343, 1129, 1097, 290, 797, 796]      NaN    734881840
# 804  [997, 8, 343, 1129, 1097, 290, 797, 804]      NaN    734881840
#
#                        name
# 796  Dopaminergic A13 group
# 804         Fields of Forel
#
# [2 rows x 22 columns]

# %%
# List structure id path e.g. for ZI
structHash[797]['structure_id_path']
# structHash[688]['name']
# Out:
# [997, 8, 343, 1129, 1097, 290, 797]

# %%
# Print whole structure id path for a given region
# ZI: 797. 688: Cerebral cortex. 2: low level structure in S1
for p in structHash[797]['structure_id_path']:
    print(p,':',structHash[p]['name'])
# Out:
# 997 : root
# 8 : Basic cell groups and regions
# 343 : Brain stem
# 1129 : Interbrain
# 1097 : Hypothalamus
# 290 : Hypothalamic lateral zone
# 797 : Zona incerta

# %% [markdown]
# ## Load gene dataset list, save gene labels + names

# %%
# load gene dataset list with pandas
gene_list = pd.read_csv('/home/mathew/work/NetworkNoiseRejection/Networks/Allen_mouse_brain_atlas/mouse_expression_data_sets.csv')
gene_list.head()
# Out:
#    data_set_id  gene_id gene_symbol  \
# 0            3    43669      Snap47
# 1            5    43302         Nvl
# 2            6    43302         Nvl
# 3            7    47593      Gtf3c2
# 4            8    47593      Gtf3c2
#
#                                            gene_name probe_id  \
# 0                synaptosomal-associated protein, 47     6907
# 1                                   nuclear VCP-like   253948
# 2                                   nuclear VCP-like   253948
# 3  general transcription factor IIIC, polypeptide...   103279
# 4  general transcription factor IIIC, polypeptide...   103279
#
#          probe_name orientation plane_of_section  \
# 0  RP_040324_01_E07   Antisense          coronal
# 1  RP_Baylor_253948   Antisense          coronal
# 2  RP_Baylor_253948   Antisense         sagittal
# 3  RP_Baylor_103279   Antisense          coronal
# 4  RP_Baylor_103279   Antisense         sagittal
#
#                                        grid_file_url  \
# 0  http://download.alleninstitute.org/informatics...
# 1  http://download.alleninstitute.org/informatics...
# 2  http://download.alleninstitute.org/informatics...
# 3  http://download.alleninstitute.org/informatics...
# 4  http://download.alleninstitute.org/informatics...
#
#                         structure_unionizes_file_url Unnamed: 10 Unnamed: 11  \
# 0  http://download.alleninstitute.org/informatics...         NaN         NaN
# 1  http://download.alleninstitute.org/informatics...         NaN         NaN
# 2  http://download.alleninstitute.org/informatics...         NaN         NaN
# 3  http://download.alleninstitute.org/informatics...         NaN         NaN
# 4  http://download.alleninstitute.org/informatics...         NaN         NaN
#
#   Unnamed: 12 Unnamed: 13 Unnamed: 14
# 0         NaN         NaN         NaN
# 1         NaN         NaN         NaN
# 2         NaN         NaN         NaN
# 3         NaN         NaN         NaN
# 4         NaN         NaN         NaN

# %%
# for all datasets in my_union, work out the gene symbol and it's name
gene_name = []
gene_desc = []
for i, x in enumerate(didHash):
    g = gene_list[gene_list.data_set_id == my_union[i][0]['section_data_set_id']].gene_symbol.values
    n = gene_list[gene_list.data_set_id == my_union[i][0]['section_data_set_id']].gene_name.values
    print(g,n)
    gene_name.append(g)
    gene_desc.append(n)
# Out:
# ['Pltp'] ['phospholipid transfer protein']
# ['Gm626'] ['predicted gene 626']
# ['Rasal1'] ['RAS protein activator like 1 (GAP1 like)']
# ['St8sia6'] ['ST8 alpha-N-acetyl-neuraminide alpha-2,8-sialyltransferase 6']
# ['Tsc22d2'] ['TSC22 domain family, member 2']
# ['Mlx'] ['MAX-like protein X']
# ['Kit'] ['kit oncogene']
# ['Rasl11a'] ['RAS-like, family 11, member A']
# ['Doc2b'] ['double C2, beta']
# ['Pip5k1c'] ['phosphatidylinositol-4-phosphate 5-kinase, type 1 gamma']
# ['BC034076'] ['cDNA sequence BC034076']
# ['Tmem215'] ['transmembrane protein 215']
# ['Oprk1'] ['opioid receptor, kappa 1']
# ['Kctd6'] ['potassium channel tetramerisation domain containing 6']
# ['Calb2'] ['calbindin 2']
# ['Apbb3'] ['amyloid beta (A4) precursor protein-binding, family B, member 3']
# ['Igfn1'] ['immunoglobulin-like and fibronectin type III domain containing 1']
# ['Acsl5'] ['acyl-CoA synthetase long-chain family member 5']
# ['Wnt7b'] ['wingless-related MMTV integration site 7B']
# ['Doc2a'] ['double C2, alpha']
# ['Anxa3'] ['annexin A3']
# ['Cdk8'] ['cyclin-dependent kinase 8']
# ['Sphkap'] ['SPHK1 interactor, AKAP domain containing']
# ['Otof'] ['otoferlin']
# ['Tmem91'] ['transmembrane protein 91']
# ['Gpr4'] ['G protein-coupled receptor 4']
# ['Ppp2r5b'] ['protein phosphatase 2, regulatory subunit B (B56), beta isoform']
# ['A830036E02Rik'] ['RIKEN cDNA A830036E02 gene']
# ['Tspan11'] ['tetraspanin 11']
# ['Egr3'] ['early growth response 3']
# ['Dlk1'] ['delta-like 1 homolog (Drosophila)']
# ['Fam5b'] ['family with sequence similarity 5, member B']
# ['C130018E23Rik*'] ['RIKEN cDNA C130018E23 gene (non-RefSeq)']
# ['Atp1a3'] ['ATPase, Na+/K+ transporting, alpha 3 polypeptide']
# ['Nek7'] ['NIMA (never in mitosis gene a)-related expressed kinase 7']
# ['Plekhg5'] [ 'pleckstrin homology domain containing, family G (with RhoGef domain) member 5']
# ['Fam107b'] ['family with sequence similarity 107, member B']
# ['Fam70b'] ['family with sequence similarity 70, member B']
# ['Gramd3'] ['GRAM domain containing 3']
# ['Hrh2'] ['histamine receptor H2']
# ['Plxnd1'] ['plexin D1']
# ['0610007P14Rik'] ['RIKEN cDNA 0610007P14 gene']
# ['Ece2'] ['endothelin converting enzyme 2']
# ['Slit3'] ['slit homolog 3 (Drosophila)']
# ['Zdhhc2'] ['zinc finger, DHHC domain containing 2']
# ['Gprin3'] ['GPRIN family member 3']
# ['Slc8a1'] ['solute carrier family 8 (sodium/calcium exchanger), member 1']
# ['Rtn4r'] ['reticulon 4 receptor']
# ['Fezf1'] ['Fez family zinc finger 1']
# ['BC031353'] ['cDNA sequence BC031353']
# ['Jup'] ['junction plakoglobin']
# ['Htr4'] ['5 hydroxytryptamine (serotonin) receptor 4']
# ['Gm12680'] ['predicted gene 12680']
# ['Gria4'] ['glutamate receptor, ionotropic, AMPA4 (alpha 4)']
# ['Npsr1'] ['neuropeptide S receptor 1']
# ['Scnn1a'] ['sodium channel, nonvoltage-gated 1 alpha']
# ['Gyg'] ['glycogenin']
# ['Alg5'] [ 'asparagine-linked glycosylation 5 homolog (yeast, dolichyl-phosphate beta-glucosyltransferase)']
# ['Zfand3'] ['zinc finger, AN1-type domain 3']
# ['Rnasel'] ["ribonuclease L (2', 5'-oligoisoadenylate synthetase-dependent)"]
# ['Gm1399'] ['gene model 1399, (NCBI)']
# ['Slc18a3'] ['solute carrier family 18 (vesicular monoamine), member 3']
# ['Ntng1'] ['netrin G1']
# ['Hcrtr1'] ['hypocretin (orexin) receptor 1']
# ['Rtn1'] ['reticulon 1']
# ['Tnfrsf19'] ['tumor necrosis factor receptor superfamily, member 19']
# ['Mvp'] ['major vault protein']
# ['Col19a1'] ['collagen, type XIX, alpha 1']
# ['Notch3'] ['notch 3']
# ['Eml3'] ['echinoderm microtubule associated protein like 3']
# ['Tox3'] ['TOX high mobility group box family member 3']
# ['Atp10b'] ['ATPase, class V, type 10B']
# ['Stk17b'] ['serine/threonine kinase 17b (apoptosis-inducing)']
# ['Rbm19'] ['RNA binding motif protein 19']
# ['Palm3'] ['paralemmin 3']
# ['Sorbs1'] ['sorbin and SH3 domain containing 1']
# ['Ndufa10'] ['NADH dehydrogenase (ubiquinone) 1 alpha subcomplex 10']
# ['Gria2'] ['glutamate receptor, ionotropic, AMPA2 (alpha 2)']
# ['Cdc25b'] ['cell division cycle 25 homolog B (S. pombe)']
# ['Acsl3'] ['acyl-CoA synthetase long-chain family member 3']
# ['Wdr5'] ['WD repeat domain 5']
# ['Clic5'] ['chloride intracellular channel 5']
# ['Tmub2'] ['transmembrane and ubiquitin-like domain containing 2']
# ['Plcz1'] ['phospholipase C, zeta 1']
# ['Dgki'] ['diacylglycerol kinase, iota']
# ['Ola1'] ['Obg-like ATPase 1']
# ['Caml'] ['calcium modulating ligand']
# ['AI848100'] ['expressed sequence AI848100']
# ['Oxct1'] ['3-oxoacid CoA transferase 1']
# ['Ren2'] ['renin 2 tandem duplication of Ren1']
# ['Tecta'] ['tectorin alpha']
# ['Strada'] ['STE20-related kinase adaptor alpha']
# ['Exoc4'] ['exocyst complex component 4']
# ['TC1541413'] ['TIGR MGI TC1541413']
# ['D030063F01Rik'] ['RIKEN cDNA D030063F01 gene']
# ['Msi2'] ['Musashi homolog 2 (Drosophila)']
# ['Boc'] [ 'biregional cell adhesion molecule-related/down-regulated by oncogenes (Cdon) binding protein']
# ['Cyp39a1'] ['cytochrome P450, family 39, subfamily a, polypeptide 1']
# ['Pdxdc1'] ['pyridoxal-dependent decarboxylase domain containing 1']
# ['Dlst'] [ 'dihydrolipoamide S-succinyltransferase (E2 component of 2-oxo-glutarate complex)']
# ['Cux1'] ['cut-like homeobox 1']
# ['Lrp4'] ['low density lipoprotein receptor-related protein 4']
# ['Pcgf6'] ['polycomb group ring finger 6']
# ['Prrg2'] ['proline-rich Gla (G-carboxyglutamic acid) polypeptide 2']
# ['Pld5'] ['phospholipase D family, member 5']
# ['3110047P20Rik'] ['RIKEN cDNA 3110047P20 gene']
# ['B3galt2'] ['UDP-Gal:betaGlcNAc beta 1,3-galactosyltransferase, polypeptide 2']
# ['Pcdhb16'] ['protocadherin beta 16']
# ['Oxct1'] ['3-oxoacid CoA transferase 1']
# ['Nedd4l'] [ 'neural precursor cell expressed, developmentally down-regulated gene 4-like']
# ['Cacna2d1'] ['calcium channel, voltage-dependent, alpha2/delta subunit 1']
# ['Thbs4'] ['thrombospondin 4']
# ['Slc35b4'] ['solute carrier family 35, member B4']
# ['Alkbh6'] ['alkB, alkylation repair homolog 6 (E. coli)']
# ['Rassf6'] ['Ras association (RalGDS/AF-6) domain family member 6']
# ['Adrb1'] ['adrenergic receptor, beta 1']
# ['Chrnb3'] ['cholinergic receptor, nicotinic, beta polypeptide 3']
# ['Tmem35'] ['transmembrane protein 35']
# ['Lrrc38'] ['leucine rich repeat containing 38']
# ['Cyhr1'] ['cysteine and histidine rich 1']
# ['Nmbr'] ['neuromedin B receptor']
# ['Arl5a'] ['ADP-ribosylation factor-like 5A']
# ['Cxcl12'] ['chemokine (C-X-C motif) ligand 12']
# ['Ccdc37'] ['coiled-coil domain containing 37']
# ['Scube1'] ['signal peptide, CUB domain, EGF-like 1']
# ['Ccdc91'] ['coiled-coil domain containing 91']
# ['C1qa'] ['complement component 1, q subcomponent, alpha polypeptide']
# ['Hmgcs1'] ['3-hydroxy-3-methylglutaryl-Coenzyme A synthase 1']
# ['Rspo1'] ['R-spondin homolog (Xenopus laevis)']
# ['Dhcr24'] ['24-dehydrocholesterol reductase']
# ['Trib1'] ['tribbles homolog 1 (Drosophila)']
# ['Mad1l1'] ['MAD1 mitotic arrest deficient 1-like 1']
# ['Tro'] ['trophinin']
# ['Syt16'] ['synaptotagmin XVI']
# ['Usp20'] ['ubiquitin specific peptidase 20']
# ['Apbb2'] ['amyloid beta (A4) precursor protein-binding, family B, member 2']
# ['Fam184a'] ['family with sequence similarity 184, member A']
# ['Abhd6'] ['abhydrolase domain containing 6']
# ['Ids'] ['iduronate 2-sulfatase']
# ['Ank1'] ['ankyrin 1, erythroid']
# ['Cd109'] ['CD109 antigen']
# ['Cyp51'] ['cytochrome P450, family 51']
# ['Man2b1'] ['mannosidase 2, alpha B1']
# ['Bok'] ['BCL2-related ovarian killer protein']
# ['Ahcyl2'] ['S-adenosylhomocysteine hydrolase-like 2']
# ['Eya4'] ['eyes absent 4 homolog (Drosophila)']
# ['Scml4'] ['sex comb on midleg-like 4 (Drosophila)']
# ['Insig1'] ['insulin induced gene 1']
# ['Trhde'] ['TRH-degrading enzyme']
# ['Sdk2'] ['sidekick homolog 2 (chicken)']
# ['Gem'] ['GTP binding protein (gene overexpressed in skeletal muscle)']
# ['Nrk'] ['Nik related kinase']
# ['Twf2'] ['twinfilin, actin-binding protein, homolog 2 (Drosophila)']
# ['Pitpnm2'] ['phosphatidylinositol transfer protein, membrane-associated 2']
# ['Baiap3'] ['BAI1-associated protein 3']
# ['Tuba4a'] ['tubulin, alpha 4A']
# ['Atxn10'] ['ataxin 10']
# ['Phospho1'] ['phosphatase, orphan 1']
# ['Cntnap1'] ['contactin associated protein-like 1']
# ['BC100451'] ['cDNA sequence BC100451']
# ['Asb11'] ['ankyrin repeat and SOCS box-containing 11']
# ['Alox12b'] ['arachidonate 12-lipoxygenase, 12R type']
# ['Emp1'] ['epithelial membrane protein 1']
# ['Susd2'] ['sushi domain containing 2']
# ['Ugdh'] ['UDP-glucose dehydrogenase']
# ['Chrm4'] ['cholinergic receptor, muscarinic 4']
# ['Arc'] ['activity regulated cytoskeletal-associated protein']
# ['LOC433258'] ['similar to attractin-like 1']
# ['Neurod2'] ['neurogenic differentiation 2']
# ['C1qtnf3'] ['C1q and tumor necrosis factor related protein 3']
# ['Irs4'] ['insulin receptor substrate 4']
# ['Igsf5'] ['immunoglobulin superfamily, member 5']
# ['Lrmp'] ['lymphoid-restricted membrane protein']
# ['Kifc5b'] ['kinesin family member C5B']
# ['Zfp462'] ['zinc finger protein 462']
# ['Gm1441'] ['gene model 1441, (NCBI)']
# ['Nrbp2'] ['nuclear receptor binding protein 2']
# ['Coro6'] ['coronin 6']
# ['LOC214238'] ['similar to Sodium channel beta-2 subunit precursor']
# ['Cdh24'] ['cadherin-like 24']
# ['Rbm18'] ['RNA binding motif protein 18']
# ['Tmod1'] ['tropomodulin 1']
# ['Kcnj14'] ['potassium inwardly-rectifying channel, subfamily J, member 14']
# ['Arhgap25'] ['Rho GTPase activating protein 25']
# ['Gabarapl1'] ['gamma-aminobutyric acid (GABA) A receptor-associated protein-like 1']
# ['Samd14'] ['sterile alpha motif domain containing 14']
# ['Pclo'] ['piccolo (presynaptic cytomatrix protein)']
# ['Galntl4'] [ 'UDP-N-acetyl-alpha-D-galactosamine:polypeptide N-acetylgalactosaminyltransferase-like 4']
# ['Gria1'] ['glutamate receptor, ionotropic, AMPA1 (alpha 1)']
# ['Zkscan16'] ['zinc finger with KRAB and SCAN domains 16']
# ['Lxn'] ['latexin']
# ['Slc8a2'] ['solute carrier family 8 (sodium/calcium exchanger), member 2']
# ['Ica1'] ['islet cell autoantigen 1']
# ['Spsb4'] ['splA/ryanodine receptor domain and SOCS box containing 4']
# ['Wbp5'] ['WW domain binding protein 5']
# ['Slx1b'] ['SLX1 structure-specific endonuclease subunit homolog B (S. cerevisiae)']
# ['Bid'] ['BH3 interacting domain death agonist']
# ['Kcng4'] ['potassium voltage-gated channel, subfamily G, member 4']
# ['Elovl1'] [ 'elongation of very long chain fatty acids (FEN1/Elo2, SUR4/Elo3, yeast)-like 1']
# ['Dpp4'] ['dipeptidylpeptidase 4']
# ['Triap1'] ['TP53 regulated inhibitor of apoptosis 1']
# ['Tmem200a'] ['transmembrane protein 200A']
# ['Fndc5'] ['fibronectin type III domain containing 5']
# ['Syt10'] ['synaptotagmin X']
# ['LOC329302'] ['similar to CDC42-binding protein kinase alpha']
# ['Accn4'] ['amiloride-sensitive cation channel 4, pituitary']
# ['Utp14b'] ['UTP14, U3 small nucleolar ribonucleoprotein, homolog B (yeast)']
# ['Arg2'] ['arginase type II']
# ['Sulf1'] ['sulfatase 1']
# ['4933427D14Rik'] ['RIKEN cDNA 4933427D14 gene']
# ['Enpp2'] ['ectonucleotide pyrophosphatase/phosphodiesterase 2']
# ['Mtch2'] ['mitochondrial carrier homolog 2 (C. elegans)']
# ['Lrrc16a'] ['leucine rich repeat containing 16A']
# ['Chrne'] ['cholinergic receptor, nicotinic, epsilon polypeptide']
# ['Dbnl'] ['drebrin-like']
# ['Rnf220'] ['ring finger protein 220']
# ['Tmx2'] ['thioredoxin-related transmembrane protein 2']
# ['Runx2'] ['runt related transcription factor 2']
# ['D8Ertd82e'] ['DNA segment, Chr 8, ERATO Doi 82, expressed']
# ['Depdc7'] ['DEP domain containing 7']
# ['LOC270764'] ['similar to E2a-Pbx1-associated protein']
# ['S100b'] ['S100 protein, beta polypeptide, neural']
# ['Rps6ka2'] ['ribosomal protein S6 kinase, polypeptide 2']
# ['Nrxn1'] ['neurexin I']
# ['Hba-a1'] ['hemoglobin alpha, adult chain 1']
# ['Nup93'] ['nucleoporin 93']
# ['Kcnq5'] ['potassium voltage-gated channel, subfamily Q, member 5']
# ['Cacna2d3'] ['calcium channel, voltage-dependent, alpha2/delta subunit 3']
# ['Dnahc9'] ['dynein, axonemal, heavy chain 9']
# ['Wif1'] ['Wnt inhibitory factor 1']
# ['A830018L16Rik'] ['RIKEN cDNA A830018L16 gene']
# ['Sorcs2'] ['sortilin-related VPS10 domain containing receptor 2']
# ['Cacna1g'] ['calcium channel, voltage-dependent, T type, alpha 1G subunit']
# ['Got2'] ['glutamate oxaloacetate transaminase 2, mitochondrial']
# ['Slc24a3'] ['solute carrier family 24 (sodium/potassium/calcium exchanger), member 3']
# ['Ssb'] ['Sjogren syndrome antigen B']
# ['Steap3'] ['STEAP family member 3']
# ['Myo5c'] ['myosin VC']
# ['Fxyd6'] ['FXYD domain-containing ion transport regulator 6']
# ['Sirpa'] ['signal-regulatory protein alpha']
# ['Mtap2'] ['microtubule-associated protein 2']
# ['Pip5k1b'] ['phosphatidylinositol-4-phosphate 5-kinase, type 1 beta']
# ['Ptgs2'] ['prostaglandin-endoperoxide synthase 2']
# ['Pdp1'] ['pyruvate dehyrogenase phosphatase catalytic subunit 1']
# ['Inhbb'] ['inhibin beta-B']
# ['Per3'] ['period homolog 3 (Drosophila)']
# ['Ttn'] ['titin']
# ['Gng13'] ['guanine nucleotide binding protein (G protein), gamma 13']
# ['Garnl3'] ['GTPase activating RANGAP domain-like 3']
# ['Tspo'] ['translocator protein']
# ['Epha4'] ['Eph receptor A4']
# ['Trps1'] ['trichorhinophalangeal syndrome I (human)']
# ['Zfp790'] ['zinc finger protein 790']
# ['Hs3st2'] ['heparan sulfate (glucosamine) 3-O-sulfotransferase 2']
# ['Tmem25'] ['transmembrane protein 25']
# ['Vwa3a'] ['von Willebrand factor A domain containing 3A']
# ['Mgst3'] ['microsomal glutathione S-transferase 3']
# ['Ptprk'] ['protein tyrosine phosphatase, receptor type, K']
# ['Grik1'] ['glutamate receptor, ionotropic, kainate 1']
# ['Shisa2'] ['shisa homolog 2 (Xenopus laevis)']
# ['Grid2ip'] ['glutamate receptor, ionotropic, delta 2 (Grid2) interacting protein 1']
# ['Gosr2'] ['golgi SNAP receptor complex member 2']
# ['Vstm2b'] ['V-set and transmembrane domain containing 2B']
# ['Cntn3'] ['contactin 3']
# ['Megf9'] ['multiple EGF-like-domains 9']
# ['Hmgcr'] ['3-hydroxy-3-methylglutaryl-Coenzyme A reductase']
# ['Zcchc12'] ['zinc finger, CCHC domain containing 12']
# ['Pnoc'] ['prepronociceptin']
# ['Adamts15'] [ 'a disintegrin-like and metallopeptidase (reprolysin type) with thrombospondin type 1 motif, 15']
# ['Npr3'] ['natriuretic peptide receptor 3']
# ['B2m'] ['beta-2 microglobulin']
# ['Prosapip1'] ['ProSAPiP1 protein']
# ['Asns'] ['asparagine synthetase']
# ['Peg10'] ['paternally expressed 10']
# ['Apbb2'] ['amyloid beta (A4) precursor protein-binding, family B, member 2']
# ['Tesc'] ['tescalcin']
# ['Dexi'] ['dexamethasone-induced transcript']
# ['Fam49a'] ['family with sequence similarity 49, member A']
# ['Cnot7'] ['CCR4-NOT transcription complex, subunit 7']
# ['Cacnb3'] ['calcium channel, voltage-dependent, beta 3 subunit']
# ['Podn'] ['podocan']
# ['Mfap1a'] ['microfibrillar-associated protein 1A']
# ['Asxl3'] ['additional sex combs like 3 (Drosophila)']
# ['Kcnab3'] ['potassium voltage-gated channel, shaker-related subfamily, beta member 3']
# ['Tfap2c'] ['transcription factor AP-2, gamma']
# ['Magel2'] ['melanoma antigen, family L, 2']
# ['Prosc'] ['proline synthetase co-transcribed']
# ['Gtf2h2'] ['general transcription factor II H, polypeptide 2']
# ['Lpar1'] ['lysophosphatidic acid receptor 1']
# ['Tox'] ['thymocyte selection-associated high mobility group box']
# ['Cyp26b1'] ['cytochrome P450, family 26, subfamily b, polypeptide 1']
# ['Bcl6'] ['B cell leukemia/lymphoma 6']
# ['Ttll6'] ['tubulin tyrosine ligase-like family, member 6']
# ['Atp6v0a2'] ['ATPase, H+ transporting, lysosomal V0 subunit A2']
# ['Tnfaip8'] ['tumor necrosis factor, alpha-induced protein 8']
# ['Sstr4'] ['somatostatin receptor 4']
# ['6720401G13Rik'] ['RIKEN cDNA 6720401G13 gene']
# ['Vamp1'] ['vesicle-associated membrane protein 1']
# ['Pim2'] ['proviral integration site 2']
# ['Btbd3'] ['BTB (POZ) domain containing 3']
# ['Grb10'] ['growth factor receptor bound protein 10']
# ['Arl10'] ['ADP-ribosylation factor-like 10']
# ['Gad1'] ['glutamate decarboxylase 1']
# ['Cyld'] ['cylindromatosis (turban tumor syndrome)']
# ['Camk1d'] ['calcium/calmodulin-dependent protein kinase ID']
# ['Fign'] ['fidgetin']
# ['Slc6a7'] [ 'solute carrier family 6 (neurotransmitter transporter, L-proline), member 7']
# ['Mylip'] ['myosin regulatory light chain interacting protein']
# ['Camk2a'] ['calcium/calmodulin-dependent protein kinase II alpha']
# ['Pde10a'] ['phosphodiesterase 10A']
# ['App'] ['amyloid beta (A4) precursor protein']
# ['Abcc4'] ['ATP-binding cassette, sub-family C (CFTR/MRP), member 4']
# ['Asap1'] ['ArfGAP with SH3 domain, ankyrin repeat and PH domain1']
# ['Sp8'] ['trans-acting transcription factor 8']
# ['Mpp3'] ['membrane protein, palmitoylated 3 (MAGUK p55 subfamily member 3)']
# ['Hsbp1'] ['heat shock factor binding protein 1']
# ['Phf1'] ['PHD finger protein 1']
# ['Unc5b'] ['unc-5 homolog B (C. elegans)']
# ['Tmem90b'] ['transmembrane protein 90B']
# ['Col6a3'] ['collagen, type VI, alpha 3']
# ['Hpd'] ['4-hydroxyphenylpyruvic acid dioxygenase']
# ['Psmb2'] ['proteasome (prosome, macropain) subunit, beta type 2']
# ['P2rx7'] ['purinergic receptor P2X, ligand-gated ion channel, 7']
# ['Cacna1i'] ['calcium channel, voltage-dependent, alpha 1I subunit']
# ['Phyhipl'] ['phytanoyl-CoA hydroxylase interacting protein-like']
# ['Ckap2'] ['cytoskeleton associated protein 2']
# ['Kctd8'] ['potassium channel tetramerisation domain containing 8']
# ['Chst11'] ['carbohydrate sulfotransferase 11']
# ['Gm1088'] ['gene model 1088, (NCBI)']
# ['Hsp90b1'] ['heat shock protein 90, beta (Grp94), member 1']
# ['Cdyl2'] ['chromodomain protein, Y chromosome-like 2']
# ['Dnajb1'] ['DnaJ (Hsp40) homolog, subfamily B, member 1']
# ['Trpm1'] ['transient receptor potential cation channel, subfamily M, member 1']
# ['Dapk1'] ['death associated protein kinase 1']
# ['Chd6'] ['chromodomain helicase DNA binding protein 6']
# ['Rspo2'] ['R-spondin 2 homolog (Xenopus laevis)']
# ['Ptpn5'] ['protein tyrosine phosphatase, non-receptor type 5']
# ['Ube4b'] ['ubiquitination factor E4B, UFD2 homolog (S. cerevisiae)']
# ['Nfil3'] ['nuclear factor, interleukin 3, regulated']
# ['Kif5c'] ['kinesin family member 5C']
# ['Cxcl14'] ['chemokine (C-X-C motif) ligand 14']
# ['Rasgrp2'] ['RAS, guanyl releasing protein 2']
# ['Ngef'] ['neuronal guanine nucleotide exchange factor']
# ['Ttll4'] ['tubulin tyrosine ligase-like family, member 4']
# ['Psrc1'] ['proline/serine-rich coiled-coil 1']
# ['Atpaf1'] ['ATP synthase mitochondrial F1 complex assembly factor 1']
# ['Plekha7'] ['pleckstrin homology domain containing, family A member 7']
# ['Hist1h1b'] ['histone cluster 1, H1b']
# ['Lysmd2'] ['LysM, putative peptidoglycan-binding, domain containing 2']
# ['Efnb2'] ['ephrin B2']
# ['Manba'] ['mannosidase, beta A, lysosomal']
# ['Ndst3'] ['N-deacetylase/N-sulfotransferase (heparan glucosaminyl) 3']
# ['Fstl1'] ['follistatin-like 1']
# ['Ndufaf2'] ['NADH dehydrogenase (ubiquinone) 1 alpha subcomplex, assembly factor 2']
# ['Nipal3'] ['NIPA-like domain containing 3']
# ['Ankrd34c'] ['ankyrin repeat domain 34C']
# ['Map2k4'] ['mitogen-activated protein kinase kinase 4']
# ['Cds1'] ['CDP-diacylglycerol synthase 1']
# ['Zfp521'] ['zinc finger protein 521']
# ['Ptdss1'] ['phosphatidylserine synthase 1']
# ['Sowaha'] ['sosondowah ankyrin repeat domain family member A']
# ['6430709H04Rik'] ['RIKEN cDNA 6430709H04 gene']
# ['Loxl1'] ['lysyl oxidase-like 1']
# ['Atic'] [ '5-aminoimidazole-4-carboxamide ribonucleotide formyltransferase/IMP cyclohydrolase']
# ['Rprm'] ['reprimo, TP53 dependent G2 arrest mediator candidate']
# ['Dbndd2'] ['dysbindin (dystrobrevin binding protein 1) domain containing 2']
# ['Ndufs2'] ['NADH dehydrogenase (ubiquinone) Fe-S protein 2']
# ['Adcyap1r1'] ['adenylate cyclase activating polypeptide 1 receptor 1']
# ['Trpc2'] ['transient receptor potential cation channel, subfamily C, member 2']
# ['Pou4f1'] ['POU domain, class 4, transcription factor 1']
# ['Ntm'] ['neurotrimin']
# ['Mrps28'] ['mitochondrial ribosomal protein S28']
# ['Tspan12'] ['tetraspanin 12']
# ['3110035E14Rik'] ['RIKEN cDNA 3110035E14 gene']
# ['Rab12'] ['RAB12, member RAS oncogene family']
# ['Eif1ax'] ['eukaryotic translation initiation factor 1A, X-linked']
# ['Plch1'] ['phospholipase C, eta 1']
# ['Ctsz'] ['cathepsin Z']
# ['Anxa1'] ['annexin A1']
# ['Pip5k1b'] ['phosphatidylinositol-4-phosphate 5-kinase, type 1 beta']
# ['Rcan2'] ['regulator of calcineurin 2']
# ['Cd164'] ['CD164 antigen']
# ['C030046I01Rik'] ['RIKEN cDNA C030046I01 gene']
# ['Stard5'] ['StAR-related lipid transfer (START) domain containing 5']
# ['Hmbox1'] ['homeobox containing 1']
# ['B230373P09Rik'] ['RIKEN cDNA B230373P09 gene']
# ['Alg1'] [ 'asparagine-linked glycosylation 1 homolog (yeast, beta-1,4-mannosyltransferase)']
# ['Stard13'] ['StAR-related lipid transfer (START) domain containing 13']
# ['Ppp3ca'] ['protein phosphatase 3, catalytic subunit, alpha isoform']
# ['Leprel2'] ['leprecan-like 2']
# ['Gm6753'] ['predicted gene 6753']
# ['Grm4'] ['glutamate receptor, metabotropic 4']
# ['Cited1'] [ 'Cbp/p300-interacting transactivator with Glu/Asp-rich carboxy-terminal domain 1']
# ['Vim'] ['vimentin']
# ['Prl2c2'] ['prolactin family 2, subfamily c, member 2']
# ['Pcdhb19'] ['protocadherin beta 19']
# ['Cnnm1'] ['cyclin M1']
# ['Zscan22'] ['zinc finger and SCAN domain containing 22']
# ['Ugt8a'] ['UDP galactosyltransferase 8A']
# ['Rasa4'] ['RAS p21 protein activator 4']
# ['Cdr2'] ['cerebellar degeneration-related 2']
# ['Adarb1'] ['adenosine deaminase, RNA-specific, B1']
# ['Rufy3'] ['RUN and FYVE domain containing 3']
# ['Rpf2'] ['ribosome production factor 2 homolog (S. cerevisiae)']
# ['Htr1a'] ['5-hydroxytryptamine (serotonin) receptor 1A']
# ['Nxf1'] ['nuclear RNA export factor 1']
# ['Ryr1'] ['ryanodine receptor 1, skeletal muscle']
# ['Ankrd50'] ['ankyrin repeat domain 50']
# ['L3mbtl4'] ['l(3)mbt-like 4 (Drosophila)']
# ['Bsdc1'] ['BSD domain containing 1']
# ['Rcn2'] ['reticulocalbin 2']
# ['Asb4'] ['ankyrin repeat and SOCS box-containing 4']
# ['Gtdc1'] ['glycosyltransferase-like domain containing 1']
# ['Necab2'] ['N-terminal EF-hand calcium binding protein 2']
# ['Mtmr6'] ['myotubularin related protein 6']
# ['2610019F03Rik'] ['RIKEN cDNA 2610019F03 gene']
# ['Pcsk5'] ['proprotein convertase subtilisin/kexin type 5']
# ['P4hb'] ['prolyl 4-hydroxylase, beta polypeptide']
# ['Hexb'] ['hexosaminidase B']
# ['Ssr2'] ['signal sequence receptor, beta']
# ['Top1'] ['topoisomerase (DNA) I']
# ['Pik3r3'] ['phosphatidylinositol 3 kinase, regulatory subunit, polypeptide 3 (p55)']
# ['Tmem168'] ['transmembrane protein 168']
# ['Aldoc'] ['aldolase C, fructose-bisphosphate']
# ['Txnrd1'] ['thioredoxin reductase 1']
# ['Cyr61'] ['cysteine rich protein 61']
# ['Pip4k2a'] ['phosphatidylinositol-5-phosphate 4-kinase, type II, alpha']
# ['Clcn2'] ['chloride channel 2']
# ['Scube1'] ['signal peptide, CUB domain, EGF-like 1']
# ['Prdx4'] ['peroxiredoxin 4']
# ['Fos'] ['FBJ osteosarcoma oncogene']
# ['Mtap'] ['methylthioadenosine phosphorylase']
# ['Chchd2'] ['coiled-coil-helix-coiled-coil-helix domain containing 2']
# ['Vav3'] ['vav 3 oncogene']
# ['Pfdn4'] ['prefoldin 4']
# ['Gpr6'] ['G protein-coupled receptor 6']
# ['Ube2t'] ['ubiquitin-conjugating enzyme E2T (putative)']
# ['Pex13'] ['peroxisomal biogenesis factor 13']
# ['Pias2'] ['protein inhibitor of activated STAT 2']
# ['Prss12'] ['protease, serine, 12 neurotrypsin (motopsin)']
# ['Cntn4'] ['contactin 4']
# ['Lipa'] ['lysosomal acid lipase A']
# ['Tspan5'] ['tetraspanin 5']
# ['Gm261'] ['gene model 261, (NCBI)']
# ['Pnkd'] ['paroxysmal nonkinesiogenic dyskinesia']
# ['Robo2'] ['roundabout homolog 2 (Drosophila)']
# ['Ogfod1'] ['2-oxoglutarate and iron-dependent oxygenase domain containing 1']
# ['Arfgef2'] [ 'ADP-ribosylation factor guanine nucleotide-exchange factor 2 (brefeldin A-inhibited)']
# ['Gucy1a3'] ['guanylate cyclase 1, soluble, alpha 3']
# ['9530091C08Rik'] ['RIKEN cDNA 9530091C08 gene']
# ['B3gat1'] ['beta-1,3-glucuronyltransferase 1 (glucuronosyltransferase P)']
# ['Nudt4'] ['nudix (nucleoside diphosphate linked moiety X)-type motif 4']
# ['Rer1'] ['RER1 retention in endoplasmic reticulum 1 homolog (S. cerevisiae)']
# ['Hcn2'] ['hyperpolarization-activated, cyclic nucleotide-gated K+ 2']
# ['Vps35'] ['vacuolar protein sorting 35']
# ['Msn'] ['moesin']
# ['Gm2a'] ['GM2 ganglioside activator protein']
# ['Fgd5'] ['FYVE, RhoGEF and PH domain containing 5']
# ['Cops4'] [ 'COP9 (constitutive photomorphogenic) homolog, subunit 4 (Arabidopsis thaliana)']
# ['Adcy2'] ['adenylate cyclase 2']
# ['C2cd2l'] ['C2 calcium-dependent domain containing 2-like']
# ['Ghsr'] ['growth hormone secretagogue receptor']
# ['Tmem65'] ['transmembrane protein 65']
# ['Adora2a'] ['adenosine A2a receptor']
# ['6720456B07Rik'] ['RIKEN cDNA 6720456B07 gene']
# ['Scd2'] ['stearoyl-Coenzyme A desaturase 2']
# ['Ccdc85a'] ['coiled-coil domain containing 85A']
# ['Syne2'] ['synaptic nuclear envelope 2']
# ['Hdc'] ['histidine decarboxylase']
# ['Coch'] ['coagulation factor C homolog (Limulus polyphemus)']
# ['Gabra5'] ['gamma-aminobutyric acid (GABA) A receptor, subunit alpha 5']
# ['A830039N20Rik'] ['RIKEN cDNA A830039N20 gene']
# ['Arhgdia'] ['Rho GDP dissociation inhibitor (GDI) alpha']
# ['Jdp2'] ['Jun dimerization protein 2']
# ['Ube2e3'] ['ubiquitin-conjugating enzyme E2E 3']
# ['Sptlc2'] ['serine palmitoyltransferase, long chain base subunit 2']
# ['Fam189a2'] ['family with sequence similarity 189, member A2']
# ['Gdap2'] ['ganglioside-induced differentiation-associated-protein 2']
# ['Parp8'] ['poly (ADP-ribose) polymerase family, member 8']
# ['Sv2c'] ['synaptic vesicle glycoprotein 2c']
# ['D11Wsu47e'] ['DNA segment, Chr 11, Wayne State University 47, expressed']
# ['Ccdc88c'] ['coiled-coil domain containing 88C']
# ['Egflam'] ['EGF-like, fibronectin type III and laminin G domains']
# ['Akr1e1'] ['aldo-keto reductase family 1, member E1']
# ['1700019N12Rik'] ['RIKEN cDNA 1700019N12 gene']
# ['Bai3'] ['brain-specific angiogenesis inhibitor 3']
# ['Dbc1'] ['deleted in bladder cancer 1 (human)']
# ['Ube3a'] ['ubiquitin protein ligase E3A']
# ['Grin2d'] ['glutamate receptor, ionotropic, NMDA2D (epsilon 4)']
# ['Lzts1'] ['leucine zipper, putative tumor suppressor 1']
# ['Taok1'] ['TAO kinase 1']
# ['Rnf122'] ['ring finger protein 122']
# ['Slc7a14'] [ 'solute carrier family 7 (cationic amino acid transporter, y+ system), member 14']
# ['Cdc42ep3'] ['CDC42 effector protein (Rho GTPase binding) 3']
# ['Apba1'] ['amyloid beta (A4) precursor protein binding, family A, member 1']
# ['F630102L10Rik*'] ['RIKEN cDNA F630102L10 gene (non-RefSeq)']
# ['Pfkp'] ['phosphofructokinase, platelet']
# ['Hspa1l'] ['heat shock protein 1-like']
# ['Cops7b'] [ 'COP9 (constitutive photomorphogenic) homolog, subunit 7b (Arabidopsis thaliana)']
# ['Sox2'] ['SRY-box containing gene 2']
# ['Lman2'] ['lectin, mannose-binding 2']
# ['Col5a2'] ['collagen, type V, alpha 2']
# ['Il11ra2'] ['interleukin 11 receptor, alpha chain 2']
# ['Gpr146'] ['G protein-coupled receptor 146']
# ['Apln'] ['apelin']
# ['Rpp25'] ['ribonuclease P 25 subunit (human)']
# ['Rpl21'] ['ribosomal protein L21']
# [] []
# ['Wwc1'] ['WW, C2 and coiled-coil domain containing 1']
# ['Apba1'] ['amyloid beta (A4) precursor protein binding, family A, member 1']
# ['Tshz1'] ['teashirt zinc finger family member 1']
# ['Ptcd1'] ['pentatricopeptide repeat domain 1']
# ['Tmie'] ['transmembrane inner ear']
# ['E330014M11Rik*'] ['RIKEN cDNA E330014M11 gene (non-RefSeq)']
# ['Il34'] ['interleukin 34']
# ['Cyb5'] ['cytochrome b-5']
# ['Atp1b2'] ['ATPase, Na+/K+ transporting, beta 2 polypeptide']
# ['Nat8l'] ['N-acetyltransferase 8-like']
# ['Vti1a'] ['vesicle transport through interaction with t-SNAREs homolog 1A (yeast)']
# ['Itpk1'] ['inositol 1,3,4-triphosphate 5/6 kinase']
# ['Cd4'] ['CD4 antigen']
# ['Gfra1'] ['glial cell line derived neurotrophic factor family receptor alpha 1']
# ['Satb1'] ['special AT-rich sequence binding protein 1']
# ['Kcnj4'] ['potassium inwardly-rectifying channel, subfamily J, member 4']
# ['Meis1'] ['Meis homeobox 1']
# ['4921531P07Rik'] ['RIKEN cDNA 4921531P07 gene']
# ['Pappa2'] ['pappalysin 2']
# ['Rph3a'] ['rabphilin 3A']
# ['Frzb'] ['frizzled-related protein']
# ['Hbb-b1'] ['hemoglobin, beta adult major chain']
# ['Krt222'] ['keratin 222']
# ['Pam'] ['peptidylglycine alpha-amidating monooxygenase']
# ['Stac'] ['src homology three (SH3) and cysteine rich domain']
# ['Ctla4'] ['cytotoxic T-lymphocyte-associated protein 4']
# ['F5'] ['coagulation factor V']
# ['Dtnbp1'] ['dystrobrevin binding protein 1']
# ['Dhx40'] ['DEAH (Asp-Glu-Ala-His) box polypeptide 40']
# ['Zfpm2'] ['zinc finger protein, multitype 2']
# ['Orai2'] ['ORAI calcium release-activated calcium modulator 2']
# ['Zdhhc7'] ['zinc finger, DHHC domain containing 7']
# ['Amigo2'] ['adhesion molecule with Ig like domain 2']
# ['D830029A09Rik'] ['RIKEN cDNA D830029A09 gene']
# ['Acvrl1'] ['activin A receptor, type II-like 1']
# ['Slc44a1'] ['solute carrier family 44, member 1']
# ['Tmsb10'] ['thymosin, beta 10']
# ['Sart3'] ['squamous cell carcinoma antigen recognized by T cells 3']
# ['Gnb1'] ['guanine nucleotide binding protein (G protein), beta 1']
# ['Lats2'] ['large tumor suppressor 2']
# ['Mras'] ['muscle and microspikes RAS']
# ['Gpr56'] ['G protein-coupled receptor 56']
# ['Esyt3'] ['extended synaptotagmin-like protein 3']
# ['Dynlt3'] ['dynein light chain Tctex-type 3']
# ['Nsf'] ['N-ethylmaleimide sensitive fusion protein']
# ['Grid2'] ['glutamate receptor, ionotropic, delta 2']
# ['Pfkfb3'] ['6-phosphofructo-2-kinase/fructose-2,6-biphosphatase 3']
# ['Lipm'] ['lipase, family member M']
# ['Itgb1'] ['integrin beta 1 (fibronectin receptor beta)']
# ['Sh3rf1'] ['SH3 domain containing ring finger 1']
# ['Tiam2'] ['T cell lymphoma invasion and metastasis 2']
# ['Cldn1'] ['claudin 1']
# ['Pak6'] ['p21 protein (Cdc42/Rac)-activated kinase 6']
# ['Entpd3'] ['ectonucleoside triphosphate diphosphohydrolase 3']
# ['Lmod2'] ['leiomodin 2 (cardiac)']
# ['Stmn2'] ['stathmin-like 2']
# ['Slc35f1'] ['solute carrier family 35, member F1']
# ['Scai'] ['suppressor of cancer cell invasion']
# ['Chrna2'] ['cholinergic receptor, nicotinic, alpha polypeptide 2 (neuronal)']
# ['Prkdc'] ['protein kinase, DNA activated, catalytic polypeptide']
# ['Ipo5'] ['importin 5']
# ['Csdc2'] ['cold shock domain containing C2, RNA binding']
# ['Ntrk1'] ['neurotrophic tyrosine kinase, receptor, type 1']
# ['Susd4'] ['sushi domain containing 4']
# ['Darc'] ['Duffy blood group, chemokine receptor']
# ['Ctnnd1'] ['catenin (cadherin associated protein), delta 1']
# ['Pola1'] ['polymerase (DNA directed), alpha 1']
# ['Spag16'] ['sperm associated antigen 16']
# ['Ptpro'] ['protein tyrosine phosphatase, receptor type, O']
# ['Gmppa'] ['GDP-mannose pyrophosphorylase A']
# ['Nnat'] ['neuronatin']
# ['Smug1'] ['single-strand selective monofunctional uracil DNA glycosylase']
# ['Efnb3'] ['ephrin B3']
# ['D430041D05Rik'] ['RIKEN cDNA D430041D05 gene']
# ['Foxred2'] ['FAD-dependent oxidoreductase domain containing 2']
# ['Rab3c'] ['RAB3C, member RAS oncogene family']
# ['LOC434368'] ['similar to mastermind-like 2']
# ['Stk32c'] ['serine/threonine kinase 32C']
# ['Chrnd'] ['cholinergic receptor, nicotinic, delta polypeptide']
# ['Kpnb1'] ['karyopherin (importin) beta 1']
# ['Mylk'] ['myosin, light polypeptide kinase']
# ['Dclk3'] ['doublecortin-like kinase 3']
# ['Ttpal'] ['tocopherol (alpha) transfer protein-like']
# ['Arf1'] ['ADP-ribosylation factor 1']
# ['Nfic'] ['nuclear factor I/C']
# ['Acyp1'] ['acylphosphatase 1, erythrocyte (common) type']
# ['Htr5b'] ['5-hydroxytryptamine (serotonin) receptor 5B']
# ['Map3k5'] ['mitogen-activated protein kinase kinase kinase 5']
# ['Id2'] ['inhibitor of DNA binding 2']
# ['Arrdc3'] ['arrestin domain containing 3']
# ['Slc9a9'] ['solute carrier family 9 (sodium/hydrogen exchanger), member 9']
# ['Galnt9'] [ 'UDP-N-acetyl-alpha-D-galactosamine:polypeptide N-acetylgalactosaminyltransferase 9']
# ['Nsun7'] ['NOL1/NOP2/Sun domain family, member 7']
# ['Kcnj9'] ['potassium inwardly-rectifying channel, subfamily J, member 9']
# ['Zmynd11'] ['zinc finger, MYND domain containing 11']
# ['Kcns3'] [ 'potassium voltage-gated channel, delayed-rectifier, subfamily S, member 3']
# ['Dusp18'] ['dual specificity phosphatase 18']
# ['Tcf4'] ['transcription factor 4']
# ['Cyb5r1'] ['cytochrome b5 reductase 1']
# ['Nptx2'] ['neuronal pentraxin 2']
# ['Siae'] ['sialic acid acetylesterase']
# ['Recql5'] ['RecQ protein-like 5']
# ['Cryab'] ['crystallin, alpha B']
# ['Hspbp1'] ['HSPA (heat shock 70kDa) binding protein, cytoplasmic cochaperone 1']
# ['Sbf1'] ['SET binding factor 1']
# ['Pcdh1'] ['protocadherin 1']
# ['Gabrg1'] ['gamma-aminobutyric acid (GABA) A receptor, subunit gamma 1']
# ['Iqsec3'] ['IQ motif and Sec7 domain 3']
# ['Ap2s1'] ['adaptor-related protein complex 2, sigma 1 subunit']
# ['Leprot'] ['leptin receptor overlapping transcript']
# ['Whrn'] ['whirlin']
# ['Kctd9'] ['potassium channel tetramerisation domain containing 9']
# ['Cpne5'] ['copine V']
# ['Ifit3'] ['interferon-induced protein with tetratricopeptide repeats 3']
# ['Ovgp1'] ['oviductal glycoprotein 1']
# ['Pea15a'] ['phosphoprotein enriched in astrocytes 15A']
# ['Kcnip3'] ['Kv channel interacting protein 3, calsenilin']
# ['Acaa2'] [ 'acetyl-Coenzyme A acyltransferase 2 (mitochondrial 3-oxoacyl-Coenzyme A thiolase)']
# ['Isoc1'] ['isochorismatase domain containing 1']
# ['Fam84b'] ['family with sequence similarity 84, member B']
# ['Tbp'] ['TATA box binding protein']
# ['Cyp26b1'] ['cytochrome P450, family 26, subfamily b, polypeptide 1']
# ['Slc41a3'] ['solute carrier family 41, member 3']
# ['Fndc3b'] ['fibronectin type III domain containing 3B']
# ['Laptm4b'] ['lysosomal-associated protein transmembrane 4B']
# ['Gjd2'] ['gap junction protein, delta 2']
# ['Tspan32'] ['tetraspanin 32']
# ['Grem2'] ['gremlin 2 homolog, cysteine knot superfamily (Xenopus laevis)']
# ['Amph'] ['amphiphysin']
# ['Glcci1'] ['glucocorticoid induced transcript 1']
# ['Hs6st2'] ['heparan sulfate 6-O-sulfotransferase 2']
# ['Cthrc1'] ['collagen triple helix repeat containing 1']
# ['Oprl1'] ['opioid receptor-like 1']
# ['Kcnd3'] ['potassium voltage-gated channel, Shal-related family, member 3']
# ['P2rx5'] ['purinergic receptor P2X, ligand-gated ion channel, 5']
# ['Trp53'] ['transformation related protein 53']
# ['Tgfb1'] ['transforming growth factor, beta 1']
# ['Atp1a1'] ['ATPase, Na+/K+ transporting, alpha 1 polypeptide']
# ['Cmklr1'] ['chemokine-like receptor 1']
# ['Gda'] ['guanine deaminase']
# ['Clstn2'] ['calsyntenin 2']
# ['Prrt3'] ['proline-rich transmembrane protein 3']
# ['Ptprz1'] ['protein tyrosine phosphatase, receptor type Z, polypeptide 1']
# ['Ube2i'] ['ubiquitin-conjugating enzyme E2I']
# ['Ighm'] ['immunoglobulin heavy constant mu']
# ['Pop4'] ['processing of precursor 4, ribonuclease P/MRP family, (S. cerevisiae)']
# ['Sh3gl2'] ['SH3-domain GRB2-like 2']
# ['Loxl2'] ['lysyl oxidase-like 2']
# ['Ppp1r1a'] ['protein phosphatase 1, regulatory (inhibitor) subunit 1A']
# ['Ccr1'] ['chemokine (C-C motif) receptor 1']
# ['Galns'] ['galactosamine (N-acetyl)-6-sulfate sulfatase']
# ['Serpina3k'] ['serine (or cysteine) peptidase inhibitor, clade A, member 3K']
# ['Armc2'] ['armadillo repeat containing 2']
# ['Ostn'] ['osteocrin']
# ['Mycl1'] [ 'v-myc myelocytomatosis viral oncogene homolog 1, lung carcinoma derived (avian)']
# ['Mrpl54'] ['mitochondrial ribosomal protein L54']
# ['Tmem11'] ['transmembrane protein 11']
# ['Dffa'] ['DNA fragmentation factor, alpha subunit']
# ['Magix'] ['MAGI family member, X-linked']
# ['Pgf'] ['placental growth factor']
# ['Tnnc1'] ['troponin C, cardiac/slow skeletal']
# ['Paip2'] ['polyadenylate-binding protein-interacting protein 2']
# ['Grin1'] ['glutamate receptor, ionotropic, NMDA1 (zeta 1)']
# ['Sec14l1'] ['SEC14-like 1 (S. cerevisiae)']
# ['Syn1'] ['synapsin I']
# ['Med30'] ['mediator complex subunit 30']
# ['Sncg'] ['synuclein, gamma']
# ['Pttg1'] ['pituitary tumor-transforming gene 1']
# ['Lrrn2'] ['leucine rich repeat protein 2, neuronal']
# ['Coro2b'] ['coronin, actin binding protein, 2B']
# ['Elmo1'] ['engulfment and cell motility 1, ced-12 homolog (C. elegans)']
# ['Synj2'] ['synaptojanin 2']
# ['Lcat'] ['lecithin cholesterol acyltransferase']
# ['Tmeff2'] ['transmembrane protein with EGF-like and two follistatin-like domains 2']
# ['1600021P15Rik'] ['RIKEN cDNA 1600021P15 gene']
# ['Lhfpl3'] ['lipoma HMGIC fusion partner-like 3']
# ['Zdhhc23'] ['zinc finger, DHHC domain containing 23']
# ['Ssbp2'] ['single-stranded DNA binding protein 2']
# ['Cdh23'] ['cadherin 23 (otocadherin)']
# ['Prokr1'] ['prokineticin receptor 1']
# ['Zfyve9'] ['zinc finger, FYVE domain containing 9']
# ['Cuedc2'] ['CUE domain containing 2']
# ['Btg3'] ['B cell translocation gene 3']
# ['Egr4'] ['early growth response 4']
# ['Sorl1'] ['sortilin-related receptor, LDLR class A repeats-containing']
# ['Trpv4'] ['transient receptor potential cation channel, subfamily V, member 4']
# ['Golga7b'] ['golgi autoantigen, golgin subfamily a, 7B']
# ['Crhr2'] ['corticotropin releasing hormone receptor 2']
# ['Klhl1'] ['kelch-like 1 (Drosophila)']
# ['Fbln7'] ['fibulin 7']
# ['Rarres1'] ['retinoic acid receptor responder (tazarotene induced) 1']
# ['Qrfp'] ['pyroglutamylated RFamide peptide']
# ['Tnnt3'] ['troponin T3, skeletal, fast']
# ['1810041L15Rik'] ['RIKEN cDNA 1810041L15 gene']
# ['Cdca2'] ['cell division cycle associated 2']
# ['Otud6b'] ['OTU domain containing 6B']
# ['Ceacam14'] ['carcinoembryonic antigen-related cell adhesion molecule 14']
# ['Kiss1'] ['KiSS-1 metastasis-suppressor']
# ['Mapk8'] ['mitogen-activated protein kinase 8']
# ['Vstm2a'] ['V-set and transmembrane domain containing 2A']
# ['D3Bwg0562e'] ["DNA segment, Chr 3, Brigham & Women's Genetics 0562 expressed"]
# ['Grm1'] ['glutamate receptor, metabotropic 1']
# ['Sqrdl'] ['sulfide quinone reductase-like (yeast)']
# ['Dgkh'] ['diacylglycerol kinase, eta']
# ['Apoe'] ['apolipoprotein E']
# ['Gprasp1'] ['G protein-coupled receptor associated sorting protein 1']
# ['Tomm34'] ['translocase of outer mitochondrial membrane 34']
# ['Ntng2'] ['netrin G2']
# ['Kctd1'] ['potassium channel tetramerisation domain containing 1']
# ['Spnb1'] ['spectrin beta 1']
# ['Stk33'] ['serine/threonine kinase 33']
# ['Gss'] ['glutathione synthetase']
# ['Nenf'] ['neuron derived neurotrophic factor']
# ['Dgat2'] ['diacylglycerol O-acyltransferase 2']
# ['Mfsd2a'] ['major facilitator superfamily domain containing 2A']
# ['Fat3'] ['FAT tumor suppressor homolog 3 (Drosophila)']
# ['Adrbk2'] ['adrenergic receptor kinase, beta 2']
# ['9830001H06Rik'] ['RIKEN cDNA 9830001H06 gene']
# ['S1pr1'] ['sphingosine-1-phosphate receptor 1']
# ['Pqlc1'] ['PQ loop repeat containing 1']
# ['Slc16a2'] ['solute carrier family 16 (monocarboxylic acid transporters), member 2']
# ['Cd63'] ['CD63 antigen']
# ['Synpo2'] ['synaptopodin 2']
# ['Tmeff1'] ['transmembrane protein with EGF-like and two follistatin-like domains 1']
# ['Pkd2l1'] ['polycystic kidney disease 2-like 1']
# ['Nek2'] ['NIMA (never in mitosis gene a)-related expressed kinase 2']
# ['Itgb1bp1'] ['integrin beta 1 binding protein 1']
# ['Sulf2'] ['sulfatase 2']
# ['Prkcq'] ['protein kinase C, theta']
# ['Eepd1'] ['endonuclease/exonuclease/phosphatase family domain containing 1']
# ['Scrn1'] ['secernin 1']
# ['Elovl5'] ['ELOVL family member 5, elongation of long chain fatty acids (yeast)']
# ['Gbx2'] ['gastrulation brain homeobox 2']
# ['Prdx5'] ['peroxiredoxin 5']
# ['Glt8d2'] ['glycosyltransferase 8 domain containing 2']
# ['Smpd4'] ['sphingomyelin phosphodiesterase 4']
# ['Daam2'] ['dishevelled associated activator of morphogenesis 2']
# ['Tm6sf1'] ['transmembrane 6 superfamily member 1']
# ['Pirt'] [ 'phosphoinositide-interacting regulator of transient receptor potential channels']
# ['Prkcb'] ['protein kinase C, beta']
# ['Rapgef6'] ['Rap guanine nucleotide exchange factor (GEF) 6']
# ['Tmem108'] ['transmembrane protein 108']
# ['Aspa'] ['aspartoacylase']
# [] []
# ['Fgf1'] ['fibroblast growth factor 1']
# ['Pvrl1'] ['poliovirus receptor-related 1']
# ['Tnfrsf21'] ['tumor necrosis factor receptor superfamily, member 21']
# ['Stoml2'] ['stomatin (Epb7.2)-like 2']
# ['Pdia3'] ['protein disulfide isomerase associated 3']
# ['Atat1'] ['alpha tubulin acetyltransferase 1']
# ['Stat5a'] ['signal transducer and activator of transcription 5A']
# ['Pak7'] ['p21 protein (Cdc42/Rac)-activated kinase 7']
# ['Axin2'] ['axin2']
# ['Bcl2l12'] ['BCL2-like 12 (proline rich)']
# ['Lrp8'] [ 'low density lipoprotein receptor-related protein 8, apolipoprotein e receptor']
# ['F11r'] ['F11 receptor']
# ['Sh3bp4'] ['SH3-domain binding protein 4']
# ['Gldc'] ['glycine decarboxylase']
# ['Ptpn3'] ['protein tyrosine phosphatase, non-receptor type 3']
# ['Kcnab1'] ['potassium voltage-gated channel, shaker-related subfamily, beta member 1']
# ['Limch1'] ['LIM and calponin homology domains 1']
# ['Clmn'] ['calmin']
# ['Dact2'] ['dapper homolog 2, antagonist of beta-catenin (xenopus)']
# ['Scn1a'] ['sodium channel, voltage-gated, type I, alpha']
# ['Epha8'] ['Eph receptor A8']
# ['Ckm'] ['creatine kinase, muscle']
# ['Gckr'] ['glucokinase regulatory protein']
# ['Uap1'] ['UDP-N-acetylglucosamine pyrophosphorylase 1']
# ['Nr4a3'] ['nuclear receptor subfamily 4, group A, member 3']
# ['Col9a2'] ['collagen, type IX, alpha 2']
# ['Smarca2'] [ 'SWI/SNF related, matrix associated, actin dependent regulator of chromatin, subfamily a, member 2']
# ['Wnt9a'] ['wingless-type MMTV integration site 9A']
# ['Dlg4'] ['discs, large homolog 4 (Drosophila)']
# ['Gpr98'] ['G protein-coupled receptor 98']
# ['Sirt2'] [ 'sirtuin 2 (silent mating type information regulation 2, homolog) 2 (S. cerevisiae)']
# ['Yme1l1'] ['YME1-like 1 (S. cerevisiae)']
# ['Sdc3'] ['syndecan 3']
# ['Zfp804a'] ['zinc finger protein 804A']
# ['S100a16'] ['S100 calcium binding protein A16']
# ['Spint1'] ['serine protease inhibitor, Kunitz type 1']
# ['Ltb'] ['lymphotoxin B']
# ['Psmd5'] ['proteasome (prosome, macropain) 26S subunit, non-ATPase, 5']
# ['Ifltd1'] ['intermediate filament tail domain containing 1']
# ['Serpine2'] ['serine (or cysteine) peptidase inhibitor, clade E, member 2']
# ['LOC380889'] ['axonemal dynein heavy chain family member']
# ['Mpped1'] ['metallophosphoesterase domain containing 1']
# ['A530057D15Rik*'] ['RIKEN cDNA A530057D15 gene (non-RefSeq)']
# ['Tfam'] ['transcription factor A, mitochondrial']
# ['Rln3'] ['relaxin 3']
# ['Mc3r'] ['melanocortin 3 receptor']
# ['Coro1c'] ['coronin, actin binding protein 1C']
# ['D11Ertd759e'] ['DNA segment, Chr 11, ERATO Doi 759, expressed']
# ['Rnf13'] ['ring finger protein 13']
# ['Dtnbp1'] ['dystrobrevin binding protein 1']
# ['Rnf144b'] ['ring finger protein 144B']
# ['Dusp5'] ['dual specificity phosphatase 5']
# ['Rassf4'] ['Ras association (RalGDS/AF-6) domain family member 4']
# ['Tecr'] ['trans-2,3-enoyl-CoA reductase']
# ['Pcdhb13'] ['protocadherin beta 13']
# ['4921517L17Rik'] ['RIKEN cDNA 4921517L17 gene']
# ['Arhgap31'] ['Rho GTPase activating protein 31']
# ['Sun1'] ['Sad1 and UNC84 domain containing 1']
# ['Cotl1'] ['coactosin-like 1 (Dictyostelium)']
# ['Eef2'] ['eukaryotic translation elongation factor 2']
# ['Tnfrsf11a'] ['tumor necrosis factor receptor superfamily, member 11a']
# ['Edc3'] ['enhancer of mRNA decapping 3 homolog (S. cerevisiae)']
# ['Sema6c'] [ 'sema domain, transmembrane domain (TM), and cytoplasmic domain, (semaphorin) 6C']
# ['Igsf11'] ['immunoglobulin superfamily, member 11']
# ['Epdr1'] ['ependymin related protein 1 (zebrafish)']
# ['Satb2'] ['special AT-rich sequence binding protein 2']
# ['Wnt5a'] ['wingless-related MMTV integration site 5A']
# ['Mylk3'] ['myosin light chain kinase 3']
# ['Rpl23'] ['ribosomal protein L23']
# ['Plxna2'] ['plexin A2']
# ['Styk1'] ['serine/threonine/tyrosine kinase 1']
# ['Npvf'] ['neuropeptide VF precursor']
# ['Adipor1'] ['adiponectin receptor 1']
# ['Slco3a1'] ['solute carrier organic anion transporter family, member 3a1']
# ['Bckdhb'] ['branched chain ketoacid dehydrogenase E1, beta polypeptide']
# ['Mef2c'] ['myocyte enhancer factor 2C']
# ['Ptp4a1'] ['protein tyrosine phosphatase 4a1']
# ['Sgcz'] ['sarcoglycan zeta']
# ['Tspyl4'] ['TSPY-like 4']
# ['Ngf'] ['nerve growth factor']
# ['Srgap1'] ['SLIT-ROBO Rho GTPase activating protein 1']
# ['B630019K06Rik'] [ 'novel protein similar to F-box and leucine-rich repeat protein 17 (Fbxl17)']
# ['Fez2'] ['fasciculation and elongation protein zeta 2 (zygin II)']
# ['Adamts8'] [ 'a disintegrin-like and metallopeptidase (reprolysin type) with thrombospondin type 1 motif, 8']
# ['Chrna6'] ['cholinergic receptor, nicotinic, alpha polypeptide 6']
# ['Ifi205'] ['interferon activated gene 205']
# ['A230097P14Rik*'] ['RIKEN cDNA A230097P14 gene (non-RefSeq)']
# ['Egln1'] ['EGL nine homolog 1 (C. elegans)']
# ['Kcne3'] ['potassium voltage-gated channel, Isk-related subfamily, gene 3']
# ['Fryl'] ['furry homolog-like (Drosophila)']
# ['Midn'] ['midnolin']
# ['Spns2'] ['spinster homolog 2 (Drosophila)']
# ['Ralb'] ['v-ral simian leukemia viral oncogene homolog B (ras related)']
# ['Csrp3'] ['cysteine and glycine-rich protein 3']
# ['Uck1'] ['uridine-cytidine kinase 1']
# ['Baalc'] ['brain and acute leukemia, cytoplasmic']
# ['Rfx3'] ['regulatory factor X, 3 (influences HLA class II expression)']
# ['Gm22'] ['predicted gene 22']
# ['Mpzl1'] ['myelin protein zero-like 1']
# ['Tubb2a'] ['tubulin, beta 2A class IIA']
# ['Sdhb'] ['succinate dehydrogenase complex, subunit B, iron sulfur (Ip)']
# ['Npc2'] ['Niemann Pick type C2']
# ['Tac2'] ['tachykinin 2']
# ['Decr2'] ['2-4-dienoyl-Coenzyme A reductase 2, peroxisomal']
# ['St3gal1'] ['ST3 beta-galactoside alpha-2,3-sialyltransferase 1']
# ['Epha10'] ['Eph receptor A10']
# ['Itga11'] ['integrin alpha 11']
# ['Tmem14a'] ['transmembrane protein 14A']
# ['Aldh2'] ['aldehyde dehydrogenase 2, mitochondrial']
# ['Slc6a11'] ['solute carrier family 6 (neurotransmitter transporter, GABA), member 11']
# ['Zfand2b'] ['zinc finger, AN1 type domain 2B']
# ['Rbmx'] ['RNA binding motif protein, X chromosome']
# ['Snx31'] ['sorting nexin 31']
# ['Limk1'] ['LIM-domain containing, protein kinase']
# ['LOC433228'] ['hypothetical gene supported by AK082257']
# ['Aim1'] ['absent in melanoma 1']
# ['Tbc1d1'] ['TBC1 domain family, member 1']
# ['Mfn2'] ['mitofusin 2']
# ['Hiatl1'] ['hippocampus abundant transcript-like 1']
# ['Ngfr'] ['nerve growth factor receptor (TNFR superfamily, member 16)']
# ['Fancd2'] ['Fanconi anemia, complementation group D2']
# ['Trpc5'] ['transient receptor potential cation channel, subfamily C, member 5']
# ['Kcna2'] ['potassium voltage-gated channel, shaker-related subfamily, member 2']
# ['Glra3'] ['glycine receptor, alpha 3 subunit']
# ['Bmp5'] ['bone morphogenetic protein 5']
# ['Yeats2'] ['YEATS domain containing 2']
# ['Dlg2'] ['discs, large homolog 2 (Drosophila)']
# ['Lrrc55'] ['leucine rich repeat containing 55']
# ['Arhgef26'] ['Rho guanine nucleotide exchange factor (GEF) 26']
# ['Crym'] ['crystallin, mu']
# ['Pmfbp1'] ['polyamine modulated factor 1 binding protein 1']
# ['St8sia2'] ['ST8 alpha-N-acetyl-neuraminide alpha-2,8-sialyltransferase 2']
# ['Map2k5'] ['mitogen-activated protein kinase kinase 5']
# ['Pde4d'] ['phosphodiesterase 4D, cAMP specific']
# ['Arl4d'] ['ADP-ribosylation factor-like 4D']
# ['Stard8'] ['START domain containing 8']
# ['Pdyn'] ['prodynorphin']
# ['Ap1b1'] ['adaptor protein complex AP-1, beta 1 subunit']
# ['Exosc8'] ['exosome component 8']
# ['Npnt'] ['nephronectin']
# ['Gprc5b'] ['G protein-coupled receptor, family C, group 5, member B']
# ['Gpnmb'] ['glycoprotein (transmembrane) nmb']
# ['Glp1r'] ['glucagon-like peptide 1 receptor']
# ['Rasd2'] ['RASD family, member 2']
# ['Rps19'] ['ribosomal protein S19']
# ['Grin2a'] ['glutamate receptor, ionotropic, NMDA2A (epsilon 1)']
# ['Serpina3c'] ['serine (or cysteine) peptidase inhibitor, clade A, member 3C']
# ['Sfmbt2'] ['Scm-like with four mbt domains 2']
# ['Svip'] ['small VCP/p97-interacting protein']
# ['Gpr55'] ['G protein-coupled receptor 55']
# ['Tanc1'] ['tetratricopeptide repeat, ankyrin repeat and coiled-coil containing 1']
# ['Chrm5'] ['cholinergic receptor, muscarinic 5']
# ['Parvb'] ['parvin, beta']
# ['Cdkn1a'] ['cyclin-dependent kinase inhibitor 1A (P21)']
# ['Parm1'] ['prostate androgen-regulated mucin-like protein 1']
# ['Spg21'] ['spastic paraplegia 21 homolog (human)']
# ['Efr3a'] ['EFR3 homolog A (S. cerevisiae)']
# ['Kif26b'] ['kinesin family member 26B']
# ['Ybx2'] ['Y box protein 2']
# ['Ric8b'] ['resistance to inhibitors of cholinesterase 8 homolog B (C. elegans)']
# ['Ccdc3'] ['coiled-coil domain containing 3']
# ['Otc'] ['ornithine transcarbamylase']
# ['Syn3'] ['synapsin III']
# ['Bhlhe40'] ['basic helix-loop-helix family, member e40']
# ['Gabbr2'] ['gamma-aminobutyric acid (GABA) B receptor, 2']
# ['Fam167a'] ['family with sequence similarity 167, member A']
# ['Pcp4'] ['Purkinje cell protein 4']
# ['Gdap10'] ['ganglioside-induced differentiation-associated-protein 10']
# ['Magi1'] ['membrane associated guanylate kinase, WW and PDZ domain containing 1']
# ['Crlf1'] ['cytokine receptor-like factor 1']
# ['Hpca'] ['hippocalcin']
# ['Trh'] ['thyrotropin releasing hormone']
# ['Kcnj3'] ['potassium inwardly-rectifying channel, subfamily J, member 3']
# ['Tmem196'] ['transmembrane protein 196']
# ['Slc9a2'] ['solute carrier family 9 (sodium/hydrogen exchanger), member 2']
# ['1700037H04Rik'] ['RIKEN cDNA 1700037H04 gene']
# ['Ppap2b'] ['phosphatidic acid phosphatase type 2B']
# ['Rap2b'] ['RAP2B, member of RAS oncogene family']
# ['Fbln2'] ['fibulin 2']
# ['Tpd52l1'] ['tumor protein D52-like 1']
# ['Gabra1'] ['gamma-aminobutyric acid (GABA) A receptor, subunit alpha 1']
# ...
# ['Foxa1'] ['forkhead box A1']
# ['Esr1'] ['estrogen receptor 1 (alpha)']
# ['Htr2c'] ['5-hydroxytryptamine (serotonin) receptor 2C']
# ['Kif5a'] ['kinesin family member 5A']
# ['Ism1'] ['isthmin 1 homolog (zebrafish)']
# ['1500032L24Rik'] ['RIKEN cDNA 1500032L24 gene']
# ['Myl4'] ['myosin, light polypeptide 4']
# ['Col9a3'] ['collagen, type IX, alpha 3']
# ['C130096N06Rik'] ['RIKEN cDNA C130096N06 gene']
# ['Slc39a5'] ['solute carrier family 39 (metal ion transporter), member 5']
# ['Plcd3'] ['phospholipase C, delta 3']
# ['Pdcd4'] ['programmed cell death 4']
# ['Fbxo21'] ['F-box protein 21']
# ['Hist1h1a'] ['histone cluster 1, H1a']
# ['Cables2'] ['CDK5 and Abl enzyme substrate 2']
# ['Iqgap2'] ['IQ motif containing GTPase activating protein 2']
# ['3110082D06Rik'] ['RIKEN cDNA 3110082D06 gene']
# ['Mum1l1'] ['melanoma associated antigen (mutated) 1-like 1']
# ['Ube2ql1'] ['ubiquitin-conjugating enzyme E2Q family-like 1']
# ['Mrc1'] ['mannose receptor, C type 1']
# ['Rgs17'] ['regulator of G-protein signaling 17']
# ['3100002H09Rik'] ['RIKEN cDNA 3100002H09 gene']
# ['Ankrd34b'] ['ankyrin repeat domain 34B']
# ['Atp5h'] ['ATP synthase, H+ transporting, mitochondrial F0 complex, subunit d']
# ['Ap1b1'] ['adaptor protein complex AP-1, beta 1 subunit']
# ['F2rl1'] ['coagulation factor II (thrombin) receptor-like 1']
# ['Ppp3r2'] [ 'protein phosphatase 3, regulatory subunit B, alpha isoform (calcineurin B, type II)']
# ['Dock10'] ['dedicator of cytokinesis 10']
# ['Itgb8'] ['integrin beta 8']
# ['Akap13'] ['A kinase (PRKA) anchor protein 13']
# ['Slc5a7'] ['solute carrier family 5 (choline transporter), member 7']
# ['Slc2a1'] ['solute carrier family 2 (facilitated glucose transporter), member 1']
# ['Met'] ['met proto-oncogene']
# ['Rxfp3'] ['relaxin family peptide receptor 3']
# ['Hmx3'] ['H6 homeobox 3']
# ['Disp2'] ['dispatched homolog 2 (Drosophila)']
# ['Xlr3a'] ['X-linked lymphocyte-regulated 3A']
# ['Atp13a5'] ['ATPase type 13A5']
# ['Fam65a'] ['family with sequence similarity 65, member A']
# ['Cyfip1'] ['cytoplasmic FMR1 interacting protein 1']
# ['Spp1'] ['secreted phosphoprotein 1']
# ['Rtl1'] ['retrotransposon-like 1']
# ['Rpl11'] ['ribosomal protein L11']
# ['Cnp'] ["2',3'-cyclic nucleotide 3' phosphodiesterase"]
# ['LOC545810'] ['-']
# ['Kcnip4'] ['Kv channel interacting protein 4']
# ['Gaa'] ['glucosidase, alpha, acid']
# ['Grik3'] ['glutamate receptor, ionotropic, kainate 3']
# ['Cox7b'] ['cytochrome c oxidase subunit VIIb']
# ['Meis3'] ['Meis homeobox 3']
# ['Adra2b'] ['adrenergic receptor, alpha 2b']
# ['Csf2rb2'] [ 'colony stimulating factor 2 receptor, beta 2, low-affinity (granulocyte-macrophage)']
# ['Atp6v1d'] ['ATPase, H+ transporting, lysosomal V1 subunit D']
# ['Fxyd7'] ['FXYD domain-containing ion transport regulator 7']
# ['Mlec'] ['malectin']
# ['Phactr4'] ['phosphatase and actin regulator 4']
# ['Snhg11'] ['small nucleolar RNA host gene 11']
# ['Zic1'] ['zinc finger protein of the cerebellum 1']
# ['Pdia5'] ['protein disulfide isomerase associated 5']
# ['BC005561'] ['cDNA sequence BC005561']
# ['Cyp2j6'] ['cytochrome P450, family 2, subfamily j, polypeptide 6']
# ['Frmd6'] ['FERM domain containing 6']
# ['LOC433402'] ['similar to Nebulette (Actin-binding Z-disk protein)']
# ['1810031K17Rik'] ['RIKEN cDNA 1810031K17 gene']
# ['Rrad'] ['Ras-related associated with diabetes']
# ['Schip1'] ['schwannomin interacting protein 1']
# ['Cebpd'] ['CCAAT/enhancer binding protein (C/EBP), delta']
# ['Gcg'] ['glucagon']
# ['Glo1'] ['glyoxalase 1']
# ['Gpc2'] ['glypican 2 (cerebroglycan)']
# ['Pkp2'] ['plakophilin 2']
# ['Glce'] ['glucuronyl C5-epimerase']
# ['Fam196a'] ['family with sequence similarity 196, member A']
# ['Thbs2'] ['thrombospondin 2']
# ['Elovl6'] ['ELOVL family member 6, elongation of long chain fatty acids (yeast)']
# ['Ccdc109b'] ['coiled-coil domain containing 109B']
# ['Rarb'] ['retinoic acid receptor, beta']
# ['Fat4'] ['FAT tumor suppressor homolog 4 (Drosophila)']
# ['Trim16'] ['tripartite motif-containing 16']
# ['Gng2'] ['guanine nucleotide binding protein (G protein), gamma 2']
# ['Pcdhac1'] ['protocadherin alpha subfamily C, 1']
# ['Phldb2'] ['pleckstrin homology-like domain, family B, member 2']
# ['3632451O06Rik'] ['RIKEN cDNA 3632451O06 gene']
# ['Pus7'] ['pseudouridylate synthase 7 homolog (S. cerevisiae)']
# ['Psg16'] ['pregnancy specific glycoprotein 16']
# ['Sh3d19'] ['SH3 domain protein D19']
# ['Ltn1'] ['listerin E3 ubiquitin protein ligase 1']
# ['Csk'] ['c-src tyrosine kinase']
# ['Ubr1'] ['ubiquitin protein ligase E3 component n-recognin 1']
# ['Tshz3'] ['teashirt zinc finger family member 3']
# ['Vopp1'] ['vesicular, overexpressed in cancer, prosurvival protein 1']
# ['Car10'] ['carbonic anhydrase 10']
# ['Nxph1'] ['neurexophilin 1']
# ['Serinc5'] ['serine incorporator 5']
# ['Rps21'] ['ribosomal protein S21']
# ['Gtdc2'] ['glycosyltransferase-like domain containing 2']
# ['Rap1gds1'] ['RAP1, GTP-GDP dissociation stimulator 1']
# ['Mcam'] ['melanoma cell adhesion molecule']
# ['B4galnt3'] ['beta-1,4-N-acetyl-galactosaminyl transferase 3']
# ['Pcdhb2'] ['protocadherin beta 2']
# ['Uaca'] ['uveal autoantigen with coiled-coil domains and ankyrin repeats']
# ['Inhba'] ['inhibin beta-A']
# ['Esrrg'] ['estrogen-related receptor gamma']
# ['Etfa'] ['electron transferring flavoprotein, alpha polypeptide']
# ['BC005764'] ['cDNA sequence BC005764']
# ['Thra'] ['thyroid hormone receptor alpha']
# ['Adam19'] ['a disintegrin and metallopeptidase domain 19 (meltrin beta)']
# ['Fbn2'] ['fibrillin 2']
# ['Rims3'] ['regulating synaptic membrane exocytosis 3']
# ['Ppp3r1'] [ 'protein phosphatase 3, regulatory subunit B, alpha isoform (calcineurin B, type I)']
# ['Ppapdc2'] ['phosphatidic acid phosphatase type 2 domain containing 2']
# ['Dmrt3'] ['doublesex and mab-3 related transcription factor 3']
# ['4833424O15Rik'] ['RIKEN cDNA 4833424O15 gene']
# ['LOC620538'] ['-']
# ['Cpne7'] ['copine VII']
# ['Slc7a3'] [ 'solute carrier family 7 (cationic amino acid transporter, y+ system), member 3']
# ['Zbtb20'] ['zinc finger and BTB domain containing 20']
# ['Tsg101'] ['tumor susceptibility gene 101']
# ['Gabrg3'] ['gamma-aminobutyric acid (GABA) A receptor, subunit gamma 3']
# ['Eif2d'] ['eukaryotic translation initiation factor 2D']
# ['Cish'] ['cytokine inducible SH2-containing protein']
# ['Ostf1'] ['osteoclast stimulating factor 1']
# ['Trpc6'] ['transient receptor potential cation channel, subfamily C, member 6']
# ['Sun2'] ['Sad1 and UNC84 domain containing 2']
# ['Shoc2'] ['soc-2 (suppressor of clear) homolog (C. elegans)']
# ['St6gal1'] ['beta galactoside alpha 2,6 sialyltransferase 1']
# ['Ptbp1'] ['polypyrimidine tract binding protein 1']
# ['Stxbp6'] ['syntaxin binding protein 6 (amisyn)']
# ['Rb1cc1'] ['RB1-inducible coiled-coil 1']
# ['Gm196'] ['gene model 196, (NCBI)']
# ['Anapc16'] ['anaphase promoting complex subunit 16']
# ['Plekhh2'] [ 'pleckstrin homology domain containing, family H (with MyTH4 domain) member 2']
# ['6820408C15Rik'] ['RIKEN cDNA 6820408C15 gene']
# ['Ptk2b'] ['PTK2 protein tyrosine kinase 2 beta']
# ['Phyhip'] ['phytanoyl-CoA hydroxylase interacting protein']
# ['Cul4a'] ['cullin 4A']
# ['Ttbk2'] ['tau tubulin kinase 2']
# ['Chl1'] ['cell adhesion molecule with homology to L1CAM']
# ['Cntnap2'] ['contactin associated protein-like 2']
# ['Ptgds'] ['prostaglandin D2 synthase (brain)']
# ['Slco1a5'] ['solute carrier organic anion transporter family, member 1a5']
# ['Sv2b'] ['synaptic vesicle glycoprotein 2 b']
# ['Zfp260'] ['zinc finger protein 260']
# ['Cst6'] ['cystatin E/M']
# ['Slc8a1'] ['solute carrier family 8 (sodium/calcium exchanger), member 1']
# ['Kcnc2'] ['potassium voltage gated channel, Shaw-related subfamily, member 2']
# ['Hebp1'] ['heme binding protein 1']
# ['Zfand3'] ['zinc finger, AN1-type domain 3']
# ['Hc'] ['hemolytic complement']
# ['Lepr'] ['leptin receptor']
# ['Zfp810'] ['zinc finger protein 810']
# ['Galp'] ['galanin-like peptide']
# ['Dtna'] ['dystrobrevin alpha']
# ['Tceb3'] ['transcription elongation factor B (SIII), polypeptide 3']
# ['Actb'] ['actin, beta']
# ['Slc27a1'] ['solute carrier family 27 (fatty acid transporter), member 1']
# ['Lypd1'] ['Ly6/Plaur domain containing 1']
# ['Fhl2'] ['four and a half LIM domains 2']
# ['Trnp1'] ['TMF1-regulated nuclear protein 1']
# ['Gpd1l'] ['glycerol-3-phosphate dehydrogenase 1-like']
# ['Sidt1'] ['SID1 transmembrane family, member 1']
# ['Npas2'] ['neuronal PAS domain protein 2']
# ['Grm5'] ['glutamate receptor, metabotropic 5']
# ['Adck4'] ['aarF domain containing kinase 4']
# ['Trem2'] ['triggering receptor expressed on myeloid cells 2']
# ['Map3k15'] ['mitogen-activated protein kinase kinase kinase 15']
# ['Cyp46a1'] ['cytochrome P450, family 46, subfamily a, polypeptide 1']
# ['Osbpl8'] ['oxysterol binding protein-like 8']
# ['Mical2'] [ 'microtubule associated monoxygenase, calponin and LIM domain containing 2']
# ['Id3'] ['inhibitor of DNA binding 3']
# ['Gpc5'] ['glypican 5']
# ['Plek'] ['pleckstrin']
# ['Elavl2'] [ 'ELAV (embryonic lethal, abnormal vision, Drosophila)-like 2 (Hu antigen B)']
# ['Chst2'] ['carbohydrate sulfotransferase 2']
# ['Flrt3'] ['fibronectin leucine rich transmembrane protein 3']
# ['Cox6a2'] ['cytochrome c oxidase, subunit VI a, polypeptide 2']
# ['Vwc2'] ['von Willebrand factor C domain containing 2']
# ['Slc30a3'] ['solute carrier family 30 (zinc transporter), member 3']
# ['Cage1'] ['cancer antigen 1']
# ['Cdh10'] ['cadherin 10']
# ['Chgb'] ['chromogranin B']
# ['Kcng3'] ['potassium voltage-gated channel, subfamily G, member 3']
# ['Palmd'] ['palmdelphin']
# ['LOC432928'] ['similar to PAPIN']
# ['Abcd2'] ['ATP-binding cassette, sub-family D (ALD), member 2']
# ['2610109H07Rik'] ['RIKEN cDNA 2610109H07 gene']
# ['Psg16'] ['pregnancy specific glycoprotein 16']
# ['Ppp2r2c'] [ 'protein phosphatase 2 (formerly 2A), regulatory subunit B (PR 52), gamma isoform']
# ['Dnajc12'] ['DnaJ (Hsp40) homolog, subfamily C, member 12']
# ['4833420G17Rik'] ['RIKEN cDNA 4833420G17 gene']
# ['Aifm3'] ['apoptosis-inducing factor, mitochondrion-associated 3']
# ['Akr1c18'] ['aldo-keto reductase family 1, member C18']
# ['Calml3'] ['calmodulin-like 3']
# ['Galnt13'] [ 'UDP-N-acetyl-alpha-D-galactosamine:polypeptide N-acetylgalactosaminyltransferase 13']
# ['Neurod1'] ['neurogenic differentiation 1']
# ['Nin'] ['ninein']
# ['Slc2a12'] ['solute carrier family 2 (facilitated glucose transporter), member 12']
# ['Arhgap26'] ['Rho GTPase activating protein 26']
# ['Auts2'] ['autism susceptibility candidate 2']
# ['Tgfb2'] ['transforming growth factor, beta 2']
# ['Gdap1l1'] ['ganglioside-induced differentiation-associated protein 1-like 1']
# ['Serpinb8'] ['serine (or cysteine) peptidase inhibitor, clade B, member 8']
# ['Enox2'] ['ecto-NOX disulfide-thiol exchanger 2']
# ['Tnip2'] ['TNFAIP3 interacting protein 2']
# ['Mapk4'] ['mitogen-activated protein kinase 4']
# ['Daf2'] ['decay accelerating factor 2']
# ['Ccng1'] ['cyclin G1']
# ['9830166N24Rik*'] ['RIKEN cDNA 9830166N24 gene (non-RefSeq)']
# ['Selk'] ['selenoprotein K']
# ['Ier3'] ['immediate early response 3']
# ['Copg'] ['coatomer protein complex, subunit gamma']
# ['Cacna2d2'] ['calcium channel, voltage-dependent, alpha 2/delta subunit 2']
# ['Akr1b3'] ['aldo-keto reductase family 1, member B3 (aldose reductase)']
# ['Sh3rf2'] ['SH3 domain containing ring finger 2']
# ['Prr15l'] ['proline rich 15-like']
# ['Inpp1'] ['inositol polyphosphate-1-phosphatase']
# ['E2f4'] ['E2F transcription factor 4']
# ['Mtfp1'] ['mitochondrial fission process 1']
# ['Celsr3'] [ 'cadherin, EGF LAG seven-pass G-type receptor 3 (flamingo homolog, Drosophila)']
# ['Tmem163'] ['transmembrane protein 163']
# ['Slc35f2'] ['solute carrier family 35, member F2']
# ['Nav2'] ['neuron navigator 2']
# ['Kcne4'] ['potassium voltage-gated channel, Isk-related subfamily, gene 4']
# ['Lhx1'] ['LIM homeobox protein 1']
# ['Pgf'] ['placental growth factor']
# ['Bhlhe41'] ['basic helix-loop-helix family, member e41']
# ['P2rx2'] ['purinergic receptor P2X, ligand-gated ion channel, 2']
# ['Gm10635'] ['predicted gene 10635']
# ['Cabp7'] ['calcium binding protein 7']
# ['Atp5sl'] ['ATP5S-like']
# ['R74862'] ['expressed sequence R74862']
# ['Mpnd'] ['MPN domain containing']
# ['Lnx2'] ['ligand of numb-protein X 2']
# ['B3galt5'] ['UDP-Gal:betaGlcNAc beta 1,3-galactosyltransferase, polypeptide 5']
# ['Eid1'] ['EP300 interacting inhibitor of differentiation 1']
# ['Tbck'] ['TBC1 domain containing kinase']
# ['B3gnt5'] ['UDP-GlcNAc:betaGal beta-1,3-N-acetylglucosaminyltransferase 5']
# ['LOC434002'] ['hypothetical gene supported by AK018238']
# ['Nrxn3'] ['neurexin III']
# ['Ptpn4'] ['protein tyrosine phosphatase, non-receptor type 4']
# ['Prex1'] ['phosphatidylinositol-3,4,5-trisphosphate-dependent Rac exchange factor 1']
# ['Chml'] ['choroideremia-like']
# ['Gnal'] ['guanine nucleotide binding protein, alpha stimulating, olfactory type']
# ['Psmd11'] ['proteasome (prosome, macropain) 26S subunit, non-ATPase, 11']
# ['Cdh18'] ['cadherin 18']
# ['Dchs1'] ['dachsous 1 (Drosophila)']
# ['Mocs1'] ['molybdenum cofactor synthesis 1']
# ['Arl15'] ['ADP-ribosylation factor-like 15']
# ['Pde8b'] ['phosphodiesterase 8B']
# ['Arpp21'] ['cyclic AMP-regulated phosphoprotein, 21']
# ['Kcnj2'] ['potassium inwardly-rectifying channel, subfamily J, member 2']
# ['Uqcrfs1'] ['ubiquinol-cytochrome c reductase, Rieske iron-sulfur polypeptide 1']
# ['Igsf3'] ['immunoglobulin superfamily, member 3']
# ['Nucb2'] ['nucleobindin 2']
# ['Trhr'] ['thyrotropin releasing hormone receptor']
# ['Prlhr'] ['prolactin releasing hormone receptor']
# ['Hint1'] ['histidine triad nucleotide binding protein 1']
# ['Rgs12'] ['regulator of G-protein signaling 12']
# ['Pcsk1'] ['proprotein convertase subtilisin/kexin type 1']
# ['Yjefn3'] ['YjeF N-terminal domain containing 3']
# ['Maged2'] ['melanoma antigen, family D, 2']
# ['Stk38l'] ['serine/threonine kinase 38 like']
# ['Adcy4'] ['adenylate cyclase 4']
# ['Gsn'] ['gelsolin']
# ['Stx12'] ['syntaxin 12']
# ['Mmel1'] ['membrane metallo-endopeptidase-like 1']
# ['AW046396'] ['expressed sequence AW046396']
# ['Tead1'] ['TEA domain family member 1']
# ['Gja1'] ['gap junction protein, alpha 1']
# ['Tspan18'] ['tetraspanin 18']
# ['Sprn'] ['shadow of prion protein']
# ['Megf10'] ['multiple EGF-like-domains 10']
# ['4932418E24Rik'] ['RIKEN cDNA 4932418E24 gene']
# ['Kcnj2'] ['potassium inwardly-rectifying channel, subfamily J, member 2']
# ['Gsta4'] ['glutathione S-transferase, alpha 4']
# ['Cdh11'] ['cadherin 11']
# ['Cda'] ['cytidine deaminase']
# ['Nts'] ['neurotensin']
# ['Sc5d'] [ 'sterol-C5-desaturase (fungal ERG3, delta-5-desaturase) homolog (S. cerevisae)']
# ['Slc9a6'] ['solute carrier family 9 (sodium/hydrogen exchanger), member 6']
# ['Sostdc1'] ['sclerostin domain containing 1']
# ['Atp2a2'] ['ATPase, Ca++ transporting, cardiac muscle, slow twitch 2']
# ['Penk'] ['preproenkephalin']
# ['C530008M17Rik'] ['RIKEN cDNA C530008M17 gene']
# ['Pcdh11x'] ['protocadherin 11 X-linked']
# ['Lypd6'] ['LY6/PLAUR domain containing 6']
# ['Pvr'] ['poliovirus receptor']
# ['LOC544975'] ['-']
# ['Gbe1'] ['glucan (1,4-alpha-), branching enzyme 1']
# ['Clcn5'] ['chloride channel 5']
# ['St6galnac5'] [ 'ST6 (alpha-N-acetyl-neuraminyl-2,3-beta-galactosyl-1,3)-N-acetylgalactosaminide alpha-2,6-sialyltransferase 5']
# ['Pknox2'] ['Pbx/knotted 1 homeobox 2']
# ['Pcdh7'] ['protocadherin 7']
# ['Tmed3'] ['transmembrane emp24 domain containing 3']
# ['Zfp932'] ['zinc finger protein 932']
# ['Efr3a'] ['EFR3 homolog A (S. cerevisiae)']
# ['Zfp189'] ['zinc finger protein 189']
# ['Ckb'] ['creatine kinase, brain']
# ['Gucy2c'] ['guanylate cyclase 2c']
# ['Slc6a3'] [ 'solute carrier family 6 (neurotransmitter transporter, dopamine), member 3']
# ['Ssbp4'] ['single stranded DNA binding protein 4']
# ['Dnajc6'] ['DnaJ (Hsp40) homolog, subfamily C, member 6']
# ['Ccr10'] ['chemokine (C-C motif) receptor 10']
# ['Ublcp1'] ['ubiquitin-like domain containing CTD phosphatase 1']
# ['Zfp330'] ['zinc finger protein 330']
# ['Col5a3'] ['collagen, type V, alpha 3']
# ['Heg1'] ['HEG homolog 1 (zebrafish)']
# ['Adamts4'] [ 'a disintegrin-like and metallopeptidase (reprolysin type) with thrombospondin type 1 motif, 4']
# ['Creg1'] ['cellular repressor of E1A-stimulated genes 1']
# ['Gipc2'] ['GIPC PDZ domain containing family, member 2']
# ['Arhgef5'] ['Rho guanine nucleotide exchange factor (GEF) 5']
# ['Ctbp2'] ['C-terminal binding protein 2']
# ['Gabrq'] ['gamma-aminobutyric acid (GABA) A receptor, subunit theta']
# ['Ust'] ['uronyl-2-sulfotransferase']

# %%
# Save into matlab formats
sio.savemat('allen_genes.mat',{'allen_genes':gene_name})
sio.savemat('allen_gene_desc.mat',{'allen_gene_desc':gene_desc})

# %% [markdown]
# # APPENDIX: code to download all the data
# ## NOTE: expression data will take a long time to download...

# %%
# Initialise libraries, set dataset paths and generate queries
API_PATH = "http://api.brain-map.org/api/v2/data"
GRAPH_ID = 1
MOUSE_PRODUCT_ID = 1 # aba
PLANE_ID = 1 # coronal
TOP_N = 20000

DATA_SET_QUERY_URL = ("%s/SectionDataSet/query.json" +\
                          "?criteria=[failed$eq'false'][expression$eq'true']" +\
                          ",products[id$eq%d]" +\
                          ",plane_of_section[id$eq%d]") \
                          % (API_PATH, MOUSE_PRODUCT_ID, PLANE_ID)

UNIONIZE_FMT = "%s/StructureUnionize/query.json" +\
    "?criteria=[section_data_set_id$eq%d]" +\
    "&include=section_data_set(products[id$eq%d])" % (MOUSE_PRODUCT_ID)

STRUCTURES_URL = ("%s/Structure/query.json?" +\
                      "criteria=[graph_id$eq%d]") \
                      % (API_PATH, GRAPH_ID)

import json
import sys
import os
import string

from urllib.request import urlopen

def QueryAPI(url):
    start_row = 0
    num_rows = 20000
    total_rows = -1
    rows = []
    done = False
    
    while not done:
        pagedUrl = url + '&start_row=%d&num_rows=%d' % (start_row,num_rows)

        print(pagedUrl)
        source = urlopen(pagedUrl).read().decode('utf8') # py3
#         source = urllib.urlopen(pagedUrl).read()

        response = json.loads(source)
        rows += response['msg']
        
        if total_rows < 0:
            total_rows = int(response['total_rows'])

        start_row += len(response['msg'])

        if start_row >= total_rows:
            done = True

    return rows

# %%
# Download and save dataset list
def DownloadDataSets(n):
    dataSets = QueryAPI(DATA_SET_QUERY_URL)
  
    if n <= 0:
        return dataSets
    else:
        n = min(len(dataSets), n)

    return dataSets[:n]

n = -1
dataSets = DownloadDataSets(n)

f = open('dataSets.json', "w")
f.write(json.dumps(dataSets))
f.close()
# Out:
# http://api.brain-map.org/api/v2/data/SectionDataSet/query.json?criteria=[failed$eq'false'][expression$eq'true'],products[id$eq1],plane_of_section[id$eq1]&start_row=0&num_rows=20000

# %%
# Download and save structure data

def DownloadStructures():
    structs = QueryAPI(STRUCTURES_URL)

    # Build a dict from structure id to structure and identify each node's
    # direct descendants.
    structHash = {}
    for s in structs:
        s['num_children'] = 0
        s['structure_id_path'] = [
            int(sid) for sid in s['structure_id_path'].split('/') if sid != '']
        structHash[s['id']] = s

        # python 3 renamed iteritems to items
    for sid, s in structHash.items():
        if len(s['structure_id_path']) > 1:
            parentId = s['structure_id_path'][-2]
            structHash[parentId]['num_children'] += 1

    # pull out the structure ids for structures in this structure graph that
    # have no children (i.e. just the leaves)
    corrStructIds = [sid for sid, s in structHash.items() if s[
        'num_children'] == 0]

    return sorted(corrStructIds), structHash

structureIds, structHash = DownloadStructures()

# Save structureIds and structHash
f = open('structureIds.json', "w")
f.write(json.dumps(structureIds))
f.close()

f = open('structHash.json', "w")
f.write(json.dumps(structHash))
f.close()
# Out:
# http://api.brain-map.org/api/v2/data/Structure/query.json?criteria=[graph_id$eq1]&start_row=0&num_rows=20000

# %%
# Download expression data, but save as you go
def QueryAPI_saving(url,f_id):
    start_row = 0
    num_rows = 20000
    total_rows = -1
    rows = []
    done = False
    
    while not done:
        pagedUrl = url + '&start_row=%d&num_rows=%d' % (start_row,num_rows)

        print(pagedUrl)
        source = urlopen(pagedUrl).read().decode('utf8') # py3
#         source = urllib.urlopen(pagedUrl).read()

        response = json.loads(source)
        rows += response['msg']
        
        if total_rows < 0:
            total_rows = int(response['total_rows'])

        start_row += len(response['msg'])

        if start_row >= total_rows:
            done = True
            
            # Parse url to get dataset name
            
            
            print(f_id)
            fname = "expression_"+ f_id +".json"
            # save as you go
            f = open(fname,"w")
            f.write(json.dumps(rows))
            f.close()
            

    return rows

# %%
# Download expression data and save as you go.
def DownloadExpression(dataSets):
    return [QueryAPI_saving(UNIONIZE_FMT % (API_PATH,d['id']),str(d['id'])) for d in dataSets]
#     return [QueryAPI(UNIONIZE_FMT % (API_PATH,d['id'])) for d in dataSets]

# %%
# example small download
mini_data = dataSets[:5]
unionizes = DownloadExpression(mini_data)
# Out:
# http://api.brain-map.org/api/v2/data/StructureUnionize/query.json?criteria=[section_data_set_id$eq74581394]&include=section_data_set(products[id$eq1])&start_row=0&num_rows=20000
# 74581394
# http://api.brain-map.org/api/v2/data/StructureUnionize/query.json?criteria=[section_data_set_id$eq73931634]&include=section_data_set(products[id$eq1])&start_row=0&num_rows=20000
# 73931634
# http://api.brain-map.org/api/v2/data/StructureUnionize/query.json?criteria=[section_data_set_id$eq75774111]&include=section_data_set(products[id$eq1])&start_row=0&num_rows=20000
# 75774111
# http://api.brain-map.org/api/v2/data/StructureUnionize/query.json?criteria=[section_data_set_id$eq73929596]&include=section_data_set(products[id$eq1])&start_row=0&num_rows=20000
# 73929596
# http://api.brain-map.org/api/v2/data/StructureUnionize/query.json?criteria=[section_data_set_id$eq74958463]&include=section_data_set(products[id$eq1])&start_row=0&num_rows=20000
# 74958463
