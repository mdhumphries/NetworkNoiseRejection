# %% [markdown]
# # Loading and concatenating allen gene data

# %%
import numpy as np
import pandas as pd
import glob
import json
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# generate list of files, then load and concatenate them
x = glob.glob('/media/mathew/Data_2/Allen_genes/api-examples/structures/raw_expression*')
rows = pd.read_json(x[2])
#for i in range(10):
#    rows = rows.append(pd.read_json(x[i+1]))
    
rows
# Out:
#       expression_density  expression_energy         id  \
# 0               0.053474            8.90860  450107570
# 1               0.053474            8.90860  450107573
# 2               0.048175            7.88153  450107576
# 3               0.044946            7.53617  450107583
# 4               0.048972            8.28153  450107588
# 5               0.059814           11.27490  450107590
# 6               0.048840            8.24512  450107595
# 7               0.050490            8.55761  450107600
# 8               0.056617            9.65109  450107602
# 9               0.056617            9.65109  450107604
# 10              0.053277            9.74699  450107608
# 11              0.053277            9.74699  450107609
# 12              0.064745           11.32320  450107614
# 13              0.064745           11.32320  450107617
# 14              0.047198            7.63497  450107621
# 15              0.047198            7.63497  450107623
# 16              0.048535            8.09105  450107627
# 17              0.048535            8.09105  450107630
# 18              0.076415           14.44700  450107635
# 19              0.085009           16.26310  450107637
# 20              0.071337           13.37380  450107642
# 21              0.041234            6.44663  450107648
# 22              0.044832            7.18261  450107651
# 23              0.042188            6.58149  450107655
# 24              0.017878            2.87694  450107659
# 25              0.017878            2.87694  450107662
# 26              0.052152            9.01888  450107665
# 27              0.052152            9.01888  450107669
# 28              0.058449           10.39290  450107673
# 29              0.102241           20.42910  450107678
# ...                  ...                ...        ...
# 2415            0.077113           13.41650  450141169
# 2416            0.045760            7.31771  450141229
# 2417            0.043039            6.54324  450141241
# 2418            0.047536            7.49895  450141265
# 2419            0.046343            7.78842  450141278
# 2420            0.088851           16.19980  450141388
# 2421            0.042116            6.61736  450141434
# 2422            0.061465           10.23640  450141536
# 2423            0.047985            8.83819  450141593
# 2424            0.050584            7.82995  450141666
# 2425            0.059000            9.93314  450141883
# 2426            0.056514            9.35645  450141962
# 2427            0.063774           10.42280  450142023
# 2428            0.083918           14.85500  450142115
# 2429            0.047599            7.36575  450142162
# 2430            0.046376            7.30769  450142229
# 2431            0.046451            7.29722  450142251
# 2432            0.044794            6.99233  450142271
# 2433            0.055938            8.99646  450142281
# 2434            0.063920           10.63640  450142327
# 2435            0.124354           24.58690  450142367
# 2436            0.044074            6.71161  450142469
# 2437            0.095531           17.06450  450142565
# 2438            0.049738            9.11263  450142584
# 2439            0.081438           14.47210  450142602
# 2440            0.064394           10.55100  450142659
# 2441            0.066237           10.83800  450142945
# 2442            0.077420           13.45520  450143030
# 2443            0.116708           21.09160  450143141
# 2444            0.043199            7.16580  450143215
#
#                                        section_data_set  section_data_set_id  \
# 0     {'delegate': False, 'qc_date': '2009-05-02T23:...             74581394
# 1     {'delegate': False, 'qc_date': '2009-05-02T23:...             74581394
# 2     {'delegate': False, 'qc_date': '2009-05-02T23:...             74581394
# 3     {'delegate': False, 'qc_date': '2009-05-02T23:...             74581394
# 4     {'delegate': False, 'qc_date': '2009-05-02T23:...             74581394
# 5     {'delegate': False, 'qc_date': '2009-05-02T23:...             74581394
# 6     {'delegate': False, 'qc_date': '2009-05-02T23:...             74581394
# 7     {'delegate': False, 'qc_date': '2009-05-02T23:...             74581394
# 8     {'delegate': False, 'qc_date': '2009-05-02T23:...             74581394
# 9     {'delegate': False, 'qc_date': '2009-05-02T23:...             74581394
# 10    {'delegate': False, 'qc_date': '2009-05-02T23:...             74581394
# 11    {'delegate': False, 'qc_date': '2009-05-02T23:...             74581394
# 12    {'delegate': False, 'qc_date': '2009-05-02T23:...             74581394
# 13    {'delegate': False, 'qc_date': '2009-05-02T23:...             74581394
# 14    {'delegate': False, 'qc_date': '2009-05-02T23:...             74581394
# 15    {'delegate': False, 'qc_date': '2009-05-02T23:...             74581394
# 16    {'delegate': False, 'qc_date': '2009-05-02T23:...             74581394
# 17    {'delegate': False, 'qc_date': '2009-05-02T23:...             74581394
# 18    {'delegate': False, 'qc_date': '2009-05-02T23:...             74581394
# 19    {'delegate': False, 'qc_date': '2009-05-02T23:...             74581394
# 20    {'delegate': False, 'qc_date': '2009-05-02T23:...             74581394
# 21    {'delegate': False, 'qc_date': '2009-05-02T23:...             74581394
# 22    {'delegate': False, 'qc_date': '2009-05-02T23:...             74581394
# 23    {'delegate': False, 'qc_date': '2009-05-02T23:...             74581394
# 24    {'delegate': False, 'qc_date': '2009-05-02T23:...             74581394
# 25    {'delegate': False, 'qc_date': '2009-05-02T23:...             74581394
# 26    {'delegate': False, 'qc_date': '2009-05-02T23:...             74581394
# 27    {'delegate': False, 'qc_date': '2009-05-02T23:...             74581394
# 28    {'delegate': False, 'qc_date': '2009-05-02T23:...             74581394
# 29    {'delegate': False, 'qc_date': '2009-05-02T23:...             74581394
# ...                                                 ...                  ...
# 2415  {'delegate': False, 'qc_date': '2009-05-02T23:...             74581394
# 2416  {'delegate': False, 'qc_date': '2009-05-02T23:...             74581394
# 2417  {'delegate': False, 'qc_date': '2009-05-02T23:...             74581394
# 2418  {'delegate': False, 'qc_date': '2009-05-02T23:...             74581394
# 2419  {'delegate': False, 'qc_date': '2009-05-02T23:...             74581394
# 2420  {'delegate': False, 'qc_date': '2009-05-02T23:...             74581394
# 2421  {'delegate': False, 'qc_date': '2009-05-02T23:...             74581394
# 2422  {'delegate': False, 'qc_date': '2009-05-02T23:...             74581394
# 2423  {'delegate': False, 'qc_date': '2009-05-02T23:...             74581394
# 2424  {'delegate': False, 'qc_date': '2009-05-02T23:...             74581394
# 2425  {'delegate': False, 'qc_date': '2009-05-02T23:...             74581394
# 2426  {'delegate': False, 'qc_date': '2009-05-02T23:...             74581394
# 2427  {'delegate': False, 'qc_date': '2009-05-02T23:...             74581394
# 2428  {'delegate': False, 'qc_date': '2009-05-02T23:...             74581394
# 2429  {'delegate': False, 'qc_date': '2009-05-02T23:...             74581394
# 2430  {'delegate': False, 'qc_date': '2009-05-02T23:...             74581394
# 2431  {'delegate': False, 'qc_date': '2009-05-02T23:...             74581394
# 2432  {'delegate': False, 'qc_date': '2009-05-02T23:...             74581394
# 2433  {'delegate': False, 'qc_date': '2009-05-02T23:...             74581394
# 2434  {'delegate': False, 'qc_date': '2009-05-02T23:...             74581394
# 2435  {'delegate': False, 'qc_date': '2009-05-02T23:...             74581394
# 2436  {'delegate': False, 'qc_date': '2009-05-02T23:...             74581394
# 2437  {'delegate': False, 'qc_date': '2009-05-02T23:...             74581394
# 2438  {'delegate': False, 'qc_date': '2009-05-02T23:...             74581394
# 2439  {'delegate': False, 'qc_date': '2009-05-02T23:...             74581394
# 2440  {'delegate': False, 'qc_date': '2009-05-02T23:...             74581394
# 2441  {'delegate': False, 'qc_date': '2009-05-02T23:...             74581394
# 2442  {'delegate': False, 'qc_date': '2009-05-02T23:...             74581394
# 2443  {'delegate': False, 'qc_date': '2009-05-02T23:...             74581394
# 2444  {'delegate': False, 'qc_date': '2009-05-02T23:...             74581394
#
#       structure_id  sum_expressing_pixel_intensity  sum_expressing_pixels  \
# 0            15564                     17567800000           1.054510e+08
# 1            15565                     17567800000           1.054510e+08
# 2            15566                     10524900000           6.433290e+07
# 3            15568                       300947000           1.794850e+06
# 4            15569                       120519000           7.126800e+05
# 5            15570                         1971360           1.045820e+04
# 6            15576                       118547000           7.022220e+05
# 7            15577                       100994000           5.958690e+05
# 8            15578                         7762250           4.553660e+04
# 9            15580                         7762250           4.553660e+04
# 10           15581                          340841           1.863040e+03
# 11           15582                          340841           1.863040e+03
# 12           15583                         4751530           2.716890e+04
# 13           15584                         4751530           2.716890e+04
# 14           15585                         2669870           1.650460e+04
# 15           15586                         2669870           1.650460e+04
# 16           15587                        51906500           3.113670e+05
# 17           15589                        51906500           3.113670e+05
# 18           15590                        17681900           9.352590e+04
# 19           15591                         7393180           3.864490e+04
# 20           15592                        10288700           5.488100e+04
# 21           15594                          450864           2.883790e+03
# 22           15595                         8539740           5.330330e+04
# 23           15596                        24731000           1.585280e+05
# 24           15597                          502992           3.125810e+03
# 25           15598                          502992           3.125810e+03
# 26           15599                        41325200           2.389660e+05
# 27           15601                        41325200           2.389660e+05
# 28           15602                        31979200           1.798490e+05
# 29           15603                        11428500           5.719620e+04
# ...            ...                             ...                    ...
# 2415           989                        27211400           1.564010e+05
# 2416           998                        11001500           6.879550e+04
# 2417           999                         4106580           2.701160e+04
# 2418          1004                         4195690           2.659650e+04
# 2419          1005                         5152800           3.066020e+04
# 2420          1017                       807933000           4.431280e+06
# 2421          1022                        54580600           3.473790e+05
# 2422          1034                        18613700           1.117660e+05
# 2423          1041                       231479000           1.256770e+06
# 2424          1048                        93093800           6.014170e+05
# 2425          1072                        11810000           7.014800e+04
# 2426          1079                        19958300           1.205500e+05
# 2427          1084                        55400400           3.389790e+05
# 2428          1091                       459088000           2.593460e+06
# 2429          1096                         9018000           5.827610e+04
# 2430          1104                         2091020           1.327000e+04
# 2431          1106                        13131100           8.358780e+04
# 2432          1109                          978059           6.265660e+03
# 2433          1110                         6606540           4.107830e+04
# 2434          1118                         2603620           1.564660e+04
# 2435          1126                         1719560           8.697100e+03
# 2436          1142                        12905200           8.474570e+04
# 2437         10684                        86524800           4.843840e+05
# 2438         10687                       102091000           5.572310e+05
# 2439         10690                        46558800           2.619970e+05
# 2440         10697                        18079000           1.103390e+05
# 2441         10700                        26908500           1.644540e+05
# 2442         10713                        88456700           5.089730e+05
# 2443         10735                        54578900           3.020050e+05
# 2444     182305713                         3006970           1.812750e+04
#
#       sum_pixel_intensity    sum_pixels  voxel_energy_cv  voxel_energy_mean
# 0             97598900000  1.972000e+09         0.527604            8.89557
# 1             97598900000  1.972000e+09         0.527604            8.89557
# 2             64605900000  1.335390e+09         0.483118            7.87337
# 3              1723840000  3.993370e+07         0.623599            7.54407
# 4               671011000  1.455270e+07         0.535451            8.27926
# 5                 7942690  1.748450e+05         0.610797           11.27490
# 6               663068000  1.437790e+07         0.533243            8.24300
# 7               556101000  1.180170e+07         0.533505            8.55182
# 8                40481700  8.042870e+05         0.311448            9.65109
# 9                40481700  8.042870e+05         0.311448            9.65109
# 10                1810440  3.496880e+04         0.000000            0.00000
# 11                1810440  3.496880e+04         0.000000            0.00000
# 12               21987500  4.196280e+05         0.262226           11.32320
# 13               21987500  4.196280e+05         0.262226           11.32320
# 14               16683800  3.496900e+05         0.229281            7.63497
# 15               16683800  3.496900e+05         0.229281            7.63497
# 16              288795000  6.415290e+06         0.522000            8.08781
# 17              288795000  6.415290e+06         0.522000            8.08781
# 18               65429200  1.223910e+06         0.425947           14.44700
# 19               25175900  4.545970e+05         0.341908           16.26310
# 20               40253400  7.693180e+05         0.475221           13.37380
# 21                3095640  6.993800e+04         0.152544            6.44663
# 22               54462900  1.188950e+06         0.153191            7.18261
# 23              161425000  3.757660e+06         0.145281            6.58357
# 24                4381720  1.748360e+05         0.450324            2.87684
# 25                4381720  1.748360e+05         0.450324            2.87684
# 26              226824000  4.582070e+06         0.572265            9.00708
# 27              226824000  4.582070e+06         0.572265            9.00708
# 28              165245000  3.077020e+06         0.550656           10.39300
# 29               38562700  5.594240e+05         0.137153           20.42920
# ...                   ...           ...              ...                ...
# 2415            117591000  2.028200e+06         0.494882           13.41650
# 2416             69655000  1.503410e+06         0.107734            7.31773
# 2417             28388500  6.276070e+05         0.132730            6.54367
# 2418             23570000  5.595040e+05         0.285611            7.49895
# 2419             32444500  6.615980e+05         0.244359            7.78587
# 2420           3288990000  4.987310e+07         0.229173           16.19440
# 2421            387899000  8.248090e+06         0.162890            6.58856
# 2422             81794300  1.818390e+06         0.198914           10.23640
# 2423            938126000  2.619070e+07         1.190790            8.74876
# 2424            567061000  1.188950e+07         0.140526            7.82994
# 2425             66425800  1.188950e+06         0.249418            9.93314
# 2426            116699000  2.133110e+06         0.316427            9.35645
# 2427            271746000  5.315290e+06         0.268288           10.42280
# 2428           1911800000  3.090460e+07         0.226049           14.85330
# 2429             60537700  1.224320e+06         0.105022            7.38000
# 2430             14342800  2.861390e+05         0.106301            7.36330
# 2431             85714800  1.799470e+06         0.206018            7.36139
# 2432              6413800  1.398760e+05         0.046926            6.99233
# 2433             41311800  7.343490e+05         0.123975            8.99646
# 2434             15303600  2.447830e+05         0.133494           10.63640
# 2435              4167370  6.993800e+04         0.097914           24.58690
# 2436            101361000  1.922820e+06         0.159429            6.71110
# 2437            330570000  5.070460e+06         0.374337           17.06450
# 2438            406554000  1.120330e+07         1.099320            9.02497
# 2439            184279000  3.217150e+06         0.598016           14.47210
# 2440             89090200  1.713480e+06         0.164385           10.55100
# 2441            129424000  2.482800e+06         0.233369           10.83800
# 2442            390951000  6.574170e+06         0.245314           13.45520
# 2443            196785000  2.587710e+06         0.376194           21.09160
# 2444             19145600  4.196280e+05         0.238823            7.16580
#
# [2445 rows x 12 columns]

# %%
# Python list version of above (instead of pd.dataframe)
x = glob.glob('/media/mathew/Data_2/Allen_genes/api-examples/structures/raw_expression*')
# x = glob.glob('/Users/mathew/Dropbox/Data/allen_genes/raw_expression*')
my_union = []
# NOTE: first two files are not gene expression, so need to be avoided. Last item is also bad.
# TO DO: change for loop to reflect this
for i in range(len(x)):
    with open(x[i]) as json_data:
        my_union.append(json.load(json_data))
# Out:
# ---------------------------------------------------------------------------
# IsADirectoryError                         Traceback (most recent call last)
# <ipython-input-9-a39eee2768b2> in <module>()
#       4 my_union = []
#       5 for i in range(len(x)):
# ----> 6     with open(x[i]) as json_data:
#       7         my_union.append(json.load(json_data))
#       8
#
# IsADirectoryError: [Errno 21] Is a directory: '/media/mathew/Data_2/Allen_genes/api-examples/structures/raw_expression_json'

# %%
#my_union?
del my_union[0]
del my_union[0]
my_union[0]
# Out:
# [{'expression_density': 0.0534739,
#   'expression_energy': 8.9086,
#   'id': 450107570,
#   'section_data_set': {'blue_channel': None,
#    'delegate': False,
#    'expression': True,
#    'failed': False,
#    'failed_facet': 734881840,
#    'green_channel': None,
#    'id': 74581394,
#    'name': None,
#    'plane_of_section_id': 1,
#    'products': [{'abbreviation': 'Mouse',
#      'description': 'Genome-wide, high-resolution ISH data detailing gene expression throughout the adult mouse brain.',
#      'id': 1,
#      'name': 'Mouse Brain',
#      'product_name_facet': 2757464828,
#      'resource': 'Allen Mouse Brain Atlas',
#      'species': 'Mouse',
#      'species_name_facet': 1861523945,
#      'tags': None}],
#    'qc_date': '2009-05-02T23:04:42Z',
#    'red_channel': None,
#    'reference_space_id': 9,
#    'rnaseq_design_id': None,
#    'section_thickness': 25.0,
#    'specimen_id': 73633987,
#    'sphinx_id': 18581,
#    'storage_directory': '/external/aibssan/production32/prod340/image_series_74581394/',
#    'weight': 5270},
#   'section_data_set_id': 74581394,
#   'structure_id': 15564,
#   'sum_expressing_pixel_intensity': 17567800000.0,
#   'sum_expressing_pixels': 105451000.0,
#   'sum_pixel_intensity': 97598900000.0,
#   'sum_pixels': 1972000000.0,
#   'voxel_energy_cv': 0.527604,
#   'voxel_energy_mean': 8.89557},
#  {'expression_density': 0.0534739,
#   'expression_energy': 8.9086,
#   'id': 450107573,
#   'section_data_set': {'blue_channel': None,
#    'delegate': False,
#    'expression': True,
#    'failed': False,
#    'failed_facet': 734881840,
#    'green_channel': None,
#    'id': 74581394,
#    'name': None,
#    'plane_of_section_id': 1,
#    'products': [{'abbreviation': 'Mouse',
#      'description': 'Genome-wide, high-resolution ISH data detailing gene expression throughout the adult mouse brain.',
#      'id': 1,
#      'name': 'Mouse Brain',
#      'product_name_facet': 2757464828,
#      'resource': 'Allen Mouse Brain Atlas',
#      'species': 'Mouse',
#      'species_name_facet': 1861523945,
#      'tags': None}],
#    'qc_date': '2009-05-02T23:04:42Z',
#    'red_channel': None,
#    'reference_space_id': 9,
#    'rnaseq_design_id': None,
#    'section_thickness': 25.0,
#    'specimen_id': 73633987,
#    'sphinx_id': 18581,
#    'storage_directory': '/external/aibssan/production32/prod340/image_series_74581394/',
#    'weight': 5270},
#   'section_data_set_id': 74581394,
#   'structure_id': 15565,
#   'sum_expressing_pixel_intensity': 17567800000.0,
#   'sum_expressing_pixels': 105451000.0,
#   'sum_pixel_intensity': 97598900000.0,
#   'sum_pixels': 1972000000.0,
#   'voxel_energy_cv': 0.527604,
#   'voxel_energy_mean': 8.89557},
#  {'expression_density': 0.0481755,
#   'expression_energy': 7.88153,
#   'id': 450107576,
#   'section_data_set': {'blue_channel': None,
#    'delegate': False,
#    'expression': True,
#    'failed': False,
#    'failed_facet': 734881840,
#    'green_channel': None,
#    'id': 74581394,
#    'name': None,
#    'plane_of_section_id': 1,
#    'products': [{'abbreviation': 'Mouse',
#      'description': 'Genome-wide, high-resolution ISH data detailing gene expression throughout the adult mouse brain.',
#      'id': 1,
#      'name': 'Mouse Brain',
#      'product_name_facet': 2757464828,
#      'resource': 'Allen Mouse Brain Atlas',
#      'species': 'Mouse',
#      'species_name_facet': 1861523945,
#      'tags': None}],
#    'qc_date': '2009-05-02T23:04:42Z',
#    'red_channel': None,
#    'reference_space_id': 9,
#    'rnaseq_design_id': None,
#    'section_thickness': 25.0,
#    'specimen_id': 73633987,
#    'sphinx_id': 18581,
#    'storage_directory': '/external/aibssan/production32/prod340/image_series_74581394/',
#    'weight': 5270},
#   'section_data_set_id': 74581394,
#   'structure_id': 15566,
#   'sum_expressing_pixel_intensity': 10524900000.0,
#   'sum_expressing_pixels': 64332900.0,
#   'sum_pixel_intensity': 64605900000.0,
#   'sum_pixels': 1335390000.0,
#   'voxel_energy_cv': 0.483118,
#   'voxel_energy_mean': 7.87337},
#  {'expression_density': 0.0449458,
#   'expression_energy': 7.53617,
#   'id': 450107583,
#   'section_data_set': {'blue_channel': None,
#    'delegate': False,
#    'expression': True,
#    'failed': False,
#    'failed_facet': 734881840,
#    'green_channel': None,
#    'id': 74581394,
#    'name': None,
#    'plane_of_section_id': 1,
#    'products': [{'abbreviation': 'Mouse',
#      'description': 'Genome-wide, high-resolution ISH data detailing gene expression throughout the adult mouse brain.',
#      'id': 1,
#      'name': 'Mouse Brain',
#      'product_name_facet': 2757464828,
#      'resource': 'Allen Mouse Brain Atlas',
#      'species': 'Mouse',
#      'species_name_facet': 1861523945,
#      'tags': None}],
#    'qc_date': '2009-05-02T23:04:42Z',
#    'red_channel': None,
#    'reference_space_id': 9,
#    'rnaseq_design_id': None,
#    'section_thickness': 25.0,
#    'specimen_id': 73633987,
#    'sphinx_id': 18581,
#    'storage_directory': '/external/aibssan/production32/prod340/image_series_74581394/',
#    'weight': 5270},
#   'section_data_set_id': 74581394,
#   'structure_id': 15568,
#   'sum_expressing_pixel_intensity': 300947000.0,
#   'sum_expressing_pixels': 1794850.0,
#   'sum_pixel_intensity': 1723840000.0,
#   'sum_pixels': 39933700.0,
#   'voxel_energy_cv': 0.623599,
#   'voxel_energy_mean': 7.54407},
#  {'expression_density': 0.0489724,
#   'expression_energy': 8.28153,
#   'id': 450107588,
#   'section_data_set': {'blue_channel': None,
#    'delegate': False,
#    'expression': True,
#    'failed': False,
#    'failed_facet': 734881840,
#    'green_channel': None,
#    'id': 74581394,
#    'name': None,
#    'plane_of_section_id': 1,
#    'products': [{'abbreviation': 'Mouse',
#      'description': 'Genome-wide, high-resolution ISH data detailing gene expression throughout the adult mouse brain.',
#      'id': 1,
#      'name': 'Mouse Brain',
#      'product_name_facet': 2757464828,
#      'resource': 'Allen Mouse Brain Atlas',
#      'species': 'Mouse',
#      'species_name_facet': 1861523945,
#      'tags': None}],
#    'qc_date': '2009-05-02T23:04:42Z',
#    'red_channel': None,
#    'reference_space_id': 9,
#    'rnaseq_design_id': None,
#    'section_thickness': 25.0,
#    'specimen_id': 73633987,
#    'sphinx_id': 18581,
#    'storage_directory': '/external/aibssan/production32/prod340/image_series_74581394/',
#    'weight': 5270},
#   'section_data_set_id': 74581394,
#   'structure_id': 15569,
#   'sum_expressing_pixel_intensity': 120519000.0,
#   'sum_expressing_pixels': 712680.0,
#   'sum_pixel_intensity': 671011000.0,
#   'sum_pixels': 14552700.0,
#   'voxel_energy_cv': 0.535451,
#   'voxel_energy_mean': 8.27926},
#  {'expression_density': 0.059814,
#   'expression_energy': 11.2749,
#   'id': 450107590,
#   'section_data_set': {'blue_channel': None,
#    'delegate': False,
#    'expression': True,
#    'failed': False,
#    'failed_facet': 734881840,
#    'green_channel': None,
#    'id': 74581394,
#    'name': None,
#    'plane_of_section_id': 1,
#    'products': [{'abbreviation': 'Mouse',
#      'description': 'Genome-wide, high-resolution ISH data detailing gene expression throughout the adult mouse brain.',
#      'id': 1,
#      'name': 'Mouse Brain',
#      'product_name_facet': 2757464828,
#      'resource': 'Allen Mouse Brain Atlas',
#      'species': 'Mouse',
#      'species_name_facet': 1861523945,
#      'tags': None}],
#    'qc_date': '2009-05-02T23:04:42Z',
#    'red_channel': None,
#    'reference_space_id': 9,
#    'rnaseq_design_id': None,
#    'section_thickness': 25.0,
#    'specimen_id': 73633987,
#    'sphinx_id': 18581,
#    'storage_directory': '/external/aibssan/production32/prod340/image_series_74581394/',
#    'weight': 5270},
#   'section_data_set_id': 74581394,
#   'structure_id': 15570,
#   'sum_expressing_pixel_intensity': 1971360.0,
#   'sum_expressing_pixels': 10458.2,
#   'sum_pixel_intensity': 7942690.0,
#   'sum_pixels': 174845.0,
#   'voxel_energy_cv': 0.610797,
#   'voxel_energy_mean': 11.2749},
#  {'expression_density': 0.0488405,
#   'expression_energy': 8.24512,
#   'id': 450107595,
#   'section_data_set': {'blue_channel': None,
#    'delegate': False,
#    'expression': True,
#    'failed': False,
#    'failed_facet': 734881840,
#    'green_channel': None,
#    'id': 74581394,
#    'name': None,
#    'plane_of_section_id': 1,
#    'products': [{'abbreviation': 'Mouse',
#      'description': 'Genome-wide, high-resolution ISH data detailing gene expression throughout the adult mouse brain.',
#      'id': 1,
#      'name': 'Mouse Brain',
#      'product_name_facet': 2757464828,
#      'resource': 'Allen Mouse Brain Atlas',
#      'species': 'Mouse',
#      'species_name_facet': 1861523945,
#      'tags': None}],
#    'qc_date': '2009-05-02T23:04:42Z',
#    'red_channel': None,
#    'reference_space_id': 9,
#    'rnaseq_design_id': None,
#    'section_thickness': 25.0,
#    'specimen_id': 73633987,
#    'sphinx_id': 18581,
#    'storage_directory': '/external/aibssan/production32/prod340/image_series_74581394/',
#    'weight': 5270},
#   'section_data_set_id': 74581394,
#   'structure_id': 15576,
#   'sum_expressing_pixel_intensity': 118547000.0,
#   'sum_expressing_pixels': 702222.0,
#   'sum_pixel_intensity': 663068000.0,
#   'sum_pixels': 14377900.0,
#   'voxel_energy_cv': 0.533243,
#   'voxel_energy_mean': 8.243},
#  {'expression_density': 0.0504903,
#   'expression_energy': 8.55761,
#   'id': 450107600,
#   'section_data_set': {'blue_channel': None,
#    'delegate': False,
#    'expression': True,
#    'failed': False,
#    'failed_facet': 734881840,
#    'green_channel': None,
#    'id': 74581394,
#    'name': None,
#    'plane_of_section_id': 1,
#    'products': [{'abbreviation': 'Mouse',
#      'description': 'Genome-wide, high-resolution ISH data detailing gene expression throughout the adult mouse brain.',
#      'id': 1,
#      'name': 'Mouse Brain',
#      'product_name_facet': 2757464828,
#      'resource': 'Allen Mouse Brain Atlas',
#      'species': 'Mouse',
#      'species_name_facet': 1861523945,
#      'tags': None}],
#    'qc_date': '2009-05-02T23:04:42Z',
#    'red_channel': None,
#    'reference_space_id': 9,
#    'rnaseq_design_id': None,
#    'section_thickness': 25.0,
#    'specimen_id': 73633987,
#    'sphinx_id': 18581,
#    'storage_directory': '/external/aibssan/production32/prod340/image_series_74581394/',
#    'weight': 5270},
#   'section_data_set_id': 74581394,
#   'structure_id': 15577,
#   'sum_expressing_pixel_intensity': 100994000.0,
#   'sum_expressing_pixels': 595869.0,
#   'sum_pixel_intensity': 556101000.0,
#   'sum_pixels': 11801700.0,
#   'voxel_energy_cv': 0.533505,
#   'voxel_energy_mean': 8.55182},
#  {'expression_density': 0.0566173,
#   'expression_energy': 9.65109,
#   'id': 450107602,
#   'section_data_set': {'blue_channel': None,
#    'delegate': False,
#    'expression': True,
#    'failed': False,
#    'failed_facet': 734881840,
#    'green_channel': None,
#    'id': 74581394,
#    'name': None,
#    'plane_of_section_id': 1,
#    'products': [{'abbreviation': 'Mouse',
#      'description': 'Genome-wide, high-resolution ISH data detailing gene expression throughout the adult mouse brain.',
#      'id': 1,
#      'name': 'Mouse Brain',
#      'product_name_facet': 2757464828,
#      'resource': 'Allen Mouse Brain Atlas',
#      'species': 'Mouse',
#      'species_name_facet': 1861523945,
#      'tags': None}],
#    'qc_date': '2009-05-02T23:04:42Z',
#    'red_channel': None,
#    'reference_space_id': 9,
#    'rnaseq_design_id': None,
#    'section_thickness': 25.0,
#    'specimen_id': 73633987,
#    'sphinx_id': 18581,
#    'storage_directory': '/external/aibssan/production32/prod340/image_series_74581394/',
#    'weight': 5270},
#   'section_data_set_id': 74581394,
#   'structure_id': 15578,
#   'sum_expressing_pixel_intensity': 7762250.0,
#   'sum_expressing_pixels': 45536.6,
#   'sum_pixel_intensity': 40481700.0,
#   'sum_pixels': 804287.0,
#   'voxel_energy_cv': 0.311448,
#   'voxel_energy_mean': 9.65109},
#  {'expression_density': 0.0566173,
#   'expression_energy': 9.65109,
#   'id': 450107604,
#   'section_data_set': {'blue_channel': None,
#    'delegate': False,
#    'expression': True,
#    'failed': False,
#    'failed_facet': 734881840,
#    'green_channel': None,
#    'id': 74581394,
#    'name': None,
#    'plane_of_section_id': 1,
#    'products': [{'abbreviation': 'Mouse',
#      'description': 'Genome-wide, high-resolution ISH data detailing gene expression throughout the adult mouse brain.',
#      'id': 1,
#      'name': 'Mouse Brain',
#      'product_name_facet': 2757464828,
#      'resource': 'Allen Mouse Brain Atlas',
#      'species': 'Mouse',
#      'species_name_facet': 1861523945,
#      'tags': None}],
#    'qc_date': '2009-05-02T23:04:42Z',
#    'red_channel': None,
#    'reference_space_id': 9,
#    'rnaseq_design_id': None,
#    'section_thickness': 25.0,
#    'specimen_id': 73633987,
#    'sphinx_id': 18581,
#    'storage_directory': '/external/aibssan/production32/prod340/image_series_74581394/',
#    'weight': 5270},
#   'section_data_set_id': 74581394,
#   'structure_id': 15580,
#   'sum_expressing_pixel_intensity': 7762250.0,
#   'sum_expressing_pixels': 45536.6,
#   'sum_pixel_intensity': 40481700.0,
#   'sum_pixels': 804287.0,
#   'voxel_energy_cv': 0.311448,
#   'voxel_energy_mean': 9.65109},
#  {'expression_density': 0.0532773,
#   'expression_energy': 9.74699,
#   'id': 450107608,
#   'section_data_set': {'blue_channel': None,
#    'delegate': False,
#    'expression': True,
#    'failed': False,
#    'failed_facet': 734881840,
#    'green_channel': None,
#    'id': 74581394,
#    'name': None,
#    'plane_of_section_id': 1,
#    'products': [{'abbreviation': 'Mouse',
#      'description': 'Genome-wide, high-resolution ISH data detailing gene expression throughout the adult mouse brain.',
#      'id': 1,
#      'name': 'Mouse Brain',
#      'product_name_facet': 2757464828,
#      'resource': 'Allen Mouse Brain Atlas',
#      'species': 'Mouse',
#      'species_name_facet': 1861523945,
#      'tags': None}],
#    'qc_date': '2009-05-02T23:04:42Z',
#    'red_channel': None,
#    'reference_space_id': 9,
#    'rnaseq_design_id': None,
#    'section_thickness': 25.0,
#    'specimen_id': 73633987,
#    'sphinx_id': 18581,
#    'storage_directory': '/external/aibssan/production32/prod340/image_series_74581394/',
#    'weight': 5270},
#   'section_data_set_id': 74581394,
#   'structure_id': 15581,
#   'sum_expressing_pixel_intensity': 340841.0,
#   'sum_expressing_pixels': 1863.04,
#   'sum_pixel_intensity': 1810440.0,
#   'sum_pixels': 34968.8,
#   'voxel_energy_cv': 0.0,
#   'voxel_energy_mean': 0.0},
#  {'expression_density': 0.0532773,
#   'expression_energy': 9.74699,
#   'id': 450107609,
#   'section_data_set': {'blue_channel': None,
#    'delegate': False,
#    'expression': True,
#    'failed': False,
#    'failed_facet': 734881840,
#    'green_channel': None,
#    'id': 74581394,
#    'name': None,
#    'plane_of_section_id': 1,
#    'products': [{'abbreviation': 'Mouse',
#      'description': 'Genome-wide, high-resolution ISH data detailing gene expression throughout the adult mouse brain.',
#      'id': 1,
#      'name': 'Mouse Brain',
#      'product_name_facet': 2757464828,
#      'resource': 'Allen Mouse Brain Atlas',
#      'species': 'Mouse',
#      'species_name_facet': 1861523945,
#      'tags': None}],
#    'qc_date': '2009-05-02T23:04:42Z',
#    'red_channel': None,
#    'reference_space_id': 9,
#    'rnaseq_design_id': None,
#    'section_thickness': 25.0,
#    'specimen_id': 73633987,
#    'sphinx_id': 18581,
#    'storage_directory': '/external/aibssan/production32/prod340/image_series_74581394/',
#    'weight': 5270},
#   'section_data_set_id': 74581394,
#   'structure_id': 15582,
#   'sum_expressing_pixel_intensity': 340841.0,
#   'sum_expressing_pixels': 1863.04,
#   'sum_pixel_intensity': 1810440.0,
#   'sum_pixels': 34968.8,
#   'voxel_energy_cv': 0.0,
#   'voxel_energy_mean': 0.0},
#  {'expression_density': 0.0647453,
#   'expression_energy': 11.3232,
#   'id': 450107614,
#   'section_data_set': {'blue_channel': None,
#    'delegate': False,
#    'expression': True,
#    'failed': False,
#    'failed_facet': 734881840,
#    'green_channel': None,
#    'id': 74581394,
#    'name': None,
#    'plane_of_section_id': 1,
#    'products': [{'abbreviation': 'Mouse',
#      'description': 'Genome-wide, high-resolution ISH data detailing gene expression throughout the adult mouse brain.',
#      'id': 1,
#      'name': 'Mouse Brain',
#      'product_name_facet': 2757464828,
#      'resource': 'Allen Mouse Brain Atlas',
#      'species': 'Mouse',
#      'species_name_facet': 1861523945,
#      'tags': None}],
#    'qc_date': '2009-05-02T23:04:42Z',
#    'red_channel': None,
#    'reference_space_id': 9,
#    'rnaseq_design_id': None,
#    'section_thickness': 25.0,
#    'specimen_id': 73633987,
#    'sphinx_id': 18581,
#    'storage_directory': '/external/aibssan/production32/prod340/image_series_74581394/',
#    'weight': 5270},
#   'section_data_set_id': 74581394,
#   'structure_id': 15583,
#   'sum_expressing_pixel_intensity': 4751530.0,
#   'sum_expressing_pixels': 27168.9,
#   'sum_pixel_intensity': 21987500.0,
#   'sum_pixels': 419628.0,
#   'voxel_energy_cv': 0.262226,
#   'voxel_energy_mean': 11.3232},
#  {'expression_density': 0.0647453,
#   'expression_energy': 11.3232,
#   'id': 450107617,
#   'section_data_set': {'blue_channel': None,
#    'delegate': False,
#    'expression': True,
#    'failed': False,
#    'failed_facet': 734881840,
#    'green_channel': None,
#    'id': 74581394,
#    'name': None,
#    'plane_of_section_id': 1,
#    'products': [{'abbreviation': 'Mouse',
#      'description': 'Genome-wide, high-resolution ISH data detailing gene expression throughout the adult mouse brain.',
#      'id': 1,
#      'name': 'Mouse Brain',
#      'product_name_facet': 2757464828,
#      'resource': 'Allen Mouse Brain Atlas',
#      'species': 'Mouse',
#      'species_name_facet': 1861523945,
#      'tags': None}],
#    'qc_date': '2009-05-02T23:04:42Z',
#    'red_channel': None,
#    'reference_space_id': 9,
#    'rnaseq_design_id': None,
#    'section_thickness': 25.0,
#    'specimen_id': 73633987,
#    'sphinx_id': 18581,
#    'storage_directory': '/external/aibssan/production32/prod340/image_series_74581394/',
#    'weight': 5270},
#   'section_data_set_id': 74581394,
#   'structure_id': 15584,
#   'sum_expressing_pixel_intensity': 4751530.0,
#   'sum_expressing_pixels': 27168.9,
#   'sum_pixel_intensity': 21987500.0,
#   'sum_pixels': 419628.0,
#   'voxel_energy_cv': 0.262226,
#   'voxel_energy_mean': 11.3232},
#  {'expression_density': 0.0471978,
#   'expression_energy': 7.63497,
#   'id': 450107621,
#   'section_data_set': {'blue_channel': None,
#    'delegate': False,
#    'expression': True,
#    'failed': False,
#    'failed_facet': 734881840,
#    'green_channel': None,
#    'id': 74581394,
#    'name': None,
#    'plane_of_section_id': 1,
#    'products': [{'abbreviation': 'Mouse',
#      'description': 'Genome-wide, high-resolution ISH data detailing gene expression throughout the adult mouse brain.',
#      'id': 1,
#      'name': 'Mouse Brain',
#      'product_name_facet': 2757464828,
#      'resource': 'Allen Mouse Brain Atlas',
#      'species': 'Mouse',
#      'species_name_facet': 1861523945,
#      'tags': None}],
#    'qc_date': '2009-05-02T23:04:42Z',
#    'red_channel': None,
#    'reference_space_id': 9,
#    'rnaseq_design_id': None,
#    'section_thickness': 25.0,
#    'specimen_id': 73633987,
#    'sphinx_id': 18581,
#    'storage_directory': '/external/aibssan/production32/prod340/image_series_74581394/',
#    'weight': 5270},
#   'section_data_set_id': 74581394,
#   'structure_id': 15585,
#   'sum_expressing_pixel_intensity': 2669870.0,
#   'sum_expressing_pixels': 16504.6,
#   'sum_pixel_intensity': 16683800.0,
#   'sum_pixels': 349690.0,
#   'voxel_energy_cv': 0.229281,
#   'voxel_energy_mean': 7.63497},
#  {'expression_density': 0.0471978,
#   'expression_energy': 7.63497,
#   'id': 450107623,
#   'section_data_set': {'blue_channel': None,
#    'delegate': False,
#    'expression': True,
#    'failed': False,
#    'failed_facet': 734881840,
#    'green_channel': None,
#    'id': 74581394,
#    'name': None,
#    'plane_of_section_id': 1,
#    'products': [{'abbreviation': 'Mouse',
#      'description': 'Genome-wide, high-resolution ISH data detailing gene expression throughout the adult mouse brain.',
#      'id': 1,
#      'name': 'Mouse Brain',
#      'product_name_facet': 2757464828,
#      'resource': 'Allen Mouse Brain Atlas',
#      'species': 'Mouse',
#      'species_name_facet': 1861523945,
#      'tags': None}],
#    'qc_date': '2009-05-02T23:04:42Z',
#    'red_channel': None,
#    'reference_space_id': 9,
#    'rnaseq_design_id': None,
#    'section_thickness': 25.0,
#    'specimen_id': 73633987,
#    'sphinx_id': 18581,
#    'storage_directory': '/external/aibssan/production32/prod340/image_series_74581394/',
#    'weight': 5270},
#   'section_data_set_id': 74581394,
#   'structure_id': 15586,
#   'sum_expressing_pixel_intensity': 2669870.0,
#   'sum_expressing_pixels': 16504.6,
#   'sum_pixel_intensity': 16683800.0,
#   'sum_pixels': 349690.0,
#   'voxel_energy_cv': 0.229281,
#   'voxel_energy_mean': 7.63497},
#  {'expression_density': 0.0485351,
#   'expression_energy': 8.09105,
#   'id': 450107627,
#   'section_data_set': {'blue_channel': None,
#    'delegate': False,
#    'expression': True,
#    'failed': False,
#    'failed_facet': 734881840,
#    'green_channel': None,
#    'id': 74581394,
#    'name': None,
#    'plane_of_section_id': 1,
#    'products': [{'abbreviation': 'Mouse',
#      'description': 'Genome-wide, high-resolution ISH data detailing gene expression throughout the adult mouse brain.',
#      'id': 1,
#      'name': 'Mouse Brain',
#      'product_name_facet': 2757464828,
#      'resource': 'Allen Mouse Brain Atlas',
#      'species': 'Mouse',
#      'species_name_facet': 1861523945,
#      'tags': None}],
#    'qc_date': '2009-05-02T23:04:42Z',
#    'red_channel': None,
#    'reference_space_id': 9,
#    'rnaseq_design_id': None,
#    'section_thickness': 25.0,
#    'specimen_id': 73633987,
#    'sphinx_id': 18581,
#    'storage_directory': '/external/aibssan/production32/prod340/image_series_74581394/',
#    'weight': 5270},
#   'section_data_set_id': 74581394,
#   'structure_id': 15587,
#   'sum_expressing_pixel_intensity': 51906500.0,
#   'sum_expressing_pixels': 311367.0,
#   'sum_pixel_intensity': 288795000.0,
#   'sum_pixels': 6415290.0,
#   'voxel_energy_cv': 0.522,
#   'voxel_energy_mean': 8.08781},
#  {'expression_density': 0.0485351,
#   'expression_energy': 8.09105,
#   'id': 450107630,
#   'section_data_set': {'blue_channel': None,
#    'delegate': False,
#    'expression': True,
#    'failed': False,
#    'failed_facet': 734881840,
#    'green_channel': None,
#    'id': 74581394,
#    'name': None,
#    'plane_of_section_id': 1,
#    'products': [{'abbreviation': 'Mouse',
#      'description': 'Genome-wide, high-resolution ISH data detailing gene expression throughout the adult mouse brain.',
#      'id': 1,
#      'name': 'Mouse Brain',
#      'product_name_facet': 2757464828,
#      'resource': 'Allen Mouse Brain Atlas',
#      'species': 'Mouse',
#      'species_name_facet': 1861523945,
#      'tags': None}],
#    'qc_date': '2009-05-02T23:04:42Z',
#    'red_channel': None,
#    'reference_space_id': 9,
#    'rnaseq_design_id': None,
#    'section_thickness': 25.0,
#    'specimen_id': 73633987,
#    'sphinx_id': 18581,
#    'storage_directory': '/external/aibssan/production32/prod340/image_series_74581394/',
#    'weight': 5270},
#   'section_data_set_id': 74581394,
#   'structure_id': 15589,
#   'sum_expressing_pixel_intensity': 51906500.0,
#   'sum_expressing_pixels': 311367.0,
#   'sum_pixel_intensity': 288795000.0,
#   'sum_pixels': 6415290.0,
#   'voxel_energy_cv': 0.522,
#   'voxel_energy_mean': 8.08781},
#  {'expression_density': 0.0764154,
#   'expression_energy': 14.447,
#   'id': 450107635,
#   'section_data_set': {'blue_channel': None,
#    'delegate': False,
#    'expression': True,
#    'failed': False,
#    'failed_facet': 734881840,
#    'green_channel': None,
#    'id': 74581394,
#    'name': None,
#    'plane_of_section_id': 1,
#    'products': [{'abbreviation': 'Mouse',
#      'description': 'Genome-wide, high-resolution ISH data detailing gene expression throughout the adult mouse brain.',
#      'id': 1,
#      'name': 'Mouse Brain',
#      'product_name_facet': 2757464828,
#      'resource': 'Allen Mouse Brain Atlas',
#      'species': 'Mouse',
#      'species_name_facet': 1861523945,
#      'tags': None}],
#    'qc_date': '2009-05-02T23:04:42Z',
#    'red_channel': None,
#    'reference_space_id': 9,
#    'rnaseq_design_id': None,
#    'section_thickness': 25.0,
#    'specimen_id': 73633987,
#    'sphinx_id': 18581,
#    'storage_directory': '/external/aibssan/production32/prod340/image_series_74581394/',
#    'weight': 5270},
#   'section_data_set_id': 74581394,
#   'structure_id': 15590,
#   'sum_expressing_pixel_intensity': 17681900.0,
#   'sum_expressing_pixels': 93525.9,
#   'sum_pixel_intensity': 65429200.0,
#   'sum_pixels': 1223910.0,
#   'voxel_energy_cv': 0.425947,
#   'voxel_energy_mean': 14.447},
#  {'expression_density': 0.0850092,
#   'expression_energy': 16.2631,
#   'id': 450107637,
#   'section_data_set': {'blue_channel': None,
#    'delegate': False,
#    'expression': True,
#    'failed': False,
#    'failed_facet': 734881840,
#    'green_channel': None,
#    'id': 74581394,
#    'name': None,
#    'plane_of_section_id': 1,
#    'products': [{'abbreviation': 'Mouse',
#      'description': 'Genome-wide, high-resolution ISH data detailing gene expression throughout the adult mouse brain.',
#      'id': 1,
#      'name': 'Mouse Brain',
#      'product_name_facet': 2757464828,
#      'resource': 'Allen Mouse Brain Atlas',
#      'species': 'Mouse',
#      'species_name_facet': 1861523945,
#      'tags': None}],
#    'qc_date': '2009-05-02T23:04:42Z',
#    'red_channel': None,
#    'reference_space_id': 9,
#    'rnaseq_design_id': None,
#    'section_thickness': 25.0,
#    'specimen_id': 73633987,
#    'sphinx_id': 18581,
#    'storage_directory': '/external/aibssan/production32/prod340/image_series_74581394/',
#    'weight': 5270},
#   'section_data_set_id': 74581394,
#   'structure_id': 15591,
#   'sum_expressing_pixel_intensity': 7393180.0,
#   'sum_expressing_pixels': 38644.9,
#   'sum_pixel_intensity': 25175900.0,
#   'sum_pixels': 454597.0,
#   'voxel_energy_cv': 0.341908,
#   'voxel_energy_mean': 16.2631},
#  {'expression_density': 0.0713372,
#   'expression_energy': 13.3738,
#   'id': 450107642,
#   'section_data_set': {'blue_channel': None,
#    'delegate': False,
#    'expression': True,
#    'failed': False,
#    'failed_facet': 734881840,
#    'green_channel': None,
#    'id': 74581394,
#    'name': None,
#    'plane_of_section_id': 1,
#    'products': [{'abbreviation': 'Mouse',
#      'description': 'Genome-wide, high-resolution ISH data detailing gene expression throughout the adult mouse brain.',
#      'id': 1,
#      'name': 'Mouse Brain',
#      'product_name_facet': 2757464828,
#      'resource': 'Allen Mouse Brain Atlas',
#      'species': 'Mouse',
#      'species_name_facet': 1861523945,
#      'tags': None}],
#    'qc_date': '2009-05-02T23:04:42Z',
#    'red_channel': None,
#    'reference_space_id': 9,
#    'rnaseq_design_id': None,
#    'section_thickness': 25.0,
#    'specimen_id': 73633987,
#    'sphinx_id': 18581,
#    'storage_directory': '/external/aibssan/production32/prod340/image_series_74581394/',
#    'weight': 5270},
#   'section_data_set_id': 74581394,
#   'structure_id': 15592,
#   'sum_expressing_pixel_intensity': 10288700.0,
#   'sum_expressing_pixels': 54881.0,
#   'sum_pixel_intensity': 40253400.0,
#   'sum_pixels': 769318.0,
#   'voxel_energy_cv': 0.475221,
#   'voxel_energy_mean': 13.3738},
#  {'expression_density': 0.0412336,
#   'expression_energy': 6.44663,
#   'id': 450107648,
#   'section_data_set': {'blue_channel': None,
#    'delegate': False,
#    'expression': True,
#    'failed': False,
#    'failed_facet': 734881840,
#    'green_channel': None,
#    'id': 74581394,
#    'name': None,
#    'plane_of_section_id': 1,
#    'products': [{'abbreviation': 'Mouse',
#      'description': 'Genome-wide, high-resolution ISH data detailing gene expression throughout the adult mouse brain.',
#      'id': 1,
#      'name': 'Mouse Brain',
#      'product_name_facet': 2757464828,
#      'resource': 'Allen Mouse Brain Atlas',
#      'species': 'Mouse',
#      'species_name_facet': 1861523945,
#      'tags': None}],
#    'qc_date': '2009-05-02T23:04:42Z',
#    'red_channel': None,
#    'reference_space_id': 9,
#    'rnaseq_design_id': None,
#    'section_thickness': 25.0,
#    'specimen_id': 73633987,
#    'sphinx_id': 18581,
#    'storage_directory': '/external/aibssan/production32/prod340/image_series_74581394/',
#    'weight': 5270},
#   'section_data_set_id': 74581394,
#   'structure_id': 15594,
#   'sum_expressing_pixel_intensity': 450864.0,
#   'sum_expressing_pixels': 2883.79,
#   'sum_pixel_intensity': 3095640.0,
#   'sum_pixels': 69938.0,
#   'voxel_energy_cv': 0.152544,
#   'voxel_energy_mean': 6.44663},
#  {'expression_density': 0.0448324,
#   'expression_energy': 7.18261,
#   'id': 450107651,
#   'section_data_set': {'blue_channel': None,
#    'delegate': False,
#    'expression': True,
#    'failed': False,
#    'failed_facet': 734881840,
#    'green_channel': None,
#    'id': 74581394,
#    'name': None,
#    'plane_of_section_id': 1,
#    'products': [{'abbreviation': 'Mouse',
#      'description': 'Genome-wide, high-resolution ISH data detailing gene expression throughout the adult mouse brain.',
#      'id': 1,
#      'name': 'Mouse Brain',
#      'product_name_facet': 2757464828,
#      'resource': 'Allen Mouse Brain Atlas',
#      'species': 'Mouse',
#      'species_name_facet': 1861523945,
#      'tags': None}],
#    'qc_date': '2009-05-02T23:04:42Z',
#    'red_channel': None,
#    'reference_space_id': 9,
#    'rnaseq_design_id': None,
#    'section_thickness': 25.0,
#    'specimen_id': 73633987,
#    'sphinx_id': 18581,
#    'storage_directory': '/external/aibssan/production32/prod340/image_series_74581394/',
#    'weight': 5270},
#   'section_data_set_id': 74581394,
#   'structure_id': 15595,
#   'sum_expressing_pixel_intensity': 8539740.0,
#   'sum_expressing_pixels': 53303.3,
#   'sum_pixel_intensity': 54462900.0,
#   'sum_pixels': 1188950.0,
#   'voxel_energy_cv': 0.153191,
#   'voxel_energy_mean': 7.18261},
#  {'expression_density': 0.0421879,
#   'expression_energy': 6.58149,
#   'id': 450107655,
#   'section_data_set': {'blue_channel': None,
#    'delegate': False,
#    'expression': True,
#    'failed': False,
#    'failed_facet': 734881840,
#    'green_channel': None,
#    'id': 74581394,
#    'name': None,
#    'plane_of_section_id': 1,
#    'products': [{'abbreviation': 'Mouse',
#      'description': 'Genome-wide, high-resolution ISH data detailing gene expression throughout the adult mouse brain.',
#      'id': 1,
#      'name': 'Mouse Brain',
#      'product_name_facet': 2757464828,
#      'resource': 'Allen Mouse Brain Atlas',
#      'species': 'Mouse',
#      'species_name_facet': 1861523945,
#      'tags': None}],
#    'qc_date': '2009-05-02T23:04:42Z',
#    'red_channel': None,
#    'reference_space_id': 9,
#    'rnaseq_design_id': None,
#    'section_thickness': 25.0,
#    'specimen_id': 73633987,
#    'sphinx_id': 18581,
#    'storage_directory': '/external/aibssan/production32/prod340/image_series_74581394/',
#    'weight': 5270},
#   'section_data_set_id': 74581394,
#   'structure_id': 15596,
#   'sum_expressing_pixel_intensity': 24731000.0,
#   'sum_expressing_pixels': 158528.0,
#   'sum_pixel_intensity': 161425000.0,
#   'sum_pixels': 3757660.0,
#   'voxel_energy_cv': 0.145281,
#   'voxel_energy_mean': 6.58357},
#  {'expression_density': 0.0178785,
#   'expression_energy': 2.87694,
#   'id': 450107659,
#   'section_data_set': {'blue_channel': None,
#    'delegate': False,
#    'expression': True,
#    'failed': False,
#    'failed_facet': 734881840,
#    'green_channel': None,
#    'id': 74581394,
#    'name': None,
#    'plane_of_section_id': 1,
#    'products': [{'abbreviation': 'Mouse',
#      'description': 'Genome-wide, high-resolution ISH data detailing gene expression throughout the adult mouse brain.',
#      'id': 1,
#      'name': 'Mouse Brain',
#      'product_name_facet': 2757464828,
#      'resource': 'Allen Mouse Brain Atlas',
#      'species': 'Mouse',
#      'species_name_facet': 1861523945,
#      'tags': None}],
#    'qc_date': '2009-05-02T23:04:42Z',
#    'red_channel': None,
#    'reference_space_id': 9,
#    'rnaseq_design_id': None,
#    'section_thickness': 25.0,
#    'specimen_id': 73633987,
#    'sphinx_id': 18581,
#    'storage_directory': '/external/aibssan/production32/prod340/image_series_74581394/',
#    'weight': 5270},
#   'section_data_set_id': 74581394,
#   'structure_id': 15597,
#   'sum_expressing_pixel_intensity': 502992.0,
#   'sum_expressing_pixels': 3125.81,
#   'sum_pixel_intensity': 4381720.0,
#   'sum_pixels': 174836.0,
#   'voxel_energy_cv': 0.450324,
#   'voxel_energy_mean': 2.87684},
#  {'expression_density': 0.0178785,
#   'expression_energy': 2.87694,
#   'id': 450107662,
#   'section_data_set': {'blue_channel': None,
#    'delegate': False,
#    'expression': True,
#    'failed': False,
#    'failed_facet': 734881840,
#    'green_channel': None,
#    'id': 74581394,
#    'name': None,
#    'plane_of_section_id': 1,
#    'products': [{'abbreviation': 'Mouse',
#      'description': 'Genome-wide, high-resolution ISH data detailing gene expression throughout the adult mouse brain.',
#      'id': 1,
#      'name': 'Mouse Brain',
#      'product_name_facet': 2757464828,
#      'resource': 'Allen Mouse Brain Atlas',
#      'species': 'Mouse',
#      'species_name_facet': 1861523945,
#      'tags': None}],
#    'qc_date': '2009-05-02T23:04:42Z',
#    'red_channel': None,
#    'reference_space_id': 9,
#    'rnaseq_design_id': None,
#    'section_thickness': 25.0,
#    'specimen_id': 73633987,
#    'sphinx_id': 18581,
#    'storage_directory': '/external/aibssan/production32/prod340/image_series_74581394/',
#    'weight': 5270},
#   'section_data_set_id': 74581394,
#   'structure_id': 15598,
#   'sum_expressing_pixel_intensity': 502992.0,
#   'sum_expressing_pixels': 3125.81,
#   'sum_pixel_intensity': 4381720.0,
#   'sum_pixels': 174836.0,
#   'voxel_energy_cv': 0.450324,
#   'voxel_energy_mean': 2.87684},
#  {'expression_density': 0.0521524,
#   'expression_energy': 9.01888,
#   'id': 450107665,
#   'section_data_set': {'blue_channel': None,
#    'delegate': False,
#    'expression': True,
#    'failed': False,
#    'failed_facet': 734881840,
#    'green_channel': None,
#    'id': 74581394,
#    'name': None,
#    'plane_of_section_id': 1,
#    'products': [{'abbreviation': 'Mouse',
#      'description': 'Genome-wide, high-resolution ISH data detailing gene expression throughout the adult mouse brain.',
#      'id': 1,
#      'name': 'Mouse Brain',
#      'product_name_facet': 2757464828,
#      'resource': 'Allen Mouse Brain Atlas',
#      'species': 'Mouse',
#      'species_name_facet': 1861523945,
#      'tags': None}],
#    'qc_date': '2009-05-02T23:04:42Z',
#    'red_channel': None,
#    'reference_space_id': 9,
#    'rnaseq_design_id': None,
#    'section_thickness': 25.0,
#    'specimen_id': 73633987,
#    'sphinx_id': 18581,
#    'storage_directory': '/external/aibssan/production32/prod340/image_series_74581394/',
#    'weight': 5270},
#   'section_data_set_id': 74581394,
#   'structure_id': 15599,
#   'sum_expressing_pixel_intensity': 41325200.0,
#   'sum_expressing_pixels': 238966.0,
#   'sum_pixel_intensity': 226824000.0,
#   'sum_pixels': 4582070.0,
#   'voxel_energy_cv': 0.572265,
#   'voxel_energy_mean': 9.00708},
#  {'expression_density': 0.0521524,
#   'expression_energy': 9.01888,
#   'id': 450107669,
#   'section_data_set': {'blue_channel': None,
#    'delegate': False,
#    'expression': True,
#    'failed': False,
#    'failed_facet': 734881840,
#    'green_channel': None,
#    'id': 74581394,
#    'name': None,
#    'plane_of_section_id': 1,
#    'products': [{'abbreviation': 'Mouse',
#      'description': 'Genome-wide, high-resolution ISH data detailing gene expression throughout the adult mouse brain.',
#      'id': 1,
#      'name': 'Mouse Brain',
#      'product_name_facet': 2757464828,
#      'resource': 'Allen Mouse Brain Atlas',
#      'species': 'Mouse',
#      'species_name_facet': 1861523945,
#      'tags': None}],
#    'qc_date': '2009-05-02T23:04:42Z',
#    'red_channel': None,
#    'reference_space_id': 9,
#    'rnaseq_design_id': None,
#    'section_thickness': 25.0,
#    'specimen_id': 73633987,
#    'sphinx_id': 18581,
#    'storage_directory': '/external/aibssan/production32/prod340/image_series_74581394/',
#    'weight': 5270},
#   'section_data_set_id': 74581394,
#   'structure_id': 15601,
#   'sum_expressing_pixel_intensity': 41325200.0,
#   'sum_expressing_pixels': 238966.0,
#   'sum_pixel_intensity': 226824000.0,
#   'sum_pixels': 4582070.0,
#   'voxel_energy_cv': 0.572265,
#   'voxel_energy_mean': 9.00708},
#  {'expression_density': 0.0584492,
#   'expression_energy': 10.3929,
#   'id': 450107673,
#   'section_data_set': {'blue_channel': None,
#    'delegate': False,
#    'expression': True,
#    'failed': False,
#    'failed_facet': 734881840,
#    'green_channel': None,
#    'id': 74581394,
#    'name': None,
#    'plane_of_section_id': 1,
#    'products': [{'abbreviation': 'Mouse',
#      'description': 'Genome-wide, high-resolution ISH data detailing gene expression throughout the adult mouse brain.',
#      'id': 1,
#      'name': 'Mouse Brain',
#      'product_name_facet': 2757464828,
#      'resource': 'Allen Mouse Brain Atlas',
#      'species': 'Mouse',
#      'species_name_facet': 1861523945,
#      'tags': None}],
#    'qc_date': '2009-05-02T23:04:42Z',
#    'red_channel': None,
#    'reference_space_id': 9,
#    'rnaseq_design_id': None,
#    'section_thickness': 25.0,
#    'specimen_id': 73633987,
#    'sphinx_id': 18581,
#    'storage_directory': '/external/aibssan/production32/prod340/image_series_74581394/',
#    'weight': 5270},
#   'section_data_set_id': 74581394,
#   'structure_id': 15602,
#   'sum_expressing_pixel_intensity': 31979200.0,
#   'sum_expressing_pixels': 179849.0,
#   'sum_pixel_intensity': 165245000.0,
#   'sum_pixels': 3077020.0,
#   'voxel_energy_cv': 0.550656,
#   'voxel_energy_mean': 10.393},
#  {'expression_density': 0.102241,
#   'expression_energy': 20.4291,
#   'id': 450107678,
#   'section_data_set': {'blue_channel': None,
#    'delegate': False,
#    'expression': True,
#    'failed': False,
#    'failed_facet': 734881840,
#    'green_channel': None,
#    'id': 74581394,
#    'name': None,
#    'plane_of_section_id': 1,
#    'products': [{'abbreviation': 'Mouse',
#      'description': 'Genome-wide, high-resolution ISH data detailing gene expression throughout the adult mouse brain.',
#      'id': 1,
#      'name': 'Mouse Brain',
#      'product_name_facet': 2757464828,
#      'resource': 'Allen Mouse Brain Atlas',
#      'species': 'Mouse',
#      'species_name_facet': 1861523945,
#      'tags': None}],
#    'qc_date': '2009-05-02T23:04:42Z',
#    'red_channel': None,
#    'reference_space_id': 9,
#    'rnaseq_design_id': None,
#    'section_thickness': 25.0,
#    'specimen_id': 73633987,
#    'sphinx_id': 18581,
#    'storage_directory': '/external/aibssan/production32/prod340/image_series_74581394/',
#    'weight': 5270},
#   'section_data_set_id': 74581394,
#   'structure_id': 15603,
#   'sum_expressing_pixel_intensity': 11428500.0,
#   'sum_expressing_pixels': 57196.2,
#   'sum_pixel_intensity': 38562700.0,
#   'sum_pixels': 559424.0,
#   'voxel_energy_cv': 0.137153,
#   'voxel_energy_mean': 20.4292},
#  {'expression_density': 0.0487184,
#   'expression_energy': 8.16281,
#   'id': 450107682,
#   'section_data_set': {'blue_channel': None,
#    'delegate': False,
#    'expression': True,
#    'failed': False,
#    'failed_facet': 734881840,
#    'green_channel': None,
#    'id': 74581394,
#    'name': None,
#    'plane_of_section_id': 1,
#    'products': [{'abbreviation': 'Mouse',
#      'description': 'Genome-wide, high-resolution ISH data detailing gene expression throughout the adult mouse brain.',
#      'id': 1,
#      'name': 'Mouse Brain',
#      'product_name_facet': 2757464828,
#      'resource': 'Allen Mouse Brain Atlas',
#      'species': 'Mouse',
#      'species_name_facet': 1861523945,
#      'tags': None}],
#    'qc_date': '2009-05-02T23:04:42Z',
#    'red_channel': None,
#    'reference_space_id': 9,
#    'rnaseq_design_id': None,
#    'section_thickness': 25.0,
#    'specimen_id': 73633987,
#    'sphinx_id': 18581,
#    'storage_directory': '/external/aibssan/production32/prod340/image_series_74581394/',
#    'weight': 5270},
#   'section_data_set_id': 74581394,
#   'structure_id': 15604,
#   'sum_expressing_pixel_intensity': 20550600.0,
#   'sum_expressing_pixels': 122653.0,
#   'sum_pixel_intensity': 126683000.0,
#   'sum_pixels': 2517590.0,
#   'voxel_energy_cv': 0.40132,
#   'voxel_energy_mean': 8.16269},
#  {'expression_density': 0.0429576,
#   'expression_energy': 6.72784,
#   'id': 450107687,
#   'section_data_set': {'blue_channel': None,
#    'delegate': False,
#    'expression': True,
#    'failed': False,
#    'failed_facet': 734881840,
#    'green_channel': None,
#    'id': 74581394,
#    'name': None,
#    'plane_of_section_id': 1,
#    'products': [{'abbreviation': 'Mouse',
#      'description': 'Genome-wide, high-resolution ISH data detailing gene expression throughout the adult mouse brain.',
#      'id': 1,
#      'name': 'Mouse Brain',
#      'product_name_facet': 2757464828,
#      'resource': 'Allen Mouse Brain Atlas',
#      'species': 'Mouse',
#      'species_name_facet': 1861523945,
#      'tags': None}],
#    'qc_date': '2009-05-02T23:04:42Z',
#    'red_channel': None,
#    'reference_space_id': 9,
#    'rnaseq_design_id': None,
#    'section_thickness': 25.0,
#    'specimen_id': 73633987,
#    'sphinx_id': 18581,
#    'storage_directory': '/external/aibssan/production32/prod340/image_series_74581394/',
#    'weight': 5270},
#   'section_data_set_id': 74581394,
#   'structure_id': 15605,
#   'sum_expressing_pixel_intensity': 7292070.0,
#   'sum_expressing_pixels': 46560.2,
#   'sum_pixel_intensity': 51585700.0,
#   'sum_pixels': 1083860.0,
#   'voxel_energy_cv': 0.0701136,
#   'voxel_energy_mean': 6.7278},
#  {'expression_density': 0.0429796,
#   'expression_energy': 6.80964,
#   'id': 450107696,
#   'section_data_set': {'blue_channel': None,
#    'delegate': False,
#    'expression': True,
#    'failed': False,
#    'failed_facet': 734881840,
#    'green_channel': None,
#    'id': 74581394,
#    'name': None,
#    'plane_of_section_id': 1,
#    'products': [{'abbreviation': 'Mouse',
#      'description': 'Genome-wide, high-resolution ISH data detailing gene expression throughout the adult mouse brain.',
#      'id': 1,
#      'name': 'Mouse Brain',
#      'product_name_facet': 2757464828,
#      'resource': 'Allen Mouse Brain Atlas',
#      'species': 'Mouse',
#      'species_name_facet': 1861523945,
#      'tags': None}],
#    'qc_date': '2009-05-02T23:04:42Z',
#    'red_channel': None,
#    'reference_space_id': 9,
#    'rnaseq_design_id': None,
#    'section_thickness': 25.0,
#    'specimen_id': 73633987,
#    'sphinx_id': 18581,
#    'storage_directory': '/external/aibssan/production32/prod340/image_series_74581394/',
#    'weight': 5270},
#   'section_data_set_id': 74581394,
#   'structure_id': 15608,
#   'sum_expressing_pixel_intensity': 7630580.0,
#   'sum_expressing_pixels': 48161.0,
#   'sum_pixel_intensity': 49521800.0,
#   'sum_pixels': 1120560.0,
#   'voxel_energy_cv': 0.154874,
#   'voxel_energy_mean': 6.827},
#  {'expression_density': 0.0429796,
#   'expression_energy': 6.80964,
#   'id': 450107699,
#   'section_data_set': {'blue_channel': None,
#    'delegate': False,
#    'expression': True,
#    'failed': False,
#    'failed_facet': 734881840,
#    'green_channel': None,
#    'id': 74581394,
#    'name': None,
#    'plane_of_section_id': 1,
#    'products': [{'abbreviation': 'Mouse',
#      'description': 'Genome-wide, high-resolution ISH data detailing gene expression throughout the adult mouse brain.',
#      'id': 1,
#      'name': 'Mouse Brain',
#      'product_name_facet': 2757464828,
#      'resource': 'Allen Mouse Brain Atlas',
#      'species': 'Mouse',
#      'species_name_facet': 1861523945,
#      'tags': None}],
#    'qc_date': '2009-05-02T23:04:42Z',
#    'red_channel': None,
#    'reference_space_id': 9,
#    'rnaseq_design_id': None,
#    'section_thickness': 25.0,
#    'specimen_id': 73633987,
#    'sphinx_id': 18581,
#    'storage_directory': '/external/aibssan/production32/prod340/image_series_74581394/',
#    'weight': 5270},
#   'section_data_set_id': 74581394,
#   'structure_id': 15609,
#   'sum_expressing_pixel_intensity': 7630580.0,
#   'sum_expressing_pixels': 48161.0,
#   'sum_pixel_intensity': 49521800.0,
#   'sum_pixels': 1120560.0,
#   'voxel_energy_cv': 0.154874,
#   'voxel_energy_mean': 6.827},
#  {'expression_density': 0.0284938,
#   'expression_energy': 4.46143,
#   'id': 450107703,
#   'section_data_set': {'blue_channel': None,
#    'delegate': False,
#    'expression': True,
#    'failed': False,
#    'failed_facet': 734881840,
#    'green_channel': None,
#    'id': 74581394,
#    'name': None,
#    'plane_of_section_id': 1,
#    'products': [{'abbreviation': 'Mouse',
#      'description': 'Genome-wide, high-resolution ISH data detailing gene expression throughout the adult mouse brain.',
#      'id': 1,
#      'name': 'Mouse Brain',
#      'product_name_facet': 2757464828,
#      'resource': 'Allen Mouse Brain Atlas',
#      'species': 'Mouse',
#      'species_name_facet': 1861523945,
#      'tags': None}],
#    'qc_date': '2009-05-02T23:04:42Z',
#    'red_channel': None,
#    'reference_space_id': 9,
#    'rnaseq_design_id': None,
#    'section_thickness': 25.0,
#    'specimen_id': 73633987,
#    'sphinx_id': 18581,
#    'storage_directory': '/external/aibssan/production32/prod340/image_series_74581394/',
#    'weight': 5270},
#   'section_data_set_id': 74581394,
#   'structure_id': 15610,
#   'sum_expressing_pixel_intensity': 1715420.0,
#   'sum_expressing_pixels': 10955.9,
#   'sum_pixel_intensity': 12057200.0,
#   'sum_pixels': 384501.0,
#   'voxel_energy_cv': 0.459138,
#   'voxel_energy_mean': 4.46015},
#  {'expression_density': 0.0265912,
#   'expression_energy': 4.24611,
#   'id': 450107708,
#   'section_data_set': {'blue_channel': None,
#    'delegate': False,
#    'expression': True,
#    'failed': False,
#    'failed_facet': 734881840,
#    'green_channel': None,
#    'id': 74581394,
#    'name': None,
#    'plane_of_section_id': 1,
#    'products': [{'abbreviation': 'Mouse',
#      'description': 'Genome-wide, high-resolution ISH data detailing gene expression throughout the adult mouse brain.',
#      'id': 1,
#      'name': 'Mouse Brain',
#      'product_name_facet': 2757464828,
#      'resource': 'Allen Mouse Brain Atlas',
#      'species': 'Mouse',
#      'species_name_facet': 1861523945,
#      'tags': None}],
#    'qc_date': '2009-05-02T23:04:42Z',
#    'red_channel': None,
#    'reference_space_id': 9,
#    'rnaseq_design_id': None,
#    'section_thickness': 25.0,
#    'specimen_id': 73633987,
#    'sphinx_id': 18581,
#    'storage_directory': '/external/aibssan/production32/prod340/image_series_74581394/',
#    'weight': 5270},
#   'section_data_set_id': 74581394,
#   'structure_id': 15611,
#   'sum_expressing_pixel_intensity': 593919.0,
#   'sum_expressing_pixels': 3719.41,
#   'sum_pixel_intensity': 4006650.0,
#   'sum_pixels': 139874.0,
#   'voxel_energy_cv': 0.547105,
#   'voxel_energy_mean': 4.24606},
#  {'expression_density': 0.0456474,
#   'expression_energy': 7.45118,
#   'id': 450107722,
#   'section_data_set': {'blue_channel': None,
#    'delegate': False,
#    'expression': True,
#    'failed': False,
#    'failed_facet': 734881840,
#    'green_channel': None,
#    'id': 74581394,
#    'name': None,
#    'plane_of_section_id': 1,
#    'products': [{'abbreviation': 'Mouse',
#      'description': 'Genome-wide, high-resolution ISH data detailing gene expression throughout the adult mouse brain.',
#      'id': 1,
#      'name': 'Mouse Brain',
#      'product_name_facet': 2757464828,
#      'resource': 'Allen Mouse Brain Atlas',
#      'species': 'Mouse',
#      'species_name_facet': 1861523945,
#      'tags': None}],
#    'qc_date': '2009-05-02T23:04:42Z',
#    'red_channel': None,
#    'reference_space_id': 9,
#    'rnaseq_design_id': None,
#    'section_thickness': 25.0,
#    'specimen_id': 73633987,
#    'sphinx_id': 18581,
#    'storage_directory': '/external/aibssan/production32/prod340/image_series_74581394/',
#    'weight': 5270},
#   'section_data_set_id': 74581394,
#   'structure_id': 15613,
#   'sum_expressing_pixel_intensity': 11388400.0,
#   'sum_expressing_pixels': 69767.6,
#   'sum_pixel_intensity': 68427200.0,
#   'sum_pixels': 1528400.0,
#   'voxel_energy_cv': 0.277732,
#   'voxel_energy_mean': 7.47171},
#  {'expression_density': 0.0456474,
#   'expression_energy': 7.45118,
#   'id': 450108213,
#   'section_data_set': {'blue_channel': None,
#    'delegate': False,
#    'expression': True,
#    'failed': False,
#    'failed_facet': 734881840,
#    'green_channel': None,
#    'id': 74581394,
#    'name': None,
#    'plane_of_section_id': 1,
#    'products': [{'abbreviation': 'Mouse',
#      'description': 'Genome-wide, high-resolution ISH data detailing gene expression throughout the adult mouse brain.',
#      'id': 1,
#      'name': 'Mouse Brain',
#      'product_name_facet': 2757464828,
#      'resource': 'Allen Mouse Brain Atlas',
#      'species': 'Mouse',
#      'species_name_facet': 1861523945,
#      'tags': None}],
#    'qc_date': '2009-05-02T23:04:42Z',
#    'red_channel': None,
#    'reference_space_id': 9,
#    'rnaseq_design_id': None,
#    'section_thickness': 25.0,
#    'specimen_id': 73633987,
#    'sphinx_id': 18581,
#    'storage_directory': '/external/aibssan/production32/prod340/image_series_74581394/',
# ...
#      'product_name_facet': 2757464828,
#      'resource': 'Allen Mouse Brain Atlas',
#      'species': 'Mouse',
#      'species_name_facet': 1861523945,
#      'tags': None}],
#    'qc_date': '2009-05-02T23:04:42Z',
#    'red_channel': None,
#    'reference_space_id': 9,
#    'rnaseq_design_id': None,
#    'section_thickness': 25.0,
#    'specimen_id': 73633987,
#    'sphinx_id': 18581,
#    'storage_directory': '/external/aibssan/production32/prod340/image_series_74581394/',
#    'weight': 5270},
#   'section_data_set_id': 74581394,
#   'structure_id': 17188,
#   'sum_expressing_pixel_intensity': 13381000.0,
#   'sum_expressing_pixels': 84368.5,
#   'sum_pixel_intensity': 73829300.0,
#   'sum_pixels': 1608550.0,
#   'voxel_energy_cv': 0.149364,
#   'voxel_energy_mean': 8.31865},
#  {'expression_density': 0.0524499,
#   'expression_energy': 8.31864,
#   'id': 450125437,
#   'section_data_set': {'blue_channel': None,
#    'delegate': False,
#    'expression': True,
#    'failed': False,
#    'failed_facet': 734881840,
#    'green_channel': None,
#    'id': 74581394,
#    'name': None,
#    'plane_of_section_id': 1,
#    'products': [{'abbreviation': 'Mouse',
#      'description': 'Genome-wide, high-resolution ISH data detailing gene expression throughout the adult mouse brain.',
#      'id': 1,
#      'name': 'Mouse Brain',
#      'product_name_facet': 2757464828,
#      'resource': 'Allen Mouse Brain Atlas',
#      'species': 'Mouse',
#      'species_name_facet': 1861523945,
#      'tags': None}],
#    'qc_date': '2009-05-02T23:04:42Z',
#    'red_channel': None,
#    'reference_space_id': 9,
#    'rnaseq_design_id': None,
#    'section_thickness': 25.0,
#    'specimen_id': 73633987,
#    'sphinx_id': 18581,
#    'storage_directory': '/external/aibssan/production32/prod340/image_series_74581394/',
#    'weight': 5270},
#   'section_data_set_id': 74581394,
#   'structure_id': 17191,
#   'sum_expressing_pixel_intensity': 13381000.0,
#   'sum_expressing_pixels': 84368.5,
#   'sum_pixel_intensity': 73829300.0,
#   'sum_pixels': 1608550.0,
#   'voxel_energy_cv': 0.149364,
#   'voxel_energy_mean': 8.31865},
#  {'expression_density': 0.0540384,
#   'expression_energy': 8.6352,
#   'id': 450125453,
#   'section_data_set': {'blue_channel': None,
#    'delegate': False,
#    'expression': True,
#    'failed': False,
#    'failed_facet': 734881840,
#    'green_channel': None,
#    'id': 74581394,
#    'name': None,
#    'plane_of_section_id': 1,
#    'products': [{'abbreviation': 'Mouse',
#      'description': 'Genome-wide, high-resolution ISH data detailing gene expression throughout the adult mouse brain.',
#      'id': 1,
#      'name': 'Mouse Brain',
#      'product_name_facet': 2757464828,
#      'resource': 'Allen Mouse Brain Atlas',
#      'species': 'Mouse',
#      'species_name_facet': 1861523945,
#      'tags': None}],
#    'qc_date': '2009-05-02T23:04:42Z',
#    'red_channel': None,
#    'reference_space_id': 9,
#    'rnaseq_design_id': None,
#    'section_thickness': 25.0,
#    'specimen_id': 73633987,
#    'sphinx_id': 18581,
#    'storage_directory': '/external/aibssan/production32/prod340/image_series_74581394/',
#    'weight': 5270},
#   'section_data_set_id': 74581394,
#   'structure_id': 17192,
#   'sum_expressing_pixel_intensity': 4831430.0,
#   'sum_expressing_pixels': 30234.7,
#   'sum_pixel_intensity': 27459600.0,
#   'sum_pixels': 559504.0,
#   'voxel_energy_cv': 0.10426,
#   'voxel_energy_mean': 8.6352},
#  {'expression_density': 0.0539291,
#   'expression_energy': 8.62095,
#   'id': 450125460,
#   'section_data_set': {'blue_channel': None,
#    'delegate': False,
#    'expression': True,
#    'failed': False,
#    'failed_facet': 734881840,
#    'green_channel': None,
#    'id': 74581394,
#    'name': None,
#    'plane_of_section_id': 1,
#    'products': [{'abbreviation': 'Mouse',
#      'description': 'Genome-wide, high-resolution ISH data detailing gene expression throughout the adult mouse brain.',
#      'id': 1,
#      'name': 'Mouse Brain',
#      'product_name_facet': 2757464828,
#      'resource': 'Allen Mouse Brain Atlas',
#      'species': 'Mouse',
#      'species_name_facet': 1861523945,
#      'tags': None}],
#    'qc_date': '2009-05-02T23:04:42Z',
#    'red_channel': None,
#    'reference_space_id': 9,
#    'rnaseq_design_id': None,
#    'section_thickness': 25.0,
#    'specimen_id': 73633987,
#    'sphinx_id': 18581,
#    'storage_directory': '/external/aibssan/production32/prod340/image_series_74581394/',
#    'weight': 5270},
#   'section_data_set_id': 74581394,
#   'structure_id': 17193,
#   'sum_expressing_pixel_intensity': 3316130.0,
#   'sum_expressing_pixels': 20744.3,
#   'sum_pixel_intensity': 19293500.0,
#   'sum_pixels': 384659.0,
#   'voxel_energy_cv': 0.114247,
#   'voxel_energy_mean': 8.62095},
#  {'expression_density': 0.0542789,
#   'expression_energy': 8.66653,
#   'id': 450125475,
#   'section_data_set': {'blue_channel': None,
#    'delegate': False,
#    'expression': True,
#    'failed': False,
#    'failed_facet': 734881840,
#    'green_channel': None,
#    'id': 74581394,
#    'name': None,
#    'plane_of_section_id': 1,
#    'products': [{'abbreviation': 'Mouse',
#      'description': 'Genome-wide, high-resolution ISH data detailing gene expression throughout the adult mouse brain.',
#      'id': 1,
#      'name': 'Mouse Brain',
#      'product_name_facet': 2757464828,
#      'resource': 'Allen Mouse Brain Atlas',
#      'species': 'Mouse',
#      'species_name_facet': 1861523945,
#      'tags': None}],
#    'qc_date': '2009-05-02T23:04:42Z',
#    'red_channel': None,
#    'reference_space_id': 9,
#    'rnaseq_design_id': None,
#    'section_thickness': 25.0,
#    'specimen_id': 73633987,
#    'sphinx_id': 18581,
#    'storage_directory': '/external/aibssan/production32/prod340/image_series_74581394/',
#    'weight': 5270},
#   'section_data_set_id': 74581394,
#   'structure_id': 17194,
#   'sum_expressing_pixel_intensity': 1515300.0,
#   'sum_expressing_pixels': 9490.4,
#   'sum_pixel_intensity': 8166090.0,
#   'sum_pixels': 174845.0,
#   'voxel_energy_cv': 0.0903158,
#   'voxel_energy_mean': 8.66653},
#  {'expression_density': 0.0485859,
#   'expression_energy': 7.65353,
#   'id': 450125485,
#   'section_data_set': {'blue_channel': None,
#    'delegate': False,
#    'expression': True,
#    'failed': False,
#    'failed_facet': 734881840,
#    'green_channel': None,
#    'id': 74581394,
#    'name': None,
#    'plane_of_section_id': 1,
#    'products': [{'abbreviation': 'Mouse',
#      'description': 'Genome-wide, high-resolution ISH data detailing gene expression throughout the adult mouse brain.',
#      'id': 1,
#      'name': 'Mouse Brain',
#      'product_name_facet': 2757464828,
#      'resource': 'Allen Mouse Brain Atlas',
#      'species': 'Mouse',
#      'species_name_facet': 1861523945,
#      'tags': None}],
#    'qc_date': '2009-05-02T23:04:42Z',
#    'red_channel': None,
#    'reference_space_id': 9,
#    'rnaseq_design_id': None,
#    'section_thickness': 25.0,
#    'specimen_id': 73633987,
#    'sphinx_id': 18581,
#    'storage_directory': '/external/aibssan/production32/prod340/image_series_74581394/',
#    'weight': 5270},
#   'section_data_set_id': 74581394,
#   'structure_id': 17196,
#   'sum_expressing_pixel_intensity': 5620360.0,
#   'sum_expressing_pixels': 35679.0,
#   'sum_pixel_intensity': 34049700.0,
#   'sum_pixels': 734349.0,
#   'voxel_energy_cv': 0.130015,
#   'voxel_energy_mean': 7.65353},
#  {'expression_density': 0.048316,
#   'expression_energy': 7.60641,
#   'id': 450125502,
#   'section_data_set': {'blue_channel': None,
#    'delegate': False,
#    'expression': True,
#    'failed': False,
#    'failed_facet': 734881840,
#    'green_channel': None,
#    'id': 74581394,
#    'name': None,
#    'plane_of_section_id': 1,
#    'products': [{'abbreviation': 'Mouse',
#      'description': 'Genome-wide, high-resolution ISH data detailing gene expression throughout the adult mouse brain.',
#      'id': 1,
#      'name': 'Mouse Brain',
#      'product_name_facet': 2757464828,
#      'resource': 'Allen Mouse Brain Atlas',
#      'species': 'Mouse',
#      'species_name_facet': 1861523945,
#      'tags': None}],
#    'qc_date': '2009-05-02T23:04:42Z',
#    'red_channel': None,
#    'reference_space_id': 9,
#    'rnaseq_design_id': None,
#    'section_thickness': 25.0,
#    'specimen_id': 73633987,
#    'sphinx_id': 18581,
#    'storage_directory': '/external/aibssan/production32/prod340/image_series_74581394/',
#    'weight': 5270},
#   'section_data_set_id': 74581394,
#   'structure_id': 17203,
#   'sum_expressing_pixel_intensity': 4787800.0,
#   'sum_expressing_pixels': 30412.1,
#   'sum_pixel_intensity': 29545100.0,
#   'sum_pixels': 629442.0,
#   'voxel_energy_cv': 0.130038,
#   'voxel_energy_mean': 7.60641},
#  {'expression_density': 0.048316,
#   'expression_energy': 7.60641,
#   'id': 450125510,
#   'section_data_set': {'blue_channel': None,
#    'delegate': False,
#    'expression': True,
#    'failed': False,
#    'failed_facet': 734881840,
#    'green_channel': None,
#    'id': 74581394,
#    'name': None,
#    'plane_of_section_id': 1,
#    'products': [{'abbreviation': 'Mouse',
#      'description': 'Genome-wide, high-resolution ISH data detailing gene expression throughout the adult mouse brain.',
#      'id': 1,
#      'name': 'Mouse Brain',
#      'product_name_facet': 2757464828,
#      'resource': 'Allen Mouse Brain Atlas',
#      'species': 'Mouse',
#      'species_name_facet': 1861523945,
#      'tags': None}],
#    'qc_date': '2009-05-02T23:04:42Z',
#    'red_channel': None,
#    'reference_space_id': 9,
#    'rnaseq_design_id': None,
#    'section_thickness': 25.0,
#    'specimen_id': 73633987,
#    'sphinx_id': 18581,
#    'storage_directory': '/external/aibssan/production32/prod340/image_series_74581394/',
#    'weight': 5270},
#   'section_data_set_id': 74581394,
#   'structure_id': 17204,
#   'sum_expressing_pixel_intensity': 4787800.0,
#   'sum_expressing_pixels': 30412.1,
#   'sum_pixel_intensity': 29545100.0,
#   'sum_pixels': 629442.0,
#   'voxel_energy_cv': 0.130038,
#   'voxel_energy_mean': 7.60641},
#  {'expression_density': 0.0502052,
#   'expression_energy': 7.93626,
#   'id': 450125520,
#   'section_data_set': {'blue_channel': None,
#    'delegate': False,
#    'expression': True,
#    'failed': False,
#    'failed_facet': 734881840,
#    'green_channel': None,
#    'id': 74581394,
#    'name': None,
#    'plane_of_section_id': 1,
#    'products': [{'abbreviation': 'Mouse',
#      'description': 'Genome-wide, high-resolution ISH data detailing gene expression throughout the adult mouse brain.',
#      'id': 1,
#      'name': 'Mouse Brain',
#      'product_name_facet': 2757464828,
#      'resource': 'Allen Mouse Brain Atlas',
#      'species': 'Mouse',
#      'species_name_facet': 1861523945,
#      'tags': None}],
#    'qc_date': '2009-05-02T23:04:42Z',
#    'red_channel': None,
#    'reference_space_id': 9,
#    'rnaseq_design_id': None,
#    'section_thickness': 25.0,
#    'specimen_id': 73633987,
#    'sphinx_id': 18581,
#    'storage_directory': '/external/aibssan/production32/prod340/image_series_74581394/',
#    'weight': 5270},
#   'section_data_set_id': 74581394,
#   'structure_id': 17205,
#   'sum_expressing_pixel_intensity': 832567.0,
#   'sum_expressing_pixels': 5266.87,
#   'sum_pixel_intensity': 4504580.0,
#   'sum_pixels': 104907.0,
#   'voxel_energy_cv': 0.151508,
#   'voxel_energy_mean': 7.93625},
#  {'expression_density': 0.0502052,
#   'expression_energy': 7.93626,
#   'id': 450125533,
#   'section_data_set': {'blue_channel': None,
#    'delegate': False,
#    'expression': True,
#    'failed': False,
#    'failed_facet': 734881840,
#    'green_channel': None,
#    'id': 74581394,
#    'name': None,
#    'plane_of_section_id': 1,
#    'products': [{'abbreviation': 'Mouse',
#      'description': 'Genome-wide, high-resolution ISH data detailing gene expression throughout the adult mouse brain.',
#      'id': 1,
#      'name': 'Mouse Brain',
#      'product_name_facet': 2757464828,
#      'resource': 'Allen Mouse Brain Atlas',
#      'species': 'Mouse',
#      'species_name_facet': 1861523945,
#      'tags': None}],
#    'qc_date': '2009-05-02T23:04:42Z',
#    'red_channel': None,
#    'reference_space_id': 9,
#    'rnaseq_design_id': None,
#    'section_thickness': 25.0,
#    'specimen_id': 73633987,
#    'sphinx_id': 18581,
#    'storage_directory': '/external/aibssan/production32/prod340/image_series_74581394/',
#    'weight': 5270},
#   'section_data_set_id': 74581394,
#   'structure_id': 17206,
#   'sum_expressing_pixel_intensity': 832567.0,
#   'sum_expressing_pixels': 5266.87,
#   'sum_pixel_intensity': 4504580.0,
#   'sum_pixels': 104907.0,
#   'voxel_energy_cv': 0.151508,
#   'voxel_energy_mean': 7.93625},
#  {'expression_density': 0.0580385,
#   'expression_energy': 9.14557,
#   'id': 450125553,
#   'section_data_set': {'blue_channel': None,
#    'delegate': False,
#    'expression': True,
#    'failed': False,
#    'failed_facet': 734881840,
#    'green_channel': None,
#    'id': 74581394,
#    'name': None,
#    'plane_of_section_id': 1,
#    'products': [{'abbreviation': 'Mouse',
#      'description': 'Genome-wide, high-resolution ISH data detailing gene expression throughout the adult mouse brain.',
#      'id': 1,
#      'name': 'Mouse Brain',
#      'product_name_facet': 2757464828,
#      'resource': 'Allen Mouse Brain Atlas',
#      'species': 'Mouse',
#      'species_name_facet': 1861523945,
#      'tags': None}],
#    'qc_date': '2009-05-02T23:04:42Z',
#    'red_channel': None,
#    'reference_space_id': 9,
#    'rnaseq_design_id': None,
#    'section_thickness': 25.0,
#    'specimen_id': 73633987,
#    'sphinx_id': 18581,
#    'storage_directory': '/external/aibssan/production32/prod340/image_series_74581394/',
#    'weight': 5270},
#   'section_data_set_id': 74581394,
#   'structure_id': 17209,
#   'sum_expressing_pixel_intensity': 47292700.0,
#   'sum_expressing_pixels': 300123.0,
#   'sum_pixel_intensity': 249367000.0,
#   'sum_pixels': 5171110.0,
#   'voxel_energy_cv': 0.167064,
#   'voxel_energy_mean': 9.14584},
#  {'expression_density': 0.0498775,
#   'expression_energy': 7.78872,
#   'id': 450125578,
#   'section_data_set': {'blue_channel': None,
#    'delegate': False,
#    'expression': True,
#    'failed': False,
#    'failed_facet': 734881840,
#    'green_channel': None,
#    'id': 74581394,
#    'name': None,
#    'plane_of_section_id': 1,
#    'products': [{'abbreviation': 'Mouse',
#      'description': 'Genome-wide, high-resolution ISH data detailing gene expression throughout the adult mouse brain.',
#      'id': 1,
#      'name': 'Mouse Brain',
#      'product_name_facet': 2757464828,
#      'resource': 'Allen Mouse Brain Atlas',
#      'species': 'Mouse',
#      'species_name_facet': 1861523945,
#      'tags': None}],
#    'qc_date': '2009-05-02T23:04:42Z',
#    'red_channel': None,
#    'reference_space_id': 9,
#    'rnaseq_design_id': None,
#    'section_thickness': 25.0,
#    'specimen_id': 73633987,
#    'sphinx_id': 18581,
#    'storage_directory': '/external/aibssan/production32/prod340/image_series_74581394/',
#    'weight': 5270},
#   'section_data_set_id': 74581394,
#   'structure_id': 17212,
#   'sum_expressing_pixel_intensity': 15524700.0,
#   'sum_expressing_pixels': 99417.5,
#   'sum_pixel_intensity': 95940700.0,
#   'sum_pixels': 1993230.0,
#   'voxel_energy_cv': 0.115956,
#   'voxel_energy_mean': 7.78872},
#  {'expression_density': 0.0513465,
#   'expression_energy': 8.00831,
#   'id': 450125604,
#   'section_data_set': {'blue_channel': None,
#    'delegate': False,
#    'expression': True,
#    'failed': False,
#    'failed_facet': 734881840,
#    'green_channel': None,
#    'id': 74581394,
#    'name': None,
#    'plane_of_section_id': 1,
#    'products': [{'abbreviation': 'Mouse',
#      'description': 'Genome-wide, high-resolution ISH data detailing gene expression throughout the adult mouse brain.',
#      'id': 1,
#      'name': 'Mouse Brain',
#      'product_name_facet': 2757464828,
#      'resource': 'Allen Mouse Brain Atlas',
#      'species': 'Mouse',
#      'species_name_facet': 1861523945,
#      'tags': None}],
#    'qc_date': '2009-05-02T23:04:42Z',
#    'red_channel': None,
#    'reference_space_id': 9,
#    'rnaseq_design_id': None,
#    'section_thickness': 25.0,
#    'specimen_id': 73633987,
#    'sphinx_id': 18581,
#    'storage_directory': '/external/aibssan/production32/prod340/image_series_74581394/',
#    'weight': 5270},
#   'section_data_set_id': 74581394,
#   'structure_id': 17213,
#   'sum_expressing_pixel_intensity': 9801490.0,
#   'sum_expressing_pixels': 62843.8,
#   'sum_pixel_intensity': 60128200.0,
#   'sum_pixels': 1223920.0,
#   'voxel_energy_cv': 0.102001,
#   'voxel_energy_mean': 8.00831},
#  ...]

# %%
with open('structureIds.json') as json_data:
    structureIds = json.load(json_data)

with open('structHash.json') as json_data:
    structHash = json.load(json_data) 
    
with open('dataSets.json') as json_data:
    dataSets = json.load(json_data) 
# structureIds
# dataSets?

# %%
sidHash = dict([(id, i) for (i, id) in enumerate(structureIds)])
didHash = dict([(d['id'], i) for (i, d) in enumerate(mini_data)])

# %%
sidHash = dict([(id, i) for (i, id) in enumerate(structureIds)])
didHash = {}
for i, us in enumerate(my_union):
    # for each unionize
    for j, u in enumerate(us):
        didHash[u['section_data_set_id']] = i

# %%
nstructs = len(structureIds)
ndata = len(my_union) #my_union

expression = np.empty([nstructs, ndata])
expression.fill(np.nan)

# For each data set's set of unionizes, then for each individual structure,
# fill in the structure's expression vector.
for i, us in enumerate(my_union):
    # for each unionize
    for j, u in enumerate(us):
        sid = u['structure_id']
        did = u['section_data_set_id']


#         if sidHash.has_key(sid) and didHash.has_key(did):
        if sid in sidHash and did in didHash: 
            expression[sidHash[sid]][didHash[did]] = u['expression_energy']

# numpy has a masked_array data structure that performs computations while
# filtering out values you don't care about.  In this case, we don't want
# the correlation computation to use NaN's, which indicate that no
# expression was measured for a structure.
mdat = np.ma.masked_array(expression, np.isnan(expression))
corr = np.ma.corrcoef(mdat)

# %%
# Save expression data and correlation matrix
f = open('expression.json', "w")
f.write(json.dumps(expression.tolist()))
f.close()

f = open('gene_correlations.json', "w")
f.write(json.dumps(corr.tolist()))
f.close()

# %%
np.shape(expression)
plt.imshow(expression)

# %%
plt.imshow(corr)

# %%
region_names = [structHash[d]['name'] for d in structureIds]
region_depth = [structHash[d]['depth'] for d in structureIds]

# %%
structHash['149']
# Out:
# {'acronym': 'PVT',
#  'atlas_id': 301,
#  'color_hex_triplet': 'FF909F',
#  'depth': 7,
#  'failed': False,
#  'failed_facet': 734881840,
#  'graph_id': 1,
#  'graph_order': 688,
#  'hemisphere_id': 3,
#  'id': 149,
#  'name': 'Paraventricular nucleus of the thalamus',
#  'neuro_name_structure_id': None,
#  'neuro_name_structure_id_path': None,
#  'num_children': 0,
#  'ontology_id': 1,
#  'parent_structure_id': 571,
#  'safe_name': 'Paraventricular nucleus of the thalamus',
#  'sphinx_id': 689,
#  'st_level': None,
#  'structure_id_path': [997, 8, 343, 1129, 549, 856, 571, 149],
#  'structure_name_facet': 3631961400,
#  'weight': 8690}

# %%
structHash[structureIds[0]]
# Out:
# {'acronym': 'TMv',
#  'atlas_id': 424,
#  'color_hex_triplet': 'FF4C3E',
#  'depth': 8,
#  'failed': False,
#  'failed_facet': 734881840,
#  'graph_id': 1,
#  'graph_order': 763,
#  'hemisphere_id': 3,
#  'id': 1,
#  'name': 'Tuberomammillary nucleus, ventral part',
#  'neuro_name_structure_id': None,
#  'neuro_name_structure_id_path': None,
#  'num_children': 0,
#  'ontology_id': 1,
#  'parent_structure_id': 557,
#  'safe_name': 'Tuberomammillary nucleus ventral part',
#  'sphinx_id': 764,
#  'st_level': None,
#  'structure_id_path': [997, 8, 343, 1129, 1097, 467, 331, 557, 1],
#  'structure_name_facet': 3678649713,
#  'weight': 8690}

# %%
#Print out corr and name/depth lists to .csv for loading into matlab
import scipy.io as sio
sio.savemat('allen_names.mat',{'allen_names':region_names})
sio.savemat('allen_depth.mat',{'allen_depths':region_depth})
sio.savemat('allen_CC.mat',{'allen_cc':corr.data})

# %%
structHash?

# %%
sH
# Out:
#                                                                 1          \
# acronym                                                               TMv
# atlas_id                                                              424
# color_hex_triplet                                                  FF4C3E
# depth                                                                   8
# failed                                                              False
# failed_facet                                                    734881840
# graph_id                                                                1
# graph_order                                                           763
# hemisphere_id                                                           3
# id                                                                      1
# name                               Tuberomammillary nucleus, ventral part
# neuro_name_structure_id                                              None
# neuro_name_structure_id_path                                         None
# num_children                                                            0
# ontology_id                                                             1
# parent_structure_id                                                   557
# safe_name                           Tuberomammillary nucleus ventral part
# sphinx_id                                                             764
# st_level                                                             None
# structure_id_path             [997, 8, 343, 1129, 1097, 467, 331, 557, 1]
# structure_name_facet                                           3678649713
# weight                                                               8690
#
#                                                                    2          \
# acronym                                                              SSp-m6b
# atlas_id                                                                 990
# color_hex_triplet                                                     188064
# depth                                                                      9
# failed                                                                 False
# failed_facet                                                       734881840
# graph_id                                                                   1
# graph_order                                                               78
# hemisphere_id                                                              3
# id                                                                         2
# name                             Primary somatosensory area, mouth, layer 6b
# neuro_name_structure_id                                                 None
# neuro_name_structure_id_path                                            None
# num_children                                                               0
# ontology_id                                                                1
# parent_structure_id                                                      345
# safe_name                          Primary somatosensory area mouth layer 6b
# sphinx_id                                                                 79
# st_level                                                                None
# structure_id_path             [997, 8, 567, 688, 695, 315, 453, 322, 345, 2]
# structure_name_facet                                              1425070870
# weight                                                                  8690
#
#                                          3          \
# acronym                                        sec
# atlas_id                                       707
# color_hex_triplet                           AAAAAA
# depth                                            3
# failed                                       False
# failed_facet                             734881840
# graph_id                                         1
# graph_order                                   1288
# hemisphere_id                                    3
# id                                               3
# name                             secondary fissure
# neuro_name_structure_id                       None
# neuro_name_structure_id_path                  None
# num_children                                     0
# ontology_id                                      1
# parent_structure_id                           1040
# safe_name                        secondary fissure
# sphinx_id                                     1289
# st_level                                      None
# structure_id_path             [997, 1024, 1040, 3]
# structure_name_facet                    1603026106
# weight                                        8690
#
#                                                4          \
# acronym                                               IC
# atlas_id                                             141
# color_hex_triplet                                 FF7AFF
# depth                                                  5
# failed                                             False
# failed_facet                                   734881840
# graph_id                                               1
# graph_order                                          799
# hemisphere_id                                          3
# id                                                     4
# name                                 Inferior colliculus
# neuro_name_structure_id                             None
# neuro_name_structure_id_path                        None
# num_children                                           3
# ontology_id                                            1
# parent_structure_id                                  339
# safe_name                            Inferior colliculus
# sphinx_id                                            800
# st_level                                            None
# structure_id_path             [997, 8, 343, 313, 339, 4]
# structure_name_facet                          3456805092
# weight                                              8690
#
#                                              6          \
# acronym                                            int
# atlas_id                                           566
# color_hex_triplet                               CCCCCC
# depth                                                4
# failed                                           False
# failed_facet                                 734881840
# graph_id                                             1
# graph_order                                       1173
# hemisphere_id                                        3
# id                                                   6
# name                                  internal capsule
# neuro_name_structure_id                           None
# neuro_name_structure_id_path                      None
# num_children                                         0
# ontology_id                                          1
# parent_structure_id                                784
# safe_name                             internal capsule
# sphinx_id                                         1174
# st_level                                          None
# structure_id_path             [997, 1009, 983, 784, 6]
# structure_name_facet                        2936038281
# weight                                            8690
#
#                                                                 7          \
# acronym                                                               PSV
# atlas_id                                                              283
# color_hex_triplet                                                  FFAE6F
# depth                                                                   6
# failed                                                              False
# failed_facet                                                    734881840
# graph_id                                                                1
# graph_order                                                           864
# hemisphere_id                                                           3
# id                                                                      7
# name                          Principal sensory nucleus of the trigeminal
# neuro_name_structure_id                                              None
# neuro_name_structure_id_path                                         None
# num_children                                                            0
# ontology_id                                                             1
# parent_structure_id                                                  1132
# safe_name                     Principal sensory nucleus of the trigeminal
# sphinx_id                                                             865
# st_level                                                             None
# structure_id_path                       [997, 8, 343, 1065, 771, 1132, 7]
# structure_name_facet                                            977401861
# weight                                                               8690
#
#                                                   8          \
# acronym                                                grey
# atlas_id                                                  0
# color_hex_triplet                                    BFDAE3
# depth                                                     1
# failed                                                False
# failed_facet                                      734881840
# graph_id                                                  1
# graph_order                                               1
# hemisphere_id                                             3
# id                                                        8
# name                          Basic cell groups and regions
# neuro_name_structure_id                                None
# neuro_name_structure_id_path                           None
# num_children                                              3
# ontology_id                                               1
# parent_structure_id                                     997
# safe_name                     Basic cell groups and regions
# sphinx_id                                                 2
# st_level                                               None
# structure_id_path                                  [997, 8]
# structure_name_facet                             2244697386
# weight                                                 8690
#
#                                                                    9          \
# acronym                                                             SSp-tr6a
# atlas_id                                                                 991
# color_hex_triplet                                                     188064
# depth                                                                      9
# failed                                                                 False
# failed_facet                                                       734881840
# graph_id                                                                   1
# graph_order                                                               91
# hemisphere_id                                                              3
# id                                                                         9
# name                             Primary somatosensory area, trunk, layer 6a
# neuro_name_structure_id                                                 None
# neuro_name_structure_id_path                                            None
# num_children                                                               0
# ontology_id                                                                1
# parent_structure_id                                                      361
# safe_name                          Primary somatosensory area trunk layer 6a
# sphinx_id                                                                 92
# st_level                                                                None
# structure_id_path             [997, 8, 567, 688, 695, 315, 453, 322, 361, 9]
# structure_name_facet                                              1364764776
# weight                                                                  8690
#
#                                                                       10         \
# acronym                                                                    SCig
# atlas_id                                                                    425
# color_hex_triplet                                                        FF90FF
# depth                                                                         6
# failed                                                                    False
# failed_facet                                                          734881840
# graph_id                                                                      1
# graph_order                                                                 819
# hemisphere_id                                                                 3
# id                                                                           10
# name                          Superior colliculus, motor related, intermedia...
# neuro_name_structure_id                                                    None
# neuro_name_structure_id_path                                               None
# num_children                                                                  3
# ontology_id                                                                   1
# parent_structure_id                                                         294
# safe_name                     Superior colliculus motor related intermediate...
# sphinx_id                                                                   820
# st_level                                                                   None
# structure_id_path                              [997, 8, 343, 313, 323, 294, 10]
# structure_name_facet                                                 4208210812
# weight                                                                     8690
#
#                                            11         \
# acronym                                          plf
# atlas_id                                         708
# color_hex_triplet                             AAAAAA
# depth                                              3
# failed                                         False
# failed_facet                               734881840
# graph_id                                           1
# graph_order                                     1289
# hemisphere_id                                      3
# id                                                11
# name                          posterolateral fissure
# neuro_name_structure_id                         None
# neuro_name_structure_id_path                    None
# num_children                                       0
# ontology_id                                        1
# parent_structure_id                             1040
# safe_name                     posterolateral fissure
# sphinx_id                                       1290
# st_level                                        None
# structure_id_path              [997, 1024, 1040, 11]
# structure_name_facet                      3968698314
# weight                                          8690
#
#                                                 ...                     \
# acronym                                         ...
# atlas_id                                        ...
# color_hex_triplet                               ...
# depth                                           ...
# failed                                          ...
# failed_facet                                    ...
# graph_id                                        ...
# graph_order                                     ...
# hemisphere_id                                   ...
# id                                              ...
# name                                            ...
# neuro_name_structure_id                         ...
# neuro_name_structure_id_path                    ...
# num_children                                    ...
# ontology_id                                     ...
# parent_structure_id                             ...
# safe_name                                       ...
# sphinx_id                                       ...
# st_level                                        ...
# structure_id_path                               ...
# structure_name_facet                            ...
# weight                                          ...
#
#                                                                  526322264  \
# acronym                                                              FRP6b
# atlas_id                                                              None
# color_hex_triplet                                                   268F45
# depth                                                                    7
# failed                                                               False
# failed_facet                                                     734881840
# graph_id                                                                 1
# graph_order                                                             11
# hemisphere_id                                                            3
# id                                                               526322264
# name                                                Frontal pole, layer 6b
# neuro_name_structure_id                                               None
# neuro_name_structure_id_path                                          None
# num_children                                                             0
# ontology_id                                                              1
# parent_structure_id                                                    184
# safe_name                                            Frontal pole layer 6b
# sphinx_id                                                               12
# st_level                                                              None
# structure_id_path             [997, 8, 567, 688, 695, 315, 184, 526322264]
# structure_name_facet                                            3514382500
# weight                                                                8690
#
#                                                                       527696977  \
# acronym                                                                  ORBm6b
# atlas_id                                                                   None
# color_hex_triplet                                                        248A5E
# depth                                                                         8
# failed                                                                    False
# failed_facet                                                          734881840
# graph_id                                                                      1
# graph_order                                                                 270
# hemisphere_id                                                                 3
# id                                                                    527696977
# name                                        Orbital area, medial part, layer 6b
# neuro_name_structure_id                                                    None
# neuro_name_structure_id_path                                               None
# num_children                                                                  0
# ontology_id                                                                   1
# parent_structure_id                                                         731
# safe_name                                     Orbital area medial part layer 6b
# sphinx_id                                                                   271
# st_level                                                                   None
# structure_id_path             [997, 8, 567, 688, 695, 315, 714, 731, 527696977]
# structure_name_facet                                                 3958566100
# weight                                                                     8690
#
#                                                             549009199  \
# acronym                                                           LSS
# atlas_id                                                         None
# color_hex_triplet                                              80CDF8
# depth                                                               6
# failed                                                          False
# failed_facet                                                734881840
# graph_id                                                            1
# graph_order                                                       583
# hemisphere_id                                                       3
# id                                                          549009199
# name                                        Lateral strip of striatum
# neuro_name_structure_id                                          None
# neuro_name_structure_id_path                                     None
# num_children                                                        0
# ontology_id                                                         1
# parent_structure_id                                               493
# safe_name                                   Lateral strip of striatum
# sphinx_id                                                         584
# st_level                                                         None
# structure_id_path             [997, 8, 567, 623, 477, 493, 549009199]
# structure_name_facet                                       1436254915
# weight                                                           8690
#
#                                                              549009203  \
# acronym                                                            RPF
# atlas_id                                                          None
# color_hex_triplet                                               FF90FF
# depth                                                                6
# failed                                                           False
# failed_facet                                                 734881840
# graph_id                                                             1
# graph_order                                                        834
# hemisphere_id                                                        3
# id                                                           549009203
# name                                       Retroparafascicular nucleus
# neuro_name_structure_id                                           None
# neuro_name_structure_id_path                                      None
# num_children                                                         0
# ontology_id                                                          1
# parent_structure_id                                               1100
# safe_name                                  Retroparafascicular nucleus
# sphinx_id                                                          835
# st_level                                                          None
# structure_id_path             [997, 8, 343, 313, 323, 1100, 549009203]
# structure_name_facet                                        2559458743
# weight                                                            8690
#
#                                                        549009207  \
# acronym                                                     InCo
# atlas_id                                                    None
# color_hex_triplet                                         FF90FF
# depth                                                          5
# failed                                                     False
# failed_facet                                           734881840
# graph_id                                                       1
# graph_order                                                  835
# hemisphere_id                                                  3
# id                                                     549009207
# name                                     Intercollicular nucleus
# neuro_name_structure_id                                     None
# neuro_name_structure_id_path                                None
# num_children                                                   0
# ontology_id                                                    1
# parent_structure_id                                          323
# safe_name                                Intercollicular nucleus
# sphinx_id                                                    836
# st_level                                                    None
# structure_id_path             [997, 8, 343, 313, 323, 549009207]
# structure_name_facet                                  3796827043
# weight                                                      8690
#
#                                                        549009211  \
# acronym                                                      MA3
# atlas_id                                                    None
# color_hex_triplet                                         FF90FF
# depth                                                          5
# failed                                                     False
# failed_facet                                           734881840
# graph_id                                                       1
# graph_order                                                  839
# hemisphere_id                                                  3
# id                                                     549009211
# name                          Medial accesory oculomotor nucleus
# neuro_name_structure_id                                     None
# neuro_name_structure_id_path                                None
# num_children                                                   0
# ontology_id                                                    1
# parent_structure_id                                          323
# safe_name                     Medial accesory oculomotor nucleus
# sphinx_id                                                    840
# st_level                                                    None
# structure_id_path             [997, 8, 343, 313, 323, 549009211]
# structure_name_facet                                   842672202
# weight                                                      8690
#
#                                                              549009215  \
# acronym                                                             P5
# atlas_id                                                          None
# color_hex_triplet                                               FFBA86
# depth                                                                6
# failed                                                           False
# failed_facet                                                 734881840
# graph_id                                                             1
# graph_order                                                        894
# hemisphere_id                                                        3
# id                                                           549009215
# name                                               Peritrigeminal zone
# neuro_name_structure_id                                           None
# neuro_name_structure_id_path                                      None
# num_children                                                         0
# ontology_id                                                          1
# parent_structure_id                                                987
# safe_name                                          Peritrigeminal zone
# sphinx_id                                                          895
# st_level                                                          None
# structure_id_path             [997, 8, 343, 1065, 771, 987, 549009215]
# structure_name_facet                                        2750316450
# weight                                                            8690
#
#                                                              549009219  \
# acronym                                                           Acs5
# atlas_id                                                          None
# color_hex_triplet                                               FFBA86
# depth                                                                6
# failed                                                           False
# failed_facet                                                 734881840
# graph_id                                                             1
# graph_order                                                        895
# hemisphere_id                                                        3
# id                                                           549009219
# name                                      Accessory trigeminal nucleus
# neuro_name_structure_id                                           None
# neuro_name_structure_id_path                                      None
# num_children                                                         0
# ontology_id                                                          1
# parent_structure_id                                                987
# safe_name                                 Accessory trigeminal nucleus
# sphinx_id                                                          896
# st_level                                                          None
# structure_id_path             [997, 8, 343, 1065, 771, 987, 549009219]
# structure_name_facet                                        1603998582
# weight                                                            8690
#
#                                                              549009223  \
# acronym                                                            PC5
# atlas_id                                                          None
# color_hex_triplet                                               FFBA86
# depth                                                                6
# failed                                                           False
# failed_facet                                                 734881840
# graph_id                                                             1
# graph_order                                                        896
# hemisphere_id                                                        3
# id                                                           549009223
# name                                     Parvicellular motor 5 nucleus
# neuro_name_structure_id                                           None
# neuro_name_structure_id_path                                      None
# num_children                                                         0
# ontology_id                                                          1
# parent_structure_id                                                987
# safe_name                                Parvicellular motor 5 nucleus
# sphinx_id                                                          897
# st_level                                                          None
# structure_id_path             [997, 8, 343, 1065, 771, 987, 549009223]
# structure_name_facet                                        2234903594
# weight                                                            8690
#
#                                                              549009227
# acronym                                                             I5
# atlas_id                                                          None
# color_hex_triplet                                               FFBA86
# depth                                                                6
# failed                                                           False
# failed_facet                                                 734881840
# graph_id                                                             1
# graph_order                                                        897
# hemisphere_id                                                        3
# id                                                           549009227
# name                                           Intertrigeminal nucleus
# neuro_name_structure_id                                           None
# neuro_name_structure_id_path                                      None
# num_children                                                         0
# ontology_id                                                          1
# parent_structure_id                                                987
# safe_name                                      Intertrigeminal nucleus
# sphinx_id                                                          898
# st_level                                                          None
# structure_id_path             [997, 8, 343, 1065, 771, 987, 549009227]
# structure_name_facet                                        1777267098
# weight                                                            8690
#
# [22 rows x 1299 columns]

# %%
structs = QueryAPI(STRUCTURES_URL)
# Out:
# http://api.brain-map.org/api/v2/data/Structure/query.json?criteria=[graph_id$eq1]&start_row=0&num_rows=20000

# %%
structs[structureIds]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-65-77a52b01c4a8> in <module>()
# ----> 1 structs[structureIds]
#
# NameError: name 'structs' is not defined

# %%
structHash[315]
# Out:
# {'acronym': 'Isocortex',
#  'atlas_id': 746,
#  'color_hex_triplet': '70FF71',
#  'depth': 5,
#  'failed': False,
#  'failed_facet': 734881840,
#  'graph_id': 1,
#  'graph_order': 5,
#  'hemisphere_id': 3,
#  'id': 315,
#  'name': 'Isocortex',
#  'neuro_name_structure_id': None,
#  'neuro_name_structure_id_path': None,
#  'num_children': 17,
#  'ontology_id': 1,
#  'parent_structure_id': 695,
#  'safe_name': 'Isocortex',
#  'sphinx_id': 6,
#  'st_level': None,
#  'structure_id_path': [997, 8, 567, 688, 695, 315],
#  'structure_name_facet': 2323732626,
#  'weight': 8690}

# %%
# !ls
# Out:
# dataSets.json			structHash.json
# load_and_correlate_allen.ipynb	structureIds.json

# %% [markdown]
# # APPENDIX: code to download all the data
# ## NOTE: expression data will take a long time to download...

# %%
# Initialise libraries, set dataset paths and generate queries
API_PATH = "http://api.brain-map.org/api/v2/data"
GRAPH_ID = 1
MOUSE_PRODUCT_ID = 1 # aba
PLANE_ID = 1 # coronal
TOP_N = 20000

DATA_SET_QUERY_URL = ("%s/SectionDataSet/query.json" +\
                          "?criteria=[failed$eq'false'][expression$eq'true']" +\
                          ",products[id$eq%d]" +\
                          ",plane_of_section[id$eq%d]") \
                          % (API_PATH, MOUSE_PRODUCT_ID, PLANE_ID)

UNIONIZE_FMT = "%s/StructureUnionize/query.json" +\
    "?criteria=[section_data_set_id$eq%d]" +\
    "&include=section_data_set(products[id$eq%d])" % (MOUSE_PRODUCT_ID)

STRUCTURES_URL = ("%s/Structure/query.json?" +\
                      "criteria=[graph_id$eq%d]") \
                      % (API_PATH, GRAPH_ID)

import json
import sys
import os
import string

from urllib.request import urlopen

def QueryAPI(url):
    start_row = 0
    num_rows = 20000
    total_rows = -1
    rows = []
    done = False
    
    while not done:
        pagedUrl = url + '&start_row=%d&num_rows=%d' % (start_row,num_rows)

        print(pagedUrl)
        source = urlopen(pagedUrl).read().decode('utf8') # py3
#         source = urllib.urlopen(pagedUrl).read()

        response = json.loads(source)
        rows += response['msg']
        
        if total_rows < 0:
            total_rows = int(response['total_rows'])

        start_row += len(response['msg'])

        if start_row >= total_rows:
            done = True

    return rows

# %%
# Download and save dataset list
def DownloadDataSets(n):
    dataSets = QueryAPI(DATA_SET_QUERY_URL)
  
    if n <= 0:
        return dataSets
    else:
        n = min(len(dataSets), n)

    return dataSets[:n]

n = -1
dataSets = DownloadDataSets(n)

f = open('dataSets.json', "w")
f.write(json.dumps(dataSets))
f.close()
# Out:
# http://api.brain-map.org/api/v2/data/SectionDataSet/query.json?criteria=[failed$eq'false'][expression$eq'true'],products[id$eq1],plane_of_section[id$eq1]&start_row=0&num_rows=20000

# %%
# Download and save structure data

def DownloadStructures():
    structs = QueryAPI(STRUCTURES_URL)

    # Build a dict from structure id to structure and identify each node's
    # direct descendants.
    structHash = {}
    for s in structs:
        s['num_children'] = 0
        s['structure_id_path'] = [
            int(sid) for sid in s['structure_id_path'].split('/') if sid != '']
        structHash[s['id']] = s

        # python 3 renamed iteritems to items
    for sid, s in structHash.items():
        if len(s['structure_id_path']) > 1:
            parentId = s['structure_id_path'][-2]
            structHash[parentId]['num_children'] += 1

    # pull out the structure ids for structures in this structure graph that
    # have no children (i.e. just the leaves)
    corrStructIds = [sid for sid, s in structHash.items() if s[
        'num_children'] == 0]

    return sorted(corrStructIds), structHash

structureIds, structHash = DownloadStructures()

# Save structureIds and structHash
f = open('structureIds.json', "w")
f.write(json.dumps(structureIds))
f.close()

f = open('structHash.json', "w")
f.write(json.dumps(structHash))
f.close()
# Out:
# http://api.brain-map.org/api/v2/data/Structure/query.json?criteria=[graph_id$eq1]&start_row=0&num_rows=20000

# %%
# Download expression data, but save as you go
def QueryAPI_saving(url,f_id):
    start_row = 0
    num_rows = 20000
    total_rows = -1
    rows = []
    done = False
    
    while not done:
        pagedUrl = url + '&start_row=%d&num_rows=%d' % (start_row,num_rows)

        print(pagedUrl)
        source = urlopen(pagedUrl).read().decode('utf8') # py3
#         source = urllib.urlopen(pagedUrl).read()

        response = json.loads(source)
        rows += response['msg']
        
        if total_rows < 0:
            total_rows = int(response['total_rows'])

        start_row += len(response['msg'])

        if start_row >= total_rows:
            done = True
            
            # Parse url to get dataset name
            
            
            print(f_id)
            fname = "expression_"+ f_id +".json"
            # save as you go
            f = open(fname,"w")
            f.write(json.dumps(rows))
            f.close()
            

    return rows

# %%
# Download expression data and save as you go.
def DownloadExpression(dataSets):
    return [QueryAPI_saving(UNIONIZE_FMT % (API_PATH,d['id']),str(d['id'])) for d in dataSets]
#     return [QueryAPI(UNIONIZE_FMT % (API_PATH,d['id'])) for d in dataSets]

# %%
# example small download
mini_data = dataSets[:5]
unionizes = DownloadExpression(mini_data)
# Out:
# http://api.brain-map.org/api/v2/data/StructureUnionize/query.json?criteria=[section_data_set_id$eq74581394]&include=section_data_set(products[id$eq1])&start_row=0&num_rows=20000
# 74581394
# http://api.brain-map.org/api/v2/data/StructureUnionize/query.json?criteria=[section_data_set_id$eq73931634]&include=section_data_set(products[id$eq1])&start_row=0&num_rows=20000
# 73931634
# http://api.brain-map.org/api/v2/data/StructureUnionize/query.json?criteria=[section_data_set_id$eq75774111]&include=section_data_set(products[id$eq1])&start_row=0&num_rows=20000
# 75774111
# http://api.brain-map.org/api/v2/data/StructureUnionize/query.json?criteria=[section_data_set_id$eq73929596]&include=section_data_set(products[id$eq1])&start_row=0&num_rows=20000
# 73929596
# http://api.brain-map.org/api/v2/data/StructureUnionize/query.json?criteria=[section_data_set_id$eq74958463]&include=section_data_set(products[id$eq1])&start_row=0&num_rows=20000
# 74958463
